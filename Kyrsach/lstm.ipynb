# %%
# LSTM

# %% [markdown]
# ## Импорт библиотек

# %%
import warnings
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime

from sklearn.preprocessing import StandardScaler

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Flatten, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
warnings.filterwarnings('ignore')

# %%
seed = 42
np.random.seed(seed)
random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# ## Загрузка данных

# %%
df = pd.read_csv('df_for_learning.csv', index_col=0)
df.head()
# Out:
#    Индекс ВМО        date  Средняя температура воздуха  Количество осадков  \
# 0       34059  1982-01-31                         -9.2                 0.0
# 1       34059  1982-02-01                        -11.8                 0.0
# 2       34059  1982-02-02                        -15.2                 0.0
# 3       34059  1982-02-03                        -16.3                 0.0
# 4       34059  1982-02-04                        -17.4                 0.0
#
#    Горизонтальная дальность видимости  Общее количество облачности  \
# 0                              69.125                        5.125
# 1                              68.125                        3.375
# 2                              67.625                        1.000
# 3                              53.500                        0.625
# 4                              55.000                        5.000
#
#    Количество облачности нижнего яруса  Форма облаков верхнего яруса  \
# 0                                  0.0                         0.750
# 1                                  0.0                         1.750
# 2                                  0.0                         0.375
# 3                                  0.0                         0.250
# 4                                  0.0                         2.500
#
#    Форма облаков среднего яруса  Форма облаков вертикального развития  ...  \
# 0                         0.000                                   0.0  ...
# 1                         0.125                                   0.0  ...
# 2                         0.000                                   0.0  ...
# 3                         0.000                                   0.0  ...
# 4                         0.625                                   0.0  ...
#
#    Атмосферное давление на уровне станции_lag_395  year  day  day_of_year_sin  \
# 0                                        983.0500  1982   31         0.508671
# 1                                        980.3750  1982    1         0.523416
# 2                                        984.6000  1982    2         0.538005
# 3                                        981.3750  1982    3         0.552435
# 4                                        979.3875  1982    4         0.566702
#
#    day_of_year_cos  season  month_sin  month_cos  \
# 0         0.860961       1   0.500000   0.866025
# 1         0.852078       1   0.866025   0.500000
# 2         0.842942       1   0.866025   0.500000
# 3         0.833556       1   0.866025   0.500000
# 4         0.823923       1   0.866025   0.500000
#
#    Средняя температура воздуха_mean_group  temp_delta_vs_all_stations
# 0                               -8.820930                    0.110631
# 1                               -8.623256                    0.519601
# 2                               -9.165116                    0.276744
# 3                               -9.504651                    0.185382
# 4                               -8.655814                    0.614618
#
# [5 rows x 57 columns]

# %%
df['date'].max()
# Out:
# '2024-09-25'

# %%
df['date'] = pd.to_datetime(df['date'])
df = df.sort_values(['Индекс ВМО', 'date']).reset_index(drop=True)

# %%
df.shape
# Out:
# (109053, 57)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109053 entries, 0 to 109052
# Data columns (total 57 columns):
#  #   Column                                          Non-Null Count   Dtype
# ---  ------                                          --------------   -----
#  0   Индекс ВМО                                      109053 non-null  int64
#  1   date                                            109053 non-null  datetime64[ns]
#  2   Средняя температура воздуха                     109053 non-null  float64
#  3   Количество осадков                              109053 non-null  float64
#  4   Горизонтальная дальность видимости              109053 non-null  float64
#  5   Общее количество облачности                     109053 non-null  float64
#  6   Количество облачности нижнего яруса             109053 non-null  float64
#  7   Форма облаков верхнего яруса                    109053 non-null  float64
#  8   Форма облаков среднего яруса                    109053 non-null  float64
#  9   Форма облаков вертикального развития            109053 non-null  float64
#  10  Слоистые и слоисто_кучевые облака               109053 non-null  float64
#  11  Слоисто_дождразорванно_дождевые облака          109053 non-null  float64
#  12  Высота нижней границы облачности                109053 non-null  float64
#  13  Погода между сроками                            109053 non-null  float64
#  14  Погода в срок наблюдения                        109053 non-null  float64
#  15  Направление ветра                               109053 non-null  float64
#  16  Средняя скорость ветра                          109053 non-null  float64
#  17  Максимальная скорость ветра                     109053 non-null  float64
#  18  Сумма осадков                                   109053 non-null  float64
#  19  Температура поверхности почвы                   109053 non-null  float64
#  20  Парциальное давление водяного пара              109053 non-null  float64
#  21  Относительная влажность воздуха                 109053 non-null  float64
#  22  Дефицит насыщения водяного пара                 109053 non-null  float64
#  23  Атмосферное давление на уровне станции          109053 non-null  float64
#  24  Атмосферное давление на уровне моря             109053 non-null  float64
#  25  Характеристика барической тенденции             109053 non-null  float64
#  26  Величина барической тенденции                   109053 non-null  float64
#  27  Средняя температура воздуха_lag_335             109053 non-null  float64
#  28  Средняя температура воздуха_lag_365             109053 non-null  float64
#  29  Средняя температура воздуха_lag_395             109053 non-null  float64
#  30  Температура поверхности почвы_lag_335           109053 non-null  float64
#  31  Температура поверхности почвы_lag_365           109053 non-null  float64
#  32  Температура поверхности почвы_lag_395           109053 non-null  float64
#  33  Парциальное давление водяного пара_lag_335      109053 non-null  float64
#  34  Парциальное давление водяного пара_lag_365      109053 non-null  float64
#  35  Парциальное давление водяного пара_lag_395      109053 non-null  float64
#  36  Относительная влажность воздуха_lag_335         109053 non-null  float64
#  37  Относительная влажность воздуха_lag_365         109053 non-null  float64
#  38  Относительная влажность воздуха_lag_395         109053 non-null  float64
#  39  Дефицит насыщения водяного пара_lag_335         109053 non-null  float64
#  40  Дефицит насыщения водяного пара_lag_365         109053 non-null  float64
#  41  Дефицит насыщения водяного пара_lag_395         109053 non-null  float64
#  42  Атмосферное давление на уровне моря_lag_335     109053 non-null  float64
#  43  Атмосферное давление на уровне моря_lag_365     109053 non-null  float64
#  44  Атмосферное давление на уровне моря_lag_395     109053 non-null  float64
#  45  Атмосферное давление на уровне станции_lag_335  109053 non-null  float64
#  46  Атмосферное давление на уровне станции_lag_365  109053 non-null  float64
#  47  Атмосферное давление на уровне станции_lag_395  109053 non-null  float64
#  48  year                                            109053 non-null  int64
#  49  day                                             109053 non-null  int64
#  50  day_of_year_sin                                 109053 non-null  float64
#  51  day_of_year_cos                                 109053 non-null  float64
#  52  season                                          109053 non-null  int64
#  53  month_sin                                       109053 non-null  float64
#  54  month_cos                                       109053 non-null  float64
#  55  Средняя температура воздуха_mean_group          109053 non-null  float64
#  56  temp_delta_vs_all_stations                      109053 non-null  float64
# dtypes: datetime64[ns](1), float64(52), int64(4)
# memory usage: 47.4 MB

# %%
df.date.min(), df.date.max()
# Out:
# (Timestamp('1982-01-31 00:00:00'), Timestamp('2024-09-25 00:00:00'))

# %% [markdown]
# ## Функции оценки точности

# %% [markdown]
# #### Простые метрики

# %%
def simple_metric(y_val, y_pred):
    mae = mean_absolute_error(y_val, y_pred)
    mse = mean_squared_error(y_val, y_pred)
    rmse = np.sqrt(mse)
    mape = np.mean(np.abs((y_val - y_pred) / y_val)) * 100
    r2 = r2_score(y_val, y_pred)

    print("Простые метрики:")
    print(f"MAE: {mae:.4f}")
    print(f"MSE: {mse:.4f}")
    print(f"RMSE: {rmse:.4f}")
    print(f"MAPE: {mape:.2f}%")
    print(f"R²: {r2:.4f}")
    return {
        'MAE': mae,
        'MSE': mse,
        'RMSE': rmse,
        'MAPE': mape,
        'R2': r2
    }

# %% [markdown]
# #### Ошибки по дням

# %%
def daily_metrics_lstm(val_df, y_pred, station_ids,
                       date_col='date',
                       station_col='Индекс ВМО',
                       target_col='Средняя температура воздуха'):

    val_df = val_df.sort_values([station_col, date_col]).copy()
    horizon = y_pred.shape[1]

    rows = []

    for i, station_id in enumerate(station_ids):
        station_df = val_df[val_df[station_col] == station_id].copy()
        station_df = station_df.sort_values(date_col)

        if len(station_df) < horizon:
            continue

        station_df = station_df.tail(horizon)
        station_df['prediction'] = y_pred[i]

        rows.append(station_df)

    df_plot = pd.concat(rows, axis=0)

    results = []

    for date, group in df_plot.groupby(date_col):
        y_true = group[target_col].values
        y_hat = group['prediction'].values

        mae = mean_absolute_error(y_true, y_hat)
        rmse = np.sqrt(mean_squared_error(y_true, y_hat))
        r2 = r2_score(y_true, y_hat)

        results.append({
            'date': date,
            'MAE': mae,
            'RMSE': rmse,
            'R2': r2
        })

    return pd.DataFrame(results).sort_values('date')

# %% [markdown]
# #### Столбчатые диаграммы ошибок по индексам

# %%
def metrics_per_index_lstm(val_df, y_pred, station_ids,
                          index_col='Индекс ВМО',
                          date_col='date',
                          target_col='Средняя температура воздуха'):

    val_df = val_df.sort_values([index_col, date_col]).copy()
    horizon = y_pred.shape[1]

    rows = []
    for i, station_id in enumerate(station_ids):
        station_df = val_df[val_df[index_col] == station_id].copy()
        station_df = station_df.sort_values(date_col)

        if len(station_df) < horizon:
            continue

        station_df = station_df.tail(horizon)
        station_df['prediction'] = y_pred[i]

        rows.append(station_df)

    df_plot = pd.concat(rows, axis=0)

    metrics_list = []

    for idx, group in df_plot.groupby(index_col):
        y_true = group[target_col].values
        y_hat = group['prediction'].values

        mae = mean_absolute_error(y_true, y_hat)
        rmse = np.sqrt(mean_squared_error(y_true, y_hat))
        r2 = r2_score(y_true, y_hat) if len(y_true) > 1 else np.nan

        metrics_list.append({
            index_col: idx,
            'MAE': mae,
            'RMSE': rmse,
            'R2': r2
        })

    metrics_df = pd.DataFrame(metrics_list).sort_values(index_col)

    fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharex=True)

    axes[0].bar(metrics_df[index_col].astype(str), metrics_df['MAE'])
    axes[0].set_title('MAE по индексам')
    axes[0].set_ylabel('MAE')

    axes[1].bar(metrics_df[index_col].astype(str), metrics_df['RMSE'])
    axes[1].set_title('RMSE по индексам')
    axes[1].set_ylabel('RMSE')

    axes[2].bar(metrics_df[index_col].astype(str), metrics_df['R2'])
    axes[2].set_title('R² по индексам')
    axes[2].set_ylabel('R²')

    for ax in axes:
        ax.set_xlabel('Индекс ВМО')
        ax.tick_params(axis='x', rotation=45)

    plt.tight_layout()
    plt.show()

    return metrics_df

# %% [markdown]
# #### Линейный график MAE

# %%
def cumulative_mae_lstm(val_df, y_pred, station_ids,
                       date_col='date',
                       station_col='Индекс ВМО',
                       target_col='Средняя температура воздуха'):

    val_df = val_df.sort_values([station_col, date_col]).copy()
    horizon = y_pred.shape[1]

    rows = []

    for i, station_id in enumerate(station_ids):
        station_df = val_df[val_df[station_col] == station_id].copy()
        station_df = station_df.sort_values(date_col)

        if len(station_df) < horizon:
            continue

        station_df = station_df.tail(horizon)
        station_df['prediction'] = y_pred[i]

        rows.append(station_df)

    df_plot = pd.concat(rows, axis=0)

    df_plot = df_plot.sort_values(date_col)

    cum_errors = []
    all_true = []
    all_pred = []

    for date, group in df_plot.groupby(date_col):
        all_true.extend(group[target_col].values)
        all_pred.extend(group['prediction'].values)

        mae = mean_absolute_error(all_true, all_pred)

        cum_errors.append({
            'date': date,
            'Cumulative_MAE': mae
        })

    cum_df = pd.DataFrame(cum_errors)

    plt.figure(figsize=(12, 5))
    plt.plot(cum_df['date'], cum_df['Cumulative_MAE'], marker='o')
    plt.xlabel('Дата')
    plt.ylabel('MAE')
    plt.title('MAE по дням (LSTM)')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    return cum_df

# %% [markdown]
# #### Накопление ошибки Mae

# %%
def cumulative_error_lstm(val_df, y_pred, station_ids,
                         date_col='date',
                         station_col='Индекс ВМО',
                         target_col='Средняя температура воздуха'):

    val_df = val_df.sort_values([station_col, date_col]).copy()
    horizon = y_pred.shape[1]

    rows = []

    for i, station_id in enumerate(station_ids):
        station_df = val_df[val_df[station_col] == station_id].copy()
        station_df = station_df.sort_values(date_col)

        if len(station_df) < horizon:
            continue

        station_df = station_df.tail(horizon)
        station_df['prediction'] = y_pred[i]

        rows.append(station_df)

    df_plot = pd.concat(rows, axis=0)

    df_plot = df_plot.sort_values(date_col)

    cum_errors = []
    total_error = 0

    for date, group in df_plot.groupby(date_col):
        daily_error = np.abs(group[target_col] - group['prediction']).sum()
        total_error += daily_error

        cum_errors.append({
            'date': date,
            'Cumulative_Error': total_error
        })

    cum_df = pd.DataFrame(cum_errors)

    plt.figure(figsize=(12, 5))
    plt.plot(cum_df['date'], cum_df['Cumulative_Error'], marker='o')
    plt.xlabel('Дата')
    plt.ylabel('Cumulative Absolute Error')
    plt.title('Накопление абсолютной ошибки (LSTM)')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    return cum_df

# %% [markdown]
# #### Сравнения истинной средней и предсказанной средней

# %%
def plot_true_vs_pred(val_df, y_pred, station_ids,
                     date_col='date',
                     station_col='Индекс ВМО',
                     target_col='Средняя температура воздуха'):

    val_df = val_df.sort_values([station_col, date_col]).copy()

    preds_list = []

    horizon = y_pred.shape[1]

    for i, station_id in enumerate(station_ids):
        station_df = val_df[val_df[station_col] == station_id].copy()
        station_df = station_df.sort_values(date_col)

        if len(station_df) < horizon:
            continue

        # берём последние 30 дней
        station_df = station_df.tail(horizon)

        station_df['prediction'] = y_pred[i]
        preds_list.append(station_df)

    if len(preds_list) == 0:
        raise ValueError("Нет данных для построения графика")

    df_plot = pd.concat(preds_list, axis=0)

    # агрегируем по дате
    daily_true = df_plot.groupby(date_col)[target_col].mean()
    daily_pred = df_plot.groupby(date_col)['prediction'].mean()


    plt.figure(figsize=(12, 6))

    plt.plot(daily_true.index, daily_true.values, label='True', marker='o')
    plt.plot(daily_pred.index, daily_pred.values, label='Pred', linestyle='--', marker='x')

    plt.legend()
    plt.title('True vs Pred (last 30 days)')
    plt.xticks(rotation=45)
    plt.grid(True)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Сравнение истинной и предсказанной по индексам

# %%
def plot_true_vs_pred_by_index(val_df, y_pred, station_ids,
                              date_col='date',
                              index_col='Индекс ВМО',
                              target_col='Средняя температура воздуха'):

    val_df = val_df.sort_values([index_col, date_col]).copy()

    horizon = y_pred.shape[1]

    n_indices = len(station_ids)

    # сетка графиков
    n_cols = 2
    n_rows = (n_indices + 1) // n_cols

    fig, axes = plt.subplots(n_rows, n_cols, figsize=(14, n_rows * 3), sharex=False, sharey=False)
    axes = axes.flatten()

    for i, station_id in enumerate(station_ids):
        ax = axes[i]

        station_df = val_df[val_df[index_col] == station_id].copy()
        station_df = station_df.sort_values(date_col)

        if len(station_df) < horizon:
            ax.set_title(f'{station_id} (skip)')
            ax.axis('off')
            continue

        # берём последние 30 дней
        station_df = station_df.tail(horizon)

        y_true = station_df[target_col].values
        y_hat = y_pred[i]

        ax.plot(station_df[date_col], y_true, label='True', marker='o')
        ax.plot(station_df[date_col], y_hat, label='Pred', linestyle='--', marker='x')

        ax.set_title(f'Индекс ВМО: {station_id}')
        ax.grid(True)

        if i % n_cols == 0:
            ax.set_ylabel('Температура')

        ax.tick_params(axis='x', rotation=45)
        ax.legend(fontsize=8)

    # скрываем пустые
    for j in range(i + 1, len(axes)):
        axes[j].axis('off')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Построение модели LSTM

# %% [markdown]
# ### Задание параметров

# %%
TARGET_COL = 'Средняя температура воздуха'
WINDOW = 45
HORIZON = 30

# %% [markdown]
# ### Разделение данных

# %%
val_start = df['date'].max() - pd.Timedelta(days=HORIZON)

train_df = df[df['date'] < val_start].copy()
val_df = df[df['date'] >= val_start].copy()

print("Train:", train_df.shape)
print("Val:", val_df.shape)
# Out:
# Train: (108836, 57)
# Val: (217, 57)

# %% [markdown]
# ### Создание последовательностей для train

# %%
def create_sequences_multi(df, target_col, window=30, horizon=30):
    X, y = [], []

    for station_id, group in df.groupby('Индекс ВМО'):
        group = group.sort_values('date')

        features = group.drop(columns=['date']).values
        target = group[target_col].values

        for i in range(len(group) - window - horizon + 1):
            X.append(features[i:i + window])
            y.append(target[i + window:i + window + horizon])

    return np.array(X), np.array(y)

# %%
X_train, y_train = create_sequences_multi(train_df, TARGET_COL, WINDOW, HORIZON)

print("X_train:", X_train.shape)
print("y_train:", y_train.shape)
# Out:
# X_train: (108318, 45, 56)
# y_train: (108318, 30)

# %% [markdown]
# ### Создание окна для последнего месяца

# %%
def create_last_window(df, window=30):
    X_last = []
    station_ids = []

    for station_id, group in df.groupby('Индекс ВМО'):
        group = group.sort_values('date')

        if len(group) < window:
            print('Что-то не так!!!')
            continue

        last_window = group.drop(columns=['date']).values[-window:]
        X_last.append(last_window)
        station_ids.append(station_id)

    return np.array(X_last), station_ids

# %%
X_val, station_ids = create_last_window(train_df, WINDOW)

print("X_val:", X_val.shape)
# Out:
# X_val: (7, 45, 56)

# %% [markdown]
# ### Нормализация

# %%
n_samples, n_steps, n_features = X_train.shape

scaler = StandardScaler()

X_train_2d = X_train.reshape(-1, n_features)
X_val_2d = X_val.reshape(-1, n_features)

X_train_scaled = scaler.fit_transform(X_train_2d)
X_val_scaled = scaler.transform(X_val_2d)

X_train = X_train_scaled.reshape(n_samples, n_steps, n_features)
X_val = X_val_scaled.reshape(X_val.shape[0], n_steps, n_features)

# %%
# y_scaler = StandardScaler()
#
# y_train_2d = y_train.reshape(-1, 1)
# y_train_scaled = y_scaler.fit_transform(y_train_2d).reshape(y_train.shape)

# %% [markdown]
# ### Построение и обучение модели

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True
)

# %%
model = Sequential([
    LSTM(64, return_sequences=True, input_shape=(WINDOW, n_features)),
    LSTM(64, return_sequences=True),

    Flatten(),

    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(HORIZON)
])

model.compile(
    optimizer='adam',
    loss='mse',
    metrics=['mae']
)


model.summary()

# TRAIN
model.fit(
    X_train, y_train,
    epochs=5,
    batch_size=64,
    verbose=1
)

# model.fit(
#     X_train, y_train,
#     validation_split=0.1,
#     epochs=50,
#     batch_size=64,
#     callbacks=[early_stop],
#     verbose=1
# )
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 45, 64)         │        30,976 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 45, 64)         │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2880)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       368,768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 30)             │         1,950 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 442,974 (1.69 MB)
#  Trainable params: 442,974 (1.69 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/5
# 1693/1693 ━━━━━━━━━━━━━━━━━━━━ 52s 29ms/step - loss: 19.2204 - mae: 3.3958
# Epoch 2/5
# 1693/1693 ━━━━━━━━━━━━━━━━━━━━ 49s 29ms/step - loss: 9.7088 - mae: 2.4207
# Epoch 3/5
# 1693/1693 ━━━━━━━━━━━━━━━━━━━━ 48s 28ms/step - loss: 7.0853 - mae: 2.0499
# Epoch 4/5
# 1693/1693 ━━━━━━━━━━━━━━━━━━━━ 49s 29ms/step - loss: 5.7672 - mae: 1.8423
# Epoch 5/5
# 1693/1693 ━━━━━━━━━━━━━━━━━━━━ 49s 29ms/step - loss: 4.9283 - mae: 1.6981

# %% [markdown]
# Лучшая точность - для 12 эпох

# %% [markdown]
# ### Предсказание

# %%
print(tf.__version__)
# Out:
# 2.21.0

# %%
y_pred = model.predict(X_val)

print("y_pred shape:", y_pred.shape)  # (n_stations, 30)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# y_pred shape: (7, 30)

# %%
def get_true_last(df, horizon=30):
    y_true = []

    for station_id, group in df.groupby('Индекс ВМО'):
        group = group.sort_values('date')

        if len(group) < horizon:
            continue

        y_true.append(group[TARGET_COL].values[-horizon:])

    return np.array(y_true)


y_val_true = get_true_last(df, HORIZON)

print("y_val_true shape:", y_val_true.shape)

mae = np.mean(np.abs(y_val_true - y_pred))
print("MAE (val, last 30 days):", mae)
# Out:
# y_val_true shape: (7, 30)
# MAE (val, last 30 days): 2.296419262658982

# %% [markdown]
# ## Результат

# %%
simple_metric(y_val_true, y_pred)
# Out:
# Простые метрики:
# MAE: 2.2964
# MSE: 8.2803
# RMSE: 2.8776
# MAPE: 13.59%
# R²: -14.9403
# {'MAE': 2.296419262658982,
#  'MSE': 8.280316502277877,
#  'RMSE': np.float64(2.877553909534603),
#  'MAPE': np.float64(13.589891632185825),
#  'R2': -14.940313515173953}

# %%
# Простые метрики:
# MAE: 2.8338
# MSE: 12.3285
# RMSE: 3.5112
# MAPE: 15.18%
# R²: -25.2074
# {'MAE': 2.833763309660412,
#  'MSE': 12.328545332635999,
#  'RMSE': np.float64(3.511202832739231),
#  'MAPE': np.float64(15.175809142167617),
#  'R2': -25.20740934641087}

# %%
# Простые метрики:
# MAE: 2.2967
# MSE: 7.6634
# RMSE: 2.7683
# MAPE: 12.46%
# R²: -11.4362
# {'MAE': 2.296705726441883,
#  'MSE': 7.663381013601805,
#  'RMSE': np.float64(2.7682812381695987),
#  'MAPE': np.float64(12.458791539905576),
#  'R2': -11.436202572226758}

# %%
# Простые метрики:
# MAE: 3.3847
# MSE: 16.8327
# RMSE: 4.1028
# MAPE: 17.74%
# R²: -30.2155
# {'MAE': 3.384740012940907,
#  'MSE': 16.83274589239718,
#  'RMSE': np.float64(4.102772951602024),
#  'MAPE': np.float64(17.73559571763238),
#  'R2': -30.215536987962636}

# %%
## 50 эпох
# Простые метрики:
# MAE: 3.0935
# MSE: 14.0200
# RMSE: 3.7443
# MAPE: 16.45%
# R²: -28.6039
# {'MAE': 3.093512511480422,
#  'MSE': 14.020010440273506,
#  'RMSE': np.float64(3.7443304395143207),
#  'MAPE': np.float64(16.446405131278727),
#  'R2': -28.603883060360978}

# %%
# Простые метрики:
# MAE: 2.3602
# MSE: 8.7305
# RMSE: 2.9547
# MAPE: 12.82%
# R²: -12.1426
# {'MAE': 2.3602105603899277,
#  'MSE': 8.73045482022608,
#  'RMSE': np.float64(2.9547343061984574),
#  'MAPE': np.float64(12.821361241778492),
#  'R2': -12.142640887712446}

# %%
# Простые метрики:
# MAE: 2.2967
# MSE: 7.6634
# RMSE: 2.7683
# MAPE: 12.46%
# R²: -11.4362
# {'MAE': 2.296705726441883,
#  'MSE': 7.663381013601805,
#  'RMSE': np.float64(2.7682812381695987),
#  'MAPE': np.float64(12.458791539905576),
#  'R2': -11.436202572226758}

# %%
# Простые метрики:
# MAE: 2.4334
# MSE: 8.3286
# RMSE: 2.8859
# MAPE: 13.22%
# R²: -13.9980
# {'MAE': 2.4334070441836397,
#  'MSE': 8.328596360402546,
#  'RMSE': np.float64(2.8859307615399485),
#  'MAPE': np.float64(13.219313185678958),
#  'R2': -13.997996462961863}

# %%
# Простые метрики:
# MAE: 2.5671
# MSE: 10.1874
# RMSE: 3.1918
# MAPE: 14.49%
# R²: -22.9511
# {'MAE': 2.5670682098751976,
#  'MSE': 10.187409655295433,
#  'RMSE': np.float64(3.191772180982758),
#  'MAPE': np.float64(14.494043242578591),
#  'R2': -22.951125595980447}

# %%
plot_true_vs_pred(val_df, y_pred, station_ids)

# %%
plot_true_vs_pred_by_index(val_df, y_pred, station_ids)

# %%
df_metrics = daily_metrics_lstm(val_df, y_pred, station_ids)

df_metrics
# Out:
#          date       MAE      RMSE          R2
# 0  2024-08-27  0.385074  0.509746    0.514778
# 1  2024-08-28  1.137157  1.472263   -2.647333
# 2  2024-08-29  1.194439  1.613109   -4.133011
# 3  2024-08-30  0.839181  1.167496   -1.169892
# 4  2024-08-31  1.563511  1.775689   -1.455506
# 5  2024-09-01  1.594272  1.861529   -2.117872
# 6  2024-09-02  0.956360  1.061026   -2.367708
# 7  2024-09-03  1.315832  1.548996   -5.672532
# 8  2024-09-04  0.581500  0.729343    0.576727
# 9  2024-09-05  3.462842  3.553476   -8.676765
# 10 2024-09-06  4.220887  4.435515  -44.386820
# 11 2024-09-07  2.772322  2.952167  -40.867564
# 12 2024-09-08  1.125445  1.370431   -1.745406
# 13 2024-09-09  3.843703  4.161924  -17.719868
# 14 2024-09-10  3.984150  4.411135  -13.021289
# 15 2024-09-11  5.183345  5.301566  -70.284854
# 16 2024-09-12  5.152103  5.216577 -102.848983
# 17 2024-09-13  2.105260  2.277108  -24.056788
# 18 2024-09-14  1.769534  2.091379  -19.970588
# 19 2024-09-15  1.760529  1.918391   -7.857122
# 20 2024-09-16  2.372082  2.598839  -11.220980
# 21 2024-09-17  2.299473  2.727297  -14.522545
# 22 2024-09-18  2.269017  2.654084   -5.137339
# 23 2024-09-19  1.199556  1.582874   -3.970408
# 24 2024-09-20  1.639510  1.957085   -3.756180
# 25 2024-09-21  1.003243  1.156789   -0.989377
# 26 2024-09-22  1.386984  1.927051   -0.795922
# 27 2024-09-23  4.281119  4.346437  -14.604924
# 28 2024-09-24  4.415052  4.594358  -16.272847
# 29 2024-09-25  3.079096  3.238136   -7.030488

# %%
metrics_df = metrics_per_index_lstm(val_df, y_pred, station_ids)

print(metrics_df)
# Out:
#    Индекс ВМО       MAE      RMSE        R2
# 0       34059  2.124548  2.646355  0.461987
# 1       34152  2.020894  2.488395  0.513728
# 2       34163  1.916037  2.363010  0.581806
# 3       34172  2.301972  2.876494  0.311894
# 4       34186  2.447639  3.062976  0.353028
# 5       34289  2.381281  3.090646  0.219417
# 6       34391  2.882564  3.460486  0.090623

# %% [markdown]
# 34172 - индекс станции Саратова, скорее всего город сильно отличается от всех остальных городов, и поэтому хуже всего результаты

# %%
cum_df = cumulative_mae_lstm(val_df, y_pred, station_ids)

print(cum_df.head())
# Out:
#         date  Cumulative_MAE
# 0 2024-08-27        0.385074
# 1 2024-08-28        0.761116
# 2 2024-08-29        0.905557
# 3 2024-08-30        0.888963
# 4 2024-08-31        1.023872

# %%
cum_err_df = cumulative_error_lstm(val_df, y_pred, station_ids)

print(cum_err_df.head())
# Out:
#         date  Cumulative_Error
# 0 2024-08-27          2.695521
# 1 2024-08-28         10.655619
# 2 2024-08-29         19.016691
# 3 2024-08-30         24.890961
# 4 2024-08-31         35.835535

# %% [markdown]
# ## Важность признаков

# %%
def permutation_importance_lstm(model, X_val, y_true, n_repeats=3):
    """
    model     — обученная модель
    X_val     — (n_samples, window, n_features)
    y_true    — (n_samples, horizon)
    n_repeats — сколько раз перемешивать (для стабильности)
    """

    # базовый прогноз
    y_pred = model.predict(X_val, verbose=0)
    baseline_mae = np.mean(np.abs(y_true - y_pred))

    n_features = X_val.shape[2]
    importances = []

    for feature_idx in range(n_features):
        scores = []

        for _ in range(n_repeats):
            X_perm = X_val.copy()

            # перемешиваем ОДИН признак
            flat = X_perm[:, :, feature_idx].reshape(-1)
            np.random.shuffle(flat)
            X_perm[:, :, feature_idx] = flat.reshape(X_perm[:, :, feature_idx].shape)

            y_pred_perm = model.predict(X_perm, verbose=0)
            mae_perm = np.mean(np.abs(y_true - y_pred_perm))

            scores.append(mae_perm - baseline_mae)

        importances.append(np.mean(scores))

    return np.array(importances), baseline_mae

# %%
importances, base_mae = permutation_importance_lstm(
    model, X_val, y_val_true, n_repeats=3
)

print("Baseline MAE:", base_mae)
# Out:
# Baseline MAE: 2.296419262658982

# %%
feature_names = train_df.drop(columns=['date']).columns.tolist()

importance_df = sorted(
    zip(feature_names, importances),
    key=lambda x: x[1],
    reverse=True
)

for name, score in importance_df:
    print(f"{name}: {score:.6f}")
# Out:
# day: 0.227404
# Дефицит насыщения водяного пара: 0.147420
# Атмосферное давление на уровне станции_lag_335: 0.139319
# Направление ветра: 0.136251
# Относительная влажность воздуха_lag_335: 0.101760
# Погода между сроками: 0.097043
# Парциальное давление водяного пара_lag_335: 0.070020
# Дефицит насыщения водяного пара_lag_365: 0.060258
# Относительная влажность воздуха_lag_365: 0.058954
# Атмосферное давление на уровне моря_lag_395: 0.052705
# Количество осадков: 0.052637
# Дефицит насыщения водяного пара_lag_335: 0.051002
# Относительная влажность воздуха_lag_395: 0.043146
# Количество облачности нижнего яруса: 0.042446
# Атмосферное давление на уровне моря: 0.040499
# Относительная влажность воздуха: 0.036734
# Величина барической тенденции: 0.035079
# Температура поверхности почвы_lag_335: 0.030387
# Характеристика барической тенденции: 0.029549
# Сумма осадков: 0.025467
# Средняя температура воздуха_lag_365: 0.022399
# Температура поверхности почвы_lag_365: 0.020713
# Дефицит насыщения водяного пара_lag_395: 0.008242
# Максимальная скорость ветра: 0.007649
# Форма облаков среднего яруса: 0.006629
# Средняя температура воздуха_mean_group: 0.005552
# Высота нижней границы облачности: 0.003665
# Форма облаков верхнего яруса: 0.001982
# Средняя температура воздуха_lag_335: 0.000657
# year: 0.000000
# season: 0.000000
# Горизонтальная дальность видимости: -0.000554
# Слоисто_дождразорванно_дождевые облака: -0.004130
# Атмосферное давление на уровне станции_lag_365: -0.004309
# Слоистые и слоисто_кучевые облака: -0.004486
# Средняя скорость ветра: -0.006137
# month_sin: -0.009540
# day_of_year_cos: -0.010244
# Температура поверхности почвы: -0.010700
# Средняя температура воздуха_lag_395: -0.017345
# Общее количество облачности: -0.019367
# Парциальное давление водяного пара: -0.022378
# Погода в срок наблюдения: -0.023830
# Средняя температура воздуха: -0.025385
# Форма облаков вертикального развития: -0.027090
# Температура поверхности почвы_lag_395: -0.034027
# Индекс ВМО: -0.039007
# Парциальное давление водяного пара_lag_365: -0.040481
# day_of_year_sin: -0.045174
# Атмосферное давление на уровне моря_lag_365: -0.067219
# Атмосферное давление на уровне станции: -0.067581
# Атмосферное давление на уровне моря_lag_335: -0.068948
# month_cos: -0.076011
# Парциальное давление водяного пара_lag_395: -0.106241
# temp_delta_vs_all_stations: -0.142903
# Атмосферное давление на уровне станции_lag_395: -0.147359

# %%
# берём топ-20
top_k = 20
top_features = importance_df[:top_k]

names = [x[0] for x in top_features]
values = [x[1] for x in top_features]

plt.figure(figsize=(10, 6))
plt.barh(names[::-1], values[::-1])  # переворот, чтобы самый важный был сверху
plt.xlabel("Importance (ΔMAE)")
plt.title("Feature Importance (Permutation)")

plt.tight_layout()
plt.show()
# Out:
# KeyboardInterrupt
#
# Exception ignored in: <function WeakKeyDictionary.__init__.<locals>.remove at 0x0000022711582020>
# Traceback (most recent call last):
#   File "C:\Users\Mostov\AppData\Local\Programs\Python\Python311\Lib\weakref.py", line 370, in remove
#     self = selfref()
#            ^^^^^^^^^
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File C:\Pycharm Project\Data-Science-Projects\.venv\Lib\site-packages\IPython\core\async_helpers.py:128, in _pseudo_sync_runner(coro)
#     120 """
#     121 A runner that does not really allow async execution, and just advance the coroutine.
#     122
#    (...)    125 Credit to Nathaniel Smith
#     126 """
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#     130     return exc.value
#
# File C:\Pycharm Project\Data-Science-Projects\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3413, in InteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple, cell_id)
#    3409 exec_count = self.execution_count
#    3410 if result.error_in_exec:
#    3411     # Store formatted traceback and error details
#    3412     self.history_manager.exceptions[exec_count] = (
# -> 3413         self._format_exception_for_storage(result.error_in_exec)
#    3414     )
#    3416 # Each cell is a *single* input, regardless of how many lines it has
#    3417 self.execution_count += 1
#
# File C:\Pycharm Project\Data-Science-Projects\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3467, in InteractiveShell._format_exception_for_storage(self, exception, filename, running_compiled_code)
#    3464         stb = evalue._render_traceback_()
#    3465     else:
#    3466         # Otherwise, use InteractiveTB to format the traceback.
# -> 3467         stb = self.InteractiveTB.structured_traceback(
#    3468             etype, evalue, tb, tb_offset=1
#    3469         )
#    3470 except Exception:
#    3471     # In case formatting fails, fallback to Python's built-in formatting.
#    3472     stb = traceback.format_exception(etype, evalue, tb)
#
# File C:\Pycharm Project\Data-Science-Projects\.venv\Lib\site-packages\IPython\core\ultratb.py:1188, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1186 else:
#    1187     self.tb = etb
# -> 1188 return FormattedTB.structured_traceback(
#    1189     self, etype, evalue, etb, tb_offset, context
#    1190 )
#
# File C:\Pycharm Project\Data-Science-Projects\.venv\Lib\site-packages\IPython\core\ultratb.py:1059, in FormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1056 mode = self.mode
#    1057 if mode in self.verbose_modes:
#    1058     # Verbose modes need a full traceback
# -> 1059     return VerboseTB.structured_traceback(
#    1060         self, etype, evalue, etb, tb_offset, context
#    1061     )
#    1062 elif mode == "Docs":
#    1063     # return DocTB
#    1064     return DocTB(
#    1065         theme_name=self._theme_name,
#    1066         call_pdb=self.call_pdb,
#    (...)   1074         etype, evalue, etb, tb_offset, 1
#    1075     )  # type: ignore[arg-type]
#
# File C:\Pycharm Project\Data-Science-Projects\.venv\Lib\site-packages\IPython\core\ultratb.py:867, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     858 def structured_traceback(
#     859     self,
#     860     etype: type,
#    (...)    864     context: int = 5,
#     865 ) -> list[str]:
#     866     """Return a nice text document describing the traceback."""
# --> 867     formatted_exceptions: list[list[str]] = self.format_exception_as_a_whole(
#     868         etype, evalue, etb, context, tb_offset
#     869     )
#     871     termsize = min(75, get_terminal_size()[0])
#     872     theme = theme_table[self._theme_name]
#
# File C:\Pycharm Project\Data-Science-Projects\.venv\Lib\site-packages\IPython\core\ultratb.py:752, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, context, tb_offset)
#     750 assert isinstance(tb_offset, int)
#     751 head = self.prepare_header(str(etype), self.long_header)
# --> 752 records = self.get_records(etb, context, tb_offset) if etb else []
#     754 frames = []
#     755 skipped = 0
#
# File C:\Pycharm Project\Data-Science-Projects\.venv\Lib\site-packages\IPython\core\ultratb.py:825, in VerboseTB.get_records(self, etb, context, tb_offset)
#     823 while cf is not None:
#     824     try:
# --> 825         mod = inspect.getmodule(cf.tb_frame)
#     826         if mod is not None:
#     827             mod_name = mod.__name__
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\inspect.py:980, in getmodule(object, _filename)
#     978 # Try the cache again with the absolute file name
#     979 try:
# --> 980     file = getabsfile(object, _filename)
#     981 except (TypeError, FileNotFoundError):
#     982     return None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\inspect.py:963, in getabsfile(object, _filename)
#     958 """Return an absolute path to the source or compiled file for an object.
#     959
#     960 The idea is for each object to have a unique origin, so this routine
#     961 normalizes the result as much as possible."""
#     962 if _filename is None:
# --> 963     _filename = getsourcefile(object) or getfile(object)
#     964 return os.path.normcase(os.path.abspath(_filename))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\inspect.py:948, in getsourcefile(object)
#     946     return filename
#     947 # only return a non-existent filename if the module has a PEP 302 loader
# --> 948 module = getmodule(object, filename)
#     949 if getattr(module, '__loader__', None) is not None:
#     950     return filename
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\inspect.py:997, in getmodule(object, _filename)
#     994         f = getabsfile(module)
#     995         # Always map to the name the module knows itself by
#     996         modulesbyfile[f] = modulesbyfile[
# --> 997             os.path.realpath(f)] = module.__name__
#     998 if file in modulesbyfile:
#     999     return sys.modules.get(modulesbyfile[file])
#
# File <frozen ntpath>:723, in realpath(path, strict)
#
# KeyboardInterrupt:

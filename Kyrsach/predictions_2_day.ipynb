# %% [markdown]
# ## Импорт библиотек

# %%
import warnings
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import itertools

from datetime import datetime

from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

import xgboost as xgb
import lightgbm as lgb
from sklearn.ensemble import HistGradientBoostingRegressor
from catboost import CatBoostRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn.model_selection import GridSearchCV

# %%
warnings.filterwarnings('ignore')

# %%
seed = 42
np.random.seed(seed)
random.seed(seed)

# %% [markdown]
# ## Загрузка данных

# %%
df = pd.read_csv('df_for_learning.csv', index_col=0)
df.head()
# Out:
#    Индекс ВМО        date  Средняя температура воздуха  Количество осадков  \
# 0       34059  1982-01-31                         -9.2                 0.0
# 1       34059  1982-02-01                        -11.8                 0.0
# 2       34059  1982-02-02                        -15.2                 0.0
# 3       34059  1982-02-03                        -16.3                 0.0
# 4       34059  1982-02-04                        -17.4                 0.0
#
#    Горизонтальная дальность видимости  Общее количество облачности  \
# 0                              69.125                        5.125
# 1                              68.125                        3.375
# 2                              67.625                        1.000
# 3                              53.500                        0.625
# 4                              55.000                        5.000
#
#    Количество облачности нижнего яруса  Форма облаков верхнего яруса  \
# 0                                  0.0                         0.750
# 1                                  0.0                         1.750
# 2                                  0.0                         0.375
# 3                                  0.0                         0.250
# 4                                  0.0                         2.500
#
#    Форма облаков среднего яруса  Форма облаков вертикального развития  ...  \
# 0                         0.000                                   0.0  ...
# 1                         0.125                                   0.0  ...
# 2                         0.000                                   0.0  ...
# 3                         0.000                                   0.0  ...
# 4                         0.625                                   0.0  ...
#
#    Атмосферное давление на уровне станции_lag_395  year  day  day_of_year_sin  \
# 0                                        983.0500  1982   31         0.508671
# 1                                        980.3750  1982    1         0.523416
# 2                                        984.6000  1982    2         0.538005
# 3                                        981.3750  1982    3         0.552435
# 4                                        979.3875  1982    4         0.566702
#
#    day_of_year_cos  season  month_sin  month_cos  \
# 0         0.860961       1   0.500000   0.866025
# 1         0.852078       1   0.866025   0.500000
# 2         0.842942       1   0.866025   0.500000
# 3         0.833556       1   0.866025   0.500000
# 4         0.823923       1   0.866025   0.500000
#
#    Средняя температура воздуха_mean_group  temp_delta_vs_all_stations
# 0                               -8.820930                    0.110631
# 1                               -8.623256                    0.519601
# 2                               -9.165116                    0.276744
# 3                               -9.504651                    0.185382
# 4                               -8.655814                    0.614618
#
# [5 rows x 57 columns]

# %%
df['date'] = pd.to_datetime(df['date'])
df = df.sort_values(['Индекс ВМО', 'date']).reset_index(drop=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109053 entries, 0 to 109052
# Data columns (total 57 columns):
#  #   Column                                          Non-Null Count   Dtype
# ---  ------                                          --------------   -----
#  0   Индекс ВМО                                      109053 non-null  int64
#  1   date                                            109053 non-null  datetime64[ns]
#  2   Средняя температура воздуха                     109053 non-null  float64
#  3   Количество осадков                              109053 non-null  float64
#  4   Горизонтальная дальность видимости              109053 non-null  float64
#  5   Общее количество облачности                     109053 non-null  float64
#  6   Количество облачности нижнего яруса             109053 non-null  float64
#  7   Форма облаков верхнего яруса                    109053 non-null  float64
#  8   Форма облаков среднего яруса                    109053 non-null  float64
#  9   Форма облаков вертикального развития            109053 non-null  float64
#  10  Слоистые и слоисто_кучевые облака               109053 non-null  float64
#  11  Слоисто_дождразорванно_дождевые облака          109053 non-null  float64
#  12  Высота нижней границы облачности                109053 non-null  float64
#  13  Погода между сроками                            109053 non-null  float64
#  14  Погода в срок наблюдения                        109053 non-null  float64
#  15  Направление ветра                               109053 non-null  float64
#  16  Средняя скорость ветра                          109053 non-null  float64
#  17  Максимальная скорость ветра                     109053 non-null  float64
#  18  Сумма осадков                                   109053 non-null  float64
#  19  Температура поверхности почвы                   109053 non-null  float64
#  20  Парциальное давление водяного пара              109053 non-null  float64
#  21  Относительная влажность воздуха                 109053 non-null  float64
#  22  Дефицит насыщения водяного пара                 109053 non-null  float64
#  23  Атмосферное давление на уровне станции          109053 non-null  float64
#  24  Атмосферное давление на уровне моря             109053 non-null  float64
#  25  Характеристика барической тенденции             109053 non-null  float64
#  26  Величина барической тенденции                   109053 non-null  float64
#  27  Средняя температура воздуха_lag_335             109053 non-null  float64
#  28  Средняя температура воздуха_lag_365             109053 non-null  float64
#  29  Средняя температура воздуха_lag_395             109053 non-null  float64
#  30  Температура поверхности почвы_lag_335           109053 non-null  float64
#  31  Температура поверхности почвы_lag_365           109053 non-null  float64
#  32  Температура поверхности почвы_lag_395           109053 non-null  float64
#  33  Парциальное давление водяного пара_lag_335      109053 non-null  float64
#  34  Парциальное давление водяного пара_lag_365      109053 non-null  float64
#  35  Парциальное давление водяного пара_lag_395      109053 non-null  float64
#  36  Относительная влажность воздуха_lag_335         109053 non-null  float64
#  37  Относительная влажность воздуха_lag_365         109053 non-null  float64
#  38  Относительная влажность воздуха_lag_395         109053 non-null  float64
#  39  Дефицит насыщения водяного пара_lag_335         109053 non-null  float64
#  40  Дефицит насыщения водяного пара_lag_365         109053 non-null  float64
#  41  Дефицит насыщения водяного пара_lag_395         109053 non-null  float64
#  42  Атмосферное давление на уровне моря_lag_335     109053 non-null  float64
#  43  Атмосферное давление на уровне моря_lag_365     109053 non-null  float64
#  44  Атмосферное давление на уровне моря_lag_395     109053 non-null  float64
#  45  Атмосферное давление на уровне станции_lag_335  109053 non-null  float64
#  46  Атмосферное давление на уровне станции_lag_365  109053 non-null  float64
#  47  Атмосферное давление на уровне станции_lag_395  109053 non-null  float64
#  48  year                                            109053 non-null  int64
#  49  day                                             109053 non-null  int64
#  50  day_of_year_sin                                 109053 non-null  float64
#  51  day_of_year_cos                                 109053 non-null  float64
#  52  season                                          109053 non-null  int64
#  53  month_sin                                       109053 non-null  float64
#  54  month_cos                                       109053 non-null  float64
#  55  Средняя температура воздуха_mean_group          109053 non-null  float64
#  56  temp_delta_vs_all_stations                      109053 non-null  float64
# dtypes: datetime64[ns](1), float64(52), int64(4)
# memory usage: 47.4 MB

# %% [markdown]
# ## Работа с лагами

# %% [markdown]
# ### Выбор признаков

# %%
df.shape
# Out:
# (109053, 57)

# %%
original_cols = [
    col for col in df.columns
    if not any([
        '_lag_' in col,
        '_sin' in col,
        '_cos' in col,
        '_mean' in col,
        'delta' in col,
        col in ['year', 'day', 'season', 'Индекс ВМО', 'date']
    ])
]
# original_cols

# %% [markdown]
# ### Добавление лагов

# %%
def add_lag_features(df, lag_cols, lag=1, group_col='Индекс ВМО', date_col='date'):
    """
    Добавляет лаги для указанных колонок
    df : DataFrame
    lag_cols : list - колонки, для которых делаем лаги
    lag : int - размер лага (в днях)
    """
    df = df.sort_values([group_col, date_col]).copy()

    for col in lag_cols:
        df[f'{col}_lag_{lag}'] = df.groupby(group_col)[col].shift(lag)

    return df

# %%
df_with_lags = add_lag_features(df, original_cols, lag=2)

# %%
df_with_lags.columns
# Out:
# Index(['Индекс ВМО', 'date', 'Средняя температура воздуха',
#        'Количество осадков', 'Горизонтальная дальность видимости',
#        'Общее количество облачности', 'Количество облачности нижнего яруса',
#        'Форма облаков верхнего яруса', 'Форма облаков среднего яруса',
#        'Форма облаков вертикального развития',
#        'Слоистые и слоисто_кучевые облака',
#        'Слоисто_дождразорванно_дождевые облака',
#        'Высота нижней границы облачности', 'Погода между сроками',
#        'Погода в срок наблюдения', 'Направление ветра',
#        'Средняя скорость ветра', 'Максимальная скорость ветра',
#        'Сумма осадков', 'Температура поверхности почвы',
#        'Парциальное давление водяного пара', 'Относительная влажность воздуха',
#        'Дефицит насыщения водяного пара',
#        'Атмосферное давление на уровне станции',
#        'Атмосферное давление на уровне моря',
#        'Характеристика барической тенденции', 'Величина барической тенденции',
#        'Средняя температура воздуха_lag_335',
#        'Средняя температура воздуха_lag_365',
#        'Средняя температура воздуха_lag_395',
#        'Температура поверхности почвы_lag_335',
#        'Температура поверхности почвы_lag_365',
#        'Температура поверхности почвы_lag_395',
#        'Парциальное давление водяного пара_lag_335',
#        'Парциальное давление водяного пара_lag_365',
#        'Парциальное давление водяного пара_lag_395',
#        'Относительная влажность воздуха_lag_335',
#        'Относительная влажность воздуха_lag_365',
#        'Относительная влажность воздуха_lag_395',
#        'Дефицит насыщения водяного пара_lag_335',
#        'Дефицит насыщения водяного пара_lag_365',
#        'Дефицит насыщения водяного пара_lag_395',
#        'Атмосферное давление на уровне моря_lag_335',
#        'Атмосферное давление на уровне моря_lag_365',
#        'Атмосферное давление на уровне моря_lag_395',
#        'Атмосферное давление на уровне станции_lag_335',
#        'Атмосферное давление на уровне станции_lag_365',
#        'Атмосферное давление на уровне станции_lag_395', 'year', 'day',
#        'day_of_year_sin', 'day_of_year_cos', 'season', 'month_sin',
#        'month_cos', 'Средняя температура воздуха_mean_group',
#        'temp_delta_vs_all_stations', 'Средняя температура воздуха_lag_2',
#        'Количество осадков_lag_2', 'Горизонтальная дальность видимости_lag_2',
#        'Общее количество облачности_lag_2',
#        'Количество облачности нижнего яруса_lag_2',
#        'Форма облаков верхнего яруса_lag_2',
#        'Форма облаков среднего яруса_lag_2',
#        'Форма облаков вертикального развития_lag_2',
#        'Слоистые и слоисто_кучевые облака_lag_2',
#        'Слоисто_дождразорванно_дождевые облака_lag_2',
#        'Высота нижней границы облачности_lag_2', 'Погода между сроками_lag_2',
#        'Погода в срок наблюдения_lag_2', 'Направление ветра_lag_2',
#        'Средняя скорость ветра_lag_2', 'Максимальная скорость ветра_lag_2',
#        'Сумма осадков_lag_2', 'Температура поверхности почвы_lag_2',
#        'Парциальное давление водяного пара_lag_2',
#        'Относительная влажность воздуха_lag_2',
#        'Дефицит насыщения водяного пара_lag_2',
#        'Атмосферное давление на уровне станции_lag_2',
#        'Атмосферное давление на уровне моря_lag_2',
#        'Характеристика барической тенденции_lag_2',
#        'Величина барической тенденции_lag_2'],
#       dtype='object')

# %% [markdown]
# ### Работа с пропусками

# %%
df_with_lags.isna().sum().sum()
# Out:
# np.int64(350)

# %%
df_with_lags.date.min(), df_with_lags.date.max()
# Out:
# (Timestamp('1982-01-31 00:00:00'), Timestamp('2024-09-25 00:00:00'))

# %%
# Для каждой группы находим первую дату без NaN
def first_valid_date_per_group(df, group_col='Индекс ВМО', date_col='date'):
    # Словарь: индекс ВМО - дата первой строки без NaN
    first_dates = {}

    for idx, group in df.groupby(group_col):
        # Проверяем только колонки с NaN
        valid_rows = group[~group.isna().any(axis=1)]
        if not valid_rows.empty:
            first_dates[idx] = valid_rows[date_col].iloc[0]
        else:
            first_dates[idx] = None  # если все строки пустые

    return first_dates


first_dates_dict = first_valid_date_per_group(df_with_lags)
first_dates_dict
# Out:
# {34059: Timestamp('1982-02-02 00:00:00'),
#  34152: Timestamp('1982-02-02 00:00:00'),
#  34163: Timestamp('1982-02-02 00:00:00'),
#  34172: Timestamp('1982-02-02 00:00:00'),
#  34186: Timestamp('1982-02-02 00:00:00'),
#  34289: Timestamp('1982-02-02 00:00:00'),
#  34391: Timestamp('1982-02-02 00:00:00')}

# %%
# Обрезаем каждую группу по дате
cleaned_groups = []
for idx, group in df_with_lags.groupby('Индекс ВМО'):
    start_date = first_dates_dict[idx]
    cleaned_group = group[group['date'] >= start_date]
    cleaned_groups.append(cleaned_group)

clean_lagged_df = pd.concat(cleaned_groups).reset_index(drop=True)

# %%
clean_lagged_df.date.min(), clean_lagged_df.date.max()
# Out:
# (Timestamp('1982-02-02 00:00:00'), Timestamp('2024-09-25 00:00:00'))

# %%
clean_lagged_df.isna().sum().sum()
# Out:
# np.int64(0)

# %%
df.shape, clean_lagged_df.shape
# Out:
# ((109053, 57), (109039, 82))

# %% [markdown]
# ## Удаление лишних признаков (Чтобы не было утечек)

# %% [markdown]
# Делать предсказания по предыдущим дням, а не по текущему восстанавливать

# %%
columns_for_drop = [col for col in original_cols if col != 'Средняя температура воздуха']

# %%
df_for_training = clean_lagged_df.drop(columns=columns_for_drop)

# %%
df_for_training.head()
# Out:
#    Индекс ВМО       date  Средняя температура воздуха  \
# 0       34059 1982-02-02                        -15.2
# 1       34059 1982-02-03                        -16.3
# 2       34059 1982-02-04                        -17.4
# 3       34059 1982-02-05                         -7.9
# 4       34059 1982-02-06                         -9.8
#
#    Средняя температура воздуха_lag_335  Средняя температура воздуха_lag_365  \
# 0                                 -8.9                                 -6.4
# 1                                 -3.2                                 -8.0
# 2                                 -2.3                                  0.9
# 3                                 -5.7                                 -0.7
# 4                                -11.1                                  2.4
#
#    Средняя температура воздуха_lag_395  Температура поверхности почвы_lag_335  \
# 0                                 -0.7                                -6.7500
# 1                                 -2.5                                -2.7500
# 2                                 -0.1                                -4.0000
# 3                                  0.4                                -9.6250
# 4                                 -1.8                                -6.8875
#
#    Температура поверхности почвы_lag_365  \
# 0                                -6.7500
# 1                                -7.1250
# 2                                -1.1375
# 3                                -1.3875
# 4                                 1.0000
#
#    Температура поверхности почвы_lag_395  \
# 0                                -2.0000
# 1                                -2.7500
# 2                                -0.4250
# 3                                -0.3750
# 4                                -2.0125
#
#    Парциальное давление водяного пара_lag_335  ...  \
# 0                                      3.1500  ...
# 1                                      4.9500  ...
# 2                                      4.3375  ...
# 3                                      3.0125  ...
# 4                                      3.7750  ...
#
#    Максимальная скорость ветра_lag_2  Сумма осадков_lag_2  \
# 0                             10.000                  0.0
# 1                              7.125                  0.0
# 2                              3.500                  0.0
# 3                              4.750                  0.0
# 4                              2.750                  0.0
#
#    Температура поверхности почвы_lag_2  \
# 0                              -10.750
# 1                              -12.500
# 2                              -16.750
# 3                              -17.875
# 4                              -16.125
#
#    Парциальное давление водяного пара_lag_2  \
# 0                                    2.1125
# 1                                    1.8875
# 2                                    1.3250
# 3                                    1.3750
# 4                                    1.5375
#
#    Относительная влажность воздуха_lag_2  \
# 0                                 75.375
# 1                                 77.375
# 2                                 73.125
# 3                                 79.125
# 4                                 78.875
#
#    Дефицит насыщения водяного пара_lag_2  \
# 0                                 0.7000
# 1                                 0.5625
# 2                                 0.5250
# 3                                 0.3625
# 4                                 0.3750
#
#    Атмосферное давление на уровне станции_lag_2  \
# 0                                      997.0250
# 1                                     1001.1625
# 2                                     1006.4125
# 3                                     1005.8750
# 4                                     1004.3125
#
#    Атмосферное давление на уровне моря_lag_2  \
# 0                                  1018.3125
# 1                                  1022.6250
# 2                                  1028.3000
# 3                                  1027.8500
# 4                                  1026.1750
#
#    Характеристика барической тенденции_lag_2  \
# 0                                      5.125
# 1                                      2.000
# 2                                      3.500
# 3                                      4.000
# 4                                      6.375
#
#    Величина барической тенденции_lag_2
# 0                               0.7125
# 1                               0.9750
# 2                               0.4125
# 3                               0.4875
# 4                               0.6500
#
# [5 rows x 58 columns]

# %%
df_for_training.shape
# Out:
# (109039, 58)

# %%
df_for_training.isna().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Разделение данных на тренировочную/валидационную

# %%
df_for_training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109039 entries, 0 to 109038
# Data columns (total 58 columns):
#  #   Column                                          Non-Null Count   Dtype
# ---  ------                                          --------------   -----
#  0   Индекс ВМО                                      109039 non-null  int64
#  1   date                                            109039 non-null  datetime64[ns]
#  2   Средняя температура воздуха                     109039 non-null  float64
#  3   Средняя температура воздуха_lag_335             109039 non-null  float64
#  4   Средняя температура воздуха_lag_365             109039 non-null  float64
#  5   Средняя температура воздуха_lag_395             109039 non-null  float64
#  6   Температура поверхности почвы_lag_335           109039 non-null  float64
#  7   Температура поверхности почвы_lag_365           109039 non-null  float64
#  8   Температура поверхности почвы_lag_395           109039 non-null  float64
#  9   Парциальное давление водяного пара_lag_335      109039 non-null  float64
#  10  Парциальное давление водяного пара_lag_365      109039 non-null  float64
#  11  Парциальное давление водяного пара_lag_395      109039 non-null  float64
#  12  Относительная влажность воздуха_lag_335         109039 non-null  float64
#  13  Относительная влажность воздуха_lag_365         109039 non-null  float64
#  14  Относительная влажность воздуха_lag_395         109039 non-null  float64
#  15  Дефицит насыщения водяного пара_lag_335         109039 non-null  float64
#  16  Дефицит насыщения водяного пара_lag_365         109039 non-null  float64
#  17  Дефицит насыщения водяного пара_lag_395         109039 non-null  float64
#  18  Атмосферное давление на уровне моря_lag_335     109039 non-null  float64
#  19  Атмосферное давление на уровне моря_lag_365     109039 non-null  float64
#  20  Атмосферное давление на уровне моря_lag_395     109039 non-null  float64
#  21  Атмосферное давление на уровне станции_lag_335  109039 non-null  float64
#  22  Атмосферное давление на уровне станции_lag_365  109039 non-null  float64
#  23  Атмосферное давление на уровне станции_lag_395  109039 non-null  float64
#  24  year                                            109039 non-null  int64
#  25  day                                             109039 non-null  int64
#  26  day_of_year_sin                                 109039 non-null  float64
#  27  day_of_year_cos                                 109039 non-null  float64
#  28  season                                          109039 non-null  int64
#  29  month_sin                                       109039 non-null  float64
#  30  month_cos                                       109039 non-null  float64
#  31  Средняя температура воздуха_mean_group          109039 non-null  float64
#  32  temp_delta_vs_all_stations                      109039 non-null  float64
#  33  Средняя температура воздуха_lag_2               109039 non-null  float64
#  34  Количество осадков_lag_2                        109039 non-null  float64
#  35  Горизонтальная дальность видимости_lag_2        109039 non-null  float64
#  36  Общее количество облачности_lag_2               109039 non-null  float64
#  37  Количество облачности нижнего яруса_lag_2       109039 non-null  float64
#  38  Форма облаков верхнего яруса_lag_2              109039 non-null  float64
#  39  Форма облаков среднего яруса_lag_2              109039 non-null  float64
#  40  Форма облаков вертикального развития_lag_2      109039 non-null  float64
#  41  Слоистые и слоисто_кучевые облака_lag_2         109039 non-null  float64
#  42  Слоисто_дождразорванно_дождевые облака_lag_2    109039 non-null  float64
#  43  Высота нижней границы облачности_lag_2          109039 non-null  float64
#  44  Погода между сроками_lag_2                      109039 non-null  float64
#  45  Погода в срок наблюдения_lag_2                  109039 non-null  float64
#  46  Направление ветра_lag_2                         109039 non-null  float64
#  47  Средняя скорость ветра_lag_2                    109039 non-null  float64
#  48  Максимальная скорость ветра_lag_2               109039 non-null  float64
#  49  Сумма осадков_lag_2                             109039 non-null  float64
#  50  Температура поверхности почвы_lag_2             109039 non-null  float64
#  51  Парциальное давление водяного пара_lag_2        109039 non-null  float64
#  52  Относительная влажность воздуха_lag_2           109039 non-null  float64
#  53  Дефицит насыщения водяного пара_lag_2           109039 non-null  float64
#  54  Атмосферное давление на уровне станции_lag_2    109039 non-null  float64
#  55  Атмосферное давление на уровне моря_lag_2       109039 non-null  float64
#  56  Характеристика барической тенденции_lag_2       109039 non-null  float64
#  57  Величина барической тенденции_lag_2             109039 non-null  float64
# dtypes: datetime64[ns](1), float64(53), int64(4)
# memory usage: 48.3 MB

# %%
df_for_training.date.min(), df_for_training.date.max()
# Out:
# (Timestamp('1982-02-02 00:00:00'), Timestamp('2024-09-25 00:00:00'))

# %%
val_start = df_for_training['date'].max() - pd.DateOffset(months=1)
val_start
# Out:
# Timestamp('2024-08-25 00:00:00')

# %%
# Разделяем
train_df = df_for_training[df_for_training['date'] < val_start].copy()
val_df = df_for_training[df_for_training['date'] >= val_start].copy()

print("Train shape:", train_df.shape)
print("Validation shape:", val_df.shape)
# Out:
# Train shape: (108815, 58)
# Validation shape: (224, 58)

# %%
train_df = train_df.drop(columns=['date'])
val_df_drop_date = val_df.drop(columns=['date'])

# %%
train_df.columns
# Out:
# Index(['Индекс ВМО', 'Средняя температура воздуха',
#        'Средняя температура воздуха_lag_335',
#        'Средняя температура воздуха_lag_365',
#        'Средняя температура воздуха_lag_395',
#        'Температура поверхности почвы_lag_335',
#        'Температура поверхности почвы_lag_365',
#        'Температура поверхности почвы_lag_395',
#        'Парциальное давление водяного пара_lag_335',
#        'Парциальное давление водяного пара_lag_365',
#        'Парциальное давление водяного пара_lag_395',
#        'Относительная влажность воздуха_lag_335',
#        'Относительная влажность воздуха_lag_365',
#        'Относительная влажность воздуха_lag_395',
#        'Дефицит насыщения водяного пара_lag_335',
#        'Дефицит насыщения водяного пара_lag_365',
#        'Дефицит насыщения водяного пара_lag_395',
#        'Атмосферное давление на уровне моря_lag_335',
#        'Атмосферное давление на уровне моря_lag_365',
#        'Атмосферное давление на уровне моря_lag_395',
#        'Атмосферное давление на уровне станции_lag_335',
#        'Атмосферное давление на уровне станции_lag_365',
#        'Атмосферное давление на уровне станции_lag_395', 'year', 'day',
#        'day_of_year_sin', 'day_of_year_cos', 'season', 'month_sin',
#        'month_cos', 'Средняя температура воздуха_mean_group',
#        'temp_delta_vs_all_stations', 'Средняя температура воздуха_lag_2',
#        'Количество осадков_lag_2', 'Горизонтальная дальность видимости_lag_2',
#        'Общее количество облачности_lag_2',
#        'Количество облачности нижнего яруса_lag_2',
#        'Форма облаков верхнего яруса_lag_2',
#        'Форма облаков среднего яруса_lag_2',
#        'Форма облаков вертикального развития_lag_2',
#        'Слоистые и слоисто_кучевые облака_lag_2',
#        'Слоисто_дождразорванно_дождевые облака_lag_2',
#        'Высота нижней границы облачности_lag_2', 'Погода между сроками_lag_2',
#        'Погода в срок наблюдения_lag_2', 'Направление ветра_lag_2',
#        'Средняя скорость ветра_lag_2', 'Максимальная скорость ветра_lag_2',
#        'Сумма осадков_lag_2', 'Температура поверхности почвы_lag_2',
#        'Парциальное давление водяного пара_lag_2',
#        'Относительная влажность воздуха_lag_2',
#        'Дефицит насыщения водяного пара_lag_2',
#        'Атмосферное давление на уровне станции_lag_2',
#        'Атмосферное давление на уровне моря_lag_2',
#        'Характеристика барической тенденции_lag_2',
#        'Величина барической тенденции_lag_2'],
#       dtype='object')

# %%
y_train = train_df['Средняя температура воздуха']
y_val = val_df_drop_date['Средняя температура воздуха']

# Признаки (оставляем Индекс ВМО)
X_train = train_df.drop(columns=['Средняя температура воздуха'])
X_val = val_df_drop_date.drop(columns=['Средняя температура воздуха'])

print("Train shape:", X_train.shape, y_train.shape)
print("Validation shape:", X_val.shape, y_val.shape)
# Out:
# Train shape: (108815, 56) (108815,)
# Validation shape: (224, 56) (224,)

# %%
print(X_train.isna().sum().sum())
print(y_train.isna().sum().sum())
print('Валидационное:')
print(X_val.isna().sum().sum())
print(y_val.isna().sum().sum())
# Out:
# 0
# 0
# Валидационное:
# 0
# 0

# %%
X_train.columns
# Out:
# Index(['Индекс ВМО', 'Средняя температура воздуха_lag_335',
#        'Средняя температура воздуха_lag_365',
#        'Средняя температура воздуха_lag_395',
#        'Температура поверхности почвы_lag_335',
#        'Температура поверхности почвы_lag_365',
#        'Температура поверхности почвы_lag_395',
#        'Парциальное давление водяного пара_lag_335',
#        'Парциальное давление водяного пара_lag_365',
#        'Парциальное давление водяного пара_lag_395',
#        'Относительная влажность воздуха_lag_335',
#        'Относительная влажность воздуха_lag_365',
#        'Относительная влажность воздуха_lag_395',
#        'Дефицит насыщения водяного пара_lag_335',
#        'Дефицит насыщения водяного пара_lag_365',
#        'Дефицит насыщения водяного пара_lag_395',
#        'Атмосферное давление на уровне моря_lag_335',
#        'Атмосферное давление на уровне моря_lag_365',
#        'Атмосферное давление на уровне моря_lag_395',
#        'Атмосферное давление на уровне станции_lag_335',
#        'Атмосферное давление на уровне станции_lag_365',
#        'Атмосферное давление на уровне станции_lag_395', 'year', 'day',
#        'day_of_year_sin', 'day_of_year_cos', 'season', 'month_sin',
#        'month_cos', 'Средняя температура воздуха_mean_group',
#        'temp_delta_vs_all_stations', 'Средняя температура воздуха_lag_2',
#        'Количество осадков_lag_2', 'Горизонтальная дальность видимости_lag_2',
#        'Общее количество облачности_lag_2',
#        'Количество облачности нижнего яруса_lag_2',
#        'Форма облаков верхнего яруса_lag_2',
#        'Форма облаков среднего яруса_lag_2',
#        'Форма облаков вертикального развития_lag_2',
#        'Слоистые и слоисто_кучевые облака_lag_2',
#        'Слоисто_дождразорванно_дождевые облака_lag_2',
#        'Высота нижней границы облачности_lag_2', 'Погода между сроками_lag_2',
#        'Погода в срок наблюдения_lag_2', 'Направление ветра_lag_2',
#        'Средняя скорость ветра_lag_2', 'Максимальная скорость ветра_lag_2',
#        'Сумма осадков_lag_2', 'Температура поверхности почвы_lag_2',
#        'Парциальное давление водяного пара_lag_2',
#        'Относительная влажность воздуха_lag_2',
#        'Дефицит насыщения водяного пара_lag_2',
#        'Атмосферное давление на уровне станции_lag_2',
#        'Атмосферное давление на уровне моря_lag_2',
#        'Характеристика барической тенденции_lag_2',
#        'Величина барической тенденции_lag_2'],
#       dtype='object')

# %% [markdown]
# ## Функции оценки точности

# %% [markdown]
# ### Стандартные методы

# %%
def simple_metric(y_val, y_pred):
    mae = mean_absolute_error(y_val, y_pred)
    mse = mean_squared_error(y_val, y_pred)
    rmse = np.sqrt(mse)
    mape = np.mean(np.abs((y_val - y_pred) / y_val)) * 100
    r2 = r2_score(y_val, y_pred)

    print("Простые метрики:")
    print(f"MAE: {mae:.4f}")
    print(f"MSE: {mse:.4f}")
    print(f"RMSE: {rmse:.4f}")
    print(f"MAPE: {mape:.2f}%")
    print(f"R²: {r2:.4f}")
    return {
        'MAE': mae,
        'MSE': mse,
        'RMSE': rmse,
        'MAPE': mape,
        'R2': r2
    }

# %% [markdown]
# ### Ошибки по дням

# %%
def daily_metrics(df_val, y_pred, date_col='date',
                  y_true_col='Средняя температура воздуха', y_pred_col='prediction'):
    df_val['prediction'] = y_pred
    results = []

    for date, group in df_val.groupby(date_col):
        y_true = group[y_true_col].values
        y_pred = group[y_pred_col].values

        mae = mean_absolute_error(y_true, y_pred)
        rmse = np.sqrt(mean_squared_error(y_true, y_pred))
        r2 = r2_score(y_true, y_pred)

        results.append({
            'date': date,
            'MAE': mae,
            'RMSE': rmse,
            'R2': r2
        })

    return pd.DataFrame(results).sort_values('date')

# %% [markdown]
# ### Столбчатые диаграммы ошибок по индексам

# %%
def metrics_per_index(df_val, y_pred, index_col='Индекс ВМО',
                      y_true_col='Средняя температура воздуха', y_pred_col='prediction'):
    """
    df_val: DataFrame с колонками y_true и индекс
    y_pred: массив предсказаний
    """
    df_val = df_val.copy()
    df_val[y_pred_col] = y_pred

    metrics_list = []

    for idx, group in df_val.groupby(index_col):
        y_true = group[y_true_col].values
        y_p = group[y_pred_col].values

        mae = mean_absolute_error(y_true, y_p)
        rmse = np.sqrt(mean_squared_error(y_true, y_p))
        r2 = r2_score(y_true, y_p)

        metrics_list.append({
            index_col: idx,
            'MAE': mae,
            'RMSE': rmse,
            'R2': r2
        })

    metrics_df = pd.DataFrame(metrics_list).sort_values(index_col)

    # Строим графики
    fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharex=True)

    axes[0].bar(metrics_df[index_col].astype(str), metrics_df['MAE'], color='skyblue')
    axes[0].set_title('MAE по индексам')
    axes[0].set_ylabel('MAE (°C)')

    axes[1].bar(metrics_df[index_col].astype(str), metrics_df['RMSE'], color='salmon')
    axes[1].set_title('RMSE по индексам')
    axes[1].set_ylabel('RMSE (°C)')

    axes[2].bar(metrics_df[index_col].astype(str), metrics_df['R2'], color='lightgreen')
    axes[2].set_title('R² по индексам')
    axes[2].set_ylabel('R²')

    for ax in axes:
        ax.set_xlabel('Индекс ВМО')
        ax.tick_params(axis='x', rotation=45)

    plt.tight_layout()
    plt.show()

    return metrics_df

# %% [markdown]
# ### Линейный график MAE

# %%
def cumulative_mae(df_val, y_pred, date_col='date',
                   y_true_col='Средняя температура воздуха', y_pred_col='prediction'):
    """
    df_val: DataFrame с колонками y_true и date
    y_pred: массив предсказаний
    """
    df_val = df_val.copy()
    df_val[y_pred_col] = y_pred

    # Сортируем по дате
    df_val = df_val.sort_values(date_col)

    # Копим MAE по дням
    cum_errors = []
    all_true = []
    all_pred = []

    for date, group in df_val.groupby(date_col):
        all_true.extend(group[y_true_col].values)
        all_pred.extend(group[y_pred_col].values)

        mae = mean_absolute_error(all_true, all_pred)
        cum_errors.append({'date': date, 'Cumulative_MAE': mae})

    cum_df = pd.DataFrame(cum_errors)

    # График
    plt.figure(figsize=(12, 5))
    plt.plot(cum_df['date'], cum_df['Cumulative_MAE'], marker='o', linestyle='-')
    plt.xlabel('Дата')
    plt.ylabel('MAE (°C)')
    plt.title('MAE по дням')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.show()

    return cum_df

# %% [markdown]
# ### Накопление ошибки Mae

# %%
def cumulative_error(df_val, y_pred, date_col='date',
                     y_true_col='Средняя температура воздуха', y_pred_col='prediction'):
    df_val = df_val.copy()
    df_val[y_pred_col] = y_pred

    df_val = df_val.sort_values(date_col)

    cum_errors = []
    total_error = 0

    for date, group in df_val.groupby(date_col):
        daily_error = (group[y_true_col] - group[y_pred_col]).abs().sum()
        total_error += daily_error

        cum_errors.append({'date': date, 'Cumulative_Error': total_error})

    cum_df = pd.DataFrame(cum_errors)

    # График
    plt.figure(figsize=(12, 5))
    plt.plot(cum_df['date'], cum_df['Cumulative_Error'], marker='o')
    plt.xlabel('Дата')
    plt.ylabel('Накопленная ошибка')
    plt.title('Накопление абсолютной ошибки по дням')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.show()

    return cum_df

# %% [markdown]
# ### Сравнения истинной средней и предсказанной средней

# %%
def plot_true_vs_pred(df_val, y_pred, date_col='date', y_true_col='Средняя температура воздуха'):
    df_plot = df_val.copy()
    df_plot['prediction'] = y_pred

    # Усредняем по индексам
    daily_true = df_plot.groupby(date_col)[y_true_col].mean()
    daily_pred = df_plot.groupby(date_col)['prediction'].mean()

    plt.figure(figsize=(12, 6))
    plt.plot(daily_true.index, daily_true.values, label='Истинная температура', marker='o', linestyle='-', color='blue')
    plt.plot(daily_pred.index, daily_pred.values, label='Предсказанная температура', marker='x', linestyle='--',
             color='orange')
    plt.xlabel('Дата')
    plt.ylabel('Температура (°C)')
    plt.title('Сравнение истинной и предсказанной температуры')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Сравнение истинной и предсказанной по индексам

# %%
def plot_true_vs_pred_by_index(df_val, y_pred, date_col='date', index_col='Индекс ВМО',
                               y_true_col='Средняя температура воздуха'):
    df_plot = df_val.copy()
    df_plot['prediction'] = y_pred

    indices = df_plot[index_col].unique()
    n_indices = len(indices)

    # Определяем размер подграфиков (по 2 в ряду)
    n_cols = 2
    n_rows = (n_indices + 1) // n_cols

    fig, axes = plt.subplots(n_rows, n_cols, figsize=(14, n_rows * 3), sharex=True, sharey=True)
    axes = axes.flatten()

    for i, idx in enumerate(indices):
        ax = axes[i]
        df_idx = df_plot[df_plot[index_col] == idx]
        ax.plot(df_idx[date_col], df_idx[y_true_col], label='Истинная', marker='o', linestyle='-', color='blue')
        ax.plot(df_idx[date_col], df_idx['prediction'], label='Предсказанная', marker='x', linestyle='--',
                color='orange')
        ax.set_title(f'Индекс ВМО: {idx}')
        ax.grid(True, linestyle='--', alpha=0.5)
        if i % n_cols == 0:
            ax.set_ylabel('Температура (°C)')
        ax.legend(fontsize=8)

    # Скрываем лишние пустые графики
    for j in range(i + 1, len(axes)):
        axes[j].axis('off')

    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Предсказательные модели

# %% [markdown]
# ### XGBRegressor

# %%
# Создаем DMatrix для XGBoost
dtrain = xgb.DMatrix(X_train, label=y_train)
dval = xgb.DMatrix(X_val, label=y_val)

# Параметры модели
params = {
    'objective': 'reg:squarederror',  # регрессия
    'eval_metric': 'rmse',
    'eta': 0.1,  # learning rate
    'max_depth': 6,  # глубина деревьев
    'subsample': 0.8,  # случайная подвыборка для предотвращения переобучения
    'colsample_bytree': 0.8,
    'seed': 42
}

# Обучение с ранней остановкой
evals = [(dtrain, 'train'), (dval, 'validation')]
xgb_model = xgb.train(
    params,
    dtrain,
    num_boost_round=500,
    evals=evals,
    early_stopping_rounds=20,
    verbose_eval=50
)

# Предсказание на валидации
y_pred = xgb_model.predict(dval)
xgb_result = simple_metric(y_val, y_pred)
xgb_result
# Out:
# [0]	train-rmse:11.49640	validation-rmse:11.17855
# [50]	train-rmse:3.29935	validation-rmse:2.23050
# [100]	train-rmse:3.09738	validation-rmse:2.21608
# [148]	train-rmse:2.95050	validation-rmse:2.20916
# Простые метрики:
# MAE: 1.7098
# MSE: 4.8804
# RMSE: 2.2092
# MAPE: 10.47%
# R²: 0.6339
# {'MAE': 1.709765103033611,
#  'MSE': 4.880394124299201,
#  'RMSE': np.float64(2.209161407480042),
#  'MAPE': np.float64(10.47318389441514),
#  'R2': 0.6338500879399538}

# %% [markdown]
# ### LightGBM

# %%
train_data = lgb.Dataset(X_train, label=y_train)
val_data = lgb.Dataset(X_val, label=y_val)

# Параметры (максимально близко к XGBoost)
params = {
    'objective': 'regression',  # аналог reg:squarederror
    'metric': 'rmse',
    'learning_rate': 0.1,  # eta
    'max_depth': 6,
    'feature_fraction': 0.8,  # colsample_bytree
    'bagging_fraction': 0.8,  # subsample
    'bagging_freq': 1,
    'seed': 42,
    'verbosity': -1
}

# Обучение с early stopping
model = lgb.train(
    params,
    train_data,
    num_boost_round=500,
    valid_sets=[train_data, val_data],
    valid_names=['train', 'validation'],
    callbacks=[
        lgb.early_stopping(stopping_rounds=20),
        lgb.log_evaluation(period=50)
    ]
)

# Предсказание
y_pred = model.predict(X_val, num_iteration=model.best_iteration)

# Метрика
lgb_result = simple_metric(y_val, y_pred)
lgb_result
# Out:
# Training until validation scores don't improve for 20 rounds
# [50]	train's rmse: 3.40394	validation's rmse: 2.29997
# Early stopping, best iteration is:
# [31]	train's rmse: 3.54751	validation's rmse: 2.25299
# Простые метрики:
# MAE: 1.7335
# MSE: 5.0760
# RMSE: 2.2530
# MAPE: 10.62%
# R²: 0.6192
# {'MAE': 1.7334842874862069,
#  'MSE': 5.075983207540143,
#  'RMSE': np.float64(2.252994275967017),
#  'MAPE': np.float64(10.61895277792171),
#  'R2': 0.6191760833811806}

# %% [markdown]
# ### HistGradientBoostingRegressor

# %%
model = HistGradientBoostingRegressor(
    loss='squared_error',
    learning_rate=0.1,
    max_depth=6,
    max_iter=500,
    max_bins=255,
    early_stopping=True,
    n_iter_no_change=20,
    validation_fraction=0.2,  # ← ВАЖНО
    random_state=42,
    verbose=1
)

model.fit(X_train, y_train)

y_pred = model.predict(X_val)

hist_result = simple_metric(y_val, y_pred)
hist_result
# Out:
# Binning 0.039 GB of training data: 0.209 s
# Binning 0.010 GB of validation data: 0.050 s
# Fitting gradient boosted rounds:
# Fit 500 trees in 23.266 s, (15487 total leaves)
# Time spent computing histograms: 9.287s
# Time spent finding best splits:  4.506s
# Time spent applying splits:      6.511s
# Time spent predicting:           0.266s
# Простые метрики:
# MAE: 1.7591
# MSE: 5.2761
# RMSE: 2.2970
# MAPE: 10.89%
# R²: 0.6042
# {'MAE': 1.7591436746687583,
#  'MSE': 5.276111461831105,
#  'RMSE': np.float64(2.2969787682586675),
#  'MAPE': np.float64(10.892118730370795),
#  'R2': 0.6041615290556346}

# %% [markdown]
# ### CatBoostRegressor

# %%
# Модель (параметры максимально близки к XGBoost)
model = CatBoostRegressor(
    loss_function='RMSE',
    learning_rate=0.1,
    depth=6,
    iterations=500,
    subsample=0.8,
    rsm=0.8,
    random_seed=42,
    verbose=50
)

# Обучение с early stopping
model.fit(
    X_train, y_train,
    eval_set=(X_val, y_val),
    early_stopping_rounds=20,
    use_best_model=True
)

# Предсказание
y_pred = model.predict(X_val)

# Метрика
cat_result = simple_metric(y_val, y_pred)
cat_result
# Out:
# 0:	learn: 11.5577321	test: 11.5305604	best: 11.5305604 (0)	total: 24.2ms	remaining: 12.1s
# 50:	learn: 3.6032907	test: 2.2902697	best: 2.2782976 (39)	total: 1.23s	remaining: 10.8s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 2.278297641
# bestIteration = 39
#
# Shrink model to first 40 iterations.
# Простые метрики:
# MAE: 1.7511
# MSE: 5.1906
# RMSE: 2.2783
# MAPE: 10.51%
# R²: 0.6106
# {'MAE': 1.751052197152362,
#  'MSE': 5.190640176414003,
#  'RMSE': np.float64(2.2782976487750677),
#  'MAPE': np.float64(10.514750640502035),
#  'R2': 0.6105739832226686}

# %% [markdown]
# ## Результаты

# %%
results = []

if 'xgb_result' in globals():
    results.append({'model': 'XGBoost', **xgb_result})

if 'lgb_result' in globals():
    results.append({'model': 'LightGBM', **lgb_result})

if 'hist_result' in globals():
    results.append({'model': 'HistGB', **hist_result})

if 'cat_result' in globals():
    results.append({'model': 'CatBoost', **cat_result})


df_results = pd.DataFrame(results)
df_results = df_results.sort_values(by='MAE').reset_index(drop=True)

df_results
# Out:
#       model       MAE       MSE      RMSE       MAPE        R2
# 0   XGBoost  1.709765  4.880394  2.209161  10.473184  0.633850
# 1  LightGBM  1.733484  5.075983  2.252994  10.618953  0.619176
# 2  CatBoost  1.751052  5.190640  2.278298  10.514751  0.610574
# 3    HistGB  1.759144  5.276111  2.296979  10.892119  0.604162

# %% [markdown]
# ## Подбор параметров

# %%
param_grid = {
    'eta': [0.03, 0.05, 0.1],
    'max_depth': [4, 6, 8],
    'min_child_weight': [1, 5],
    'subsample': [0.7, 0.8],
    'colsample_bytree': [0.7, 0.8],
    'gamma': [0, 0.1]
}

keys, values = zip(*param_grid.items())
param_combinations = [dict(zip(keys, v)) for v in itertools.product(*values)]

best_score = float('inf')
best_params = None
best_model = None

for i, params_update in enumerate(param_combinations):
    print(f"\n🔹 Iteration {i+1}/{len(param_combinations)}")

    params = {
        'objective': 'reg:squarederror',
        'eval_metric': 'rmse',
        'seed': 42,
        **params_update
    }

    evals = [(dtrain, 'train'), (dval, 'validation')]

    model = xgb.train(
        params,
        dtrain,
        num_boost_round=500,
        evals=evals,
        early_stopping_rounds=20,
        verbose_eval=False
    )

    y_pred = model.predict(dval, iteration_range=(0, model.best_iteration))
    score = simple_metric(y_val, y_pred)['MAE']

    print(f"Score: {score}")
    print(f"Params: {params_update}")

    if score < best_score:
        best_score = score
        best_params = params
        best_model = model

print("\nBEST RESULT")
print("Score:", best_score)
print("Params:", best_params)
# Out:
# 🔹 Iteration 1/144
# Простые метрики:
# MAE: 1.7675
# MSE: 5.2516
# RMSE: 2.2916
# MAPE: 10.79%
# R²: 0.6060
# Score: 1.7674636815275464
# Params: {'eta': 0.03, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0}
#
# 🔹 Iteration 2/144
# Простые метрики:
# MAE: 1.7675
# MSE: 5.2516
# RMSE: 2.2916
# MAPE: 10.79%
# R²: 0.6060
# Score: 1.7674636815275464
# Params: {'eta': 0.03, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.1}
#
# 🔹 Iteration 3/144
# Простые метрики:
# MAE: 1.7833
# MSE: 5.2983
# RMSE: 2.3018
# MAPE: 10.90%
# R²: 0.6025
# Score: 1.7832500117165702
# Params: {'eta': 0.03, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.8, 'gamma': 0}
#
# 🔹 Iteration 4/144
# Простые метрики:
# MAE: 1.7833
# MSE: 5.2983
# RMSE: 2.3018
# MAPE: 10.90%
# R²: 0.6025
# Score: 1.7832500117165702
# Params: {'eta': 0.03, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.8, 'gamma': 0.1}
#
# 🔹 Iteration 5/144
# Простые метрики:
# MAE: 1.7597
# MSE: 5.1949
# RMSE: 2.2792
# MAPE: 10.76%
# R²: 0.6103
# Score: 1.7596514565604073
# Params: {'eta': 0.03, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.7, 'gamma': 0}
#
# 🔹 Iteration 6/144
# Простые метрики:
# MAE: 1.7597
# MSE: 5.1949
# RMSE: 2.2792
# MAPE: 10.76%
# R²: 0.6103
# Score: 1.7596514565604073
# Params: {'eta': 0.03, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.7, 'gamma': 0.1}
#
# 🔹 Iteration 7/144
# Простые метрики:
# MAE: 1.7733
# MSE: 5.2404
# RMSE: 2.2892
# MAPE: 10.81%
# R²: 0.6068
# Score: 1.7732647606304714
# Params: {'eta': 0.03, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0}
#
# 🔹 Iteration 8/144
# Простые метрики:
# MAE: 1.7733
# MSE: 5.2404
# RMSE: 2.2892
# MAPE: 10.81%
# R²: 0.6068
# Score: 1.7732647606304714
# Params: {'eta': 0.03, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0.1}
#
# 🔹 Iteration 9/144
# Простые метрики:
# MAE: 1.7675
# MSE: 5.2516
# RMSE: 2.2916
# MAPE: 10.79%
# R²: 0.6060
# Score: 1.7674636815275464
# Params: {'eta': 0.03, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0}
#
# 🔹 Iteration 10/144
# Простые метрики:
# MAE: 1.7675
# MSE: 5.2516
# RMSE: 2.2916
# MAPE: 10.79%
# R²: 0.6060
# Score: 1.7674636815275464
# Params: {'eta': 0.03, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.1}
#
# 🔹 Iteration 11/144
# Простые метрики:
# MAE: 1.7833
# MSE: 5.2983
# RMSE: 2.3018
# MAPE: 10.90%
# R²: 0.6025
# Score: 1.7832500117165702
# Params: {'eta': 0.03, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.8, 'gamma': 0}
#
# 🔹 Iteration 12/144
# Простые метрики:
# MAE: 1.7833
# MSE: 5.2983
# RMSE: 2.3018
# MAPE: 10.90%
# R²: 0.6025
# Score: 1.7832500117165702
# Params: {'eta': 0.03, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.8, 'gamma': 0.1}
#
# 🔹 Iteration 13/144
# Простые метрики:
# MAE: 1.7597
# MSE: 5.1949
# RMSE: 2.2792
# MAPE: 10.76%
# R²: 0.6103
# Score: 1.7596514565604073
# Params: {'eta': 0.03, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.7, 'gamma': 0}
#
# 🔹 Iteration 14/144
# Простые метрики:
# MAE: 1.7597
# MSE: 5.1949
# RMSE: 2.2792
# MAPE: 10.76%
# R²: 0.6103
# Score: 1.7596514565604073
# Params: {'eta': 0.03, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.7, 'gamma': 0.1}
#
# 🔹 Iteration 15/144
# Простые метрики:
# MAE: 1.7733
# MSE: 5.2404
# RMSE: 2.2892
# MAPE: 10.81%
# R²: 0.6068
# Score: 1.7732647606304714
# Params: {'eta': 0.03, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0}
#
# 🔹 Iteration 16/144
# Простые метрики:
# MAE: 1.7733
# MSE: 5.2404
# RMSE: 2.2892
# MAPE: 10.81%
# R²: 0.6068
# Score: 1.7732647606304714
# Params: {'eta': 0.03, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0.1}
#
# 🔹 Iteration 17/144
# Простые метрики:
# MAE: 1.7269
# MSE: 4.9355
# RMSE: 2.2216
# MAPE: 10.38%
# R²: 0.6297
# Score: 1.7268761353833335
# Params: {'eta': 0.03, 'max_depth': 6, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0}
#
# 🔹 Iteration 18/144
# Простые метрики:
# MAE: 1.7269
# MSE: 4.9355
# RMSE: 2.2216
# MAPE: 10.38%
# R²: 0.6297
# Score: 1.7268761353833335
# Params: {'eta': 0.03, 'max_depth': 6, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.1}
#
# 🔹 Iteration 19/144
# Простые метрики:
# MAE: 1.7143
# MSE: 4.9071
# RMSE: 2.2152
# MAPE: 10.40%
# R²: 0.6318
# Score: 1.7142573697226386
# Params: {'eta': 0.03, 'max_depth': 6, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.8, 'gamma': 0}
#
# 🔹 Iteration 20/144
# Простые метрики:
# MAE: 1.7143
# MSE: 4.9071
# RMSE: 2.2152
# MAPE: 10.40%
# R²: 0.6318
# Score: 1.7142573697226386
# Params: {'eta': 0.03, 'max_depth': 6, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.8, 'gamma': 0.1}
#
# 🔹 Iteration 21/144
# Простые метрики:
# MAE: 1.7459
# MSE: 5.0224
# RMSE: 2.2411
# MAPE: 10.50%
# R²: 0.6232
# Score: 1.7459178166730065
# Params: {'eta': 0.03, 'max_depth': 6, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.7, 'gamma': 0}
#
# 🔹 Iteration 22/144
# Простые метрики:
# MAE: 1.7459
# MSE: 5.0224
# RMSE: 2.2411
# MAPE: 10.50%
# R²: 0.6232
# Score: 1.7459177017211915
# Params: {'eta': 0.03, 'max_depth': 6, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.7, 'gamma': 0.1}
#
# 🔹 Iteration 23/144
# Простые метрики:
# MAE: 1.7096
# MSE: 4.9018
# RMSE: 2.2140
# MAPE: 10.34%
# R²: 0.6322
# Score: 1.709622893163136
# Params: {'eta': 0.03, 'max_depth': 6, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0}
#
# 🔹 Iteration 24/144
# Простые метрики:
# MAE: 1.7096
# MSE: 4.9018
# RMSE: 2.2140
# MAPE: 10.34%
# R²: 0.6322
# Score: 1.709622893163136
# Params: {'eta': 0.03, 'max_depth': 6, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0.1}
#
# 🔹 Iteration 25/144
# Простые метрики:
# MAE: 1.7230
# MSE: 4.9239
# RMSE: 2.2190
# MAPE: 10.40%
# R²: 0.6306
# Score: 1.7229667357036047
# Params: {'eta': 0.03, 'max_depth': 6, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0}
#
# 🔹 Iteration 26/144
# Простые метрики:
# MAE: 1.7230
# MSE: 4.9239
# RMSE: 2.2190
# MAPE: 10.40%
# R²: 0.6306
# Score: 1.7229667357036047
# Params: {'eta': 0.03, 'max_depth': 6, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.1}
#
# 🔹 Iteration 27/144
# Простые метрики:
# MAE: 1.7311
# MSE: 4.9622
# RMSE: 2.2276
# MAPE: 10.45%
# R²: 0.6277
# Score: 1.7310679376125335
# Params: {'eta': 0.03, 'max_depth': 6, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.8, 'gamma': 0}
#
# 🔹 Iteration 28/144
# Простые метрики:
# MAE: 1.7311
# MSE: 4.9622
# RMSE: 2.2276
# MAPE: 10.45%
# R²: 0.6277
# Score: 1.7310679376125335
# Params: {'eta': 0.03, 'max_depth': 6, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.8, 'gamma': 0.1}
#
# 🔹 Iteration 29/144
# Простые метрики:
# MAE: 1.7390
# MSE: 4.9960
# RMSE: 2.2352
# MAPE: 10.54%
# R²: 0.6252
# Score: 1.7390140090669903
# Params: {'eta': 0.03, 'max_depth': 6, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.7, 'gamma': 0}
#
# 🔹 Iteration 30/144
# Простые метрики:
# MAE: 1.7390
# MSE: 4.9960
# RMSE: 2.2352
# MAPE: 10.54%
# R²: 0.6252
# Score: 1.7390140090669903
# Params: {'eta': 0.03, 'max_depth': 6, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.7, 'gamma': 0.1}
#
# 🔹 Iteration 31/144
# Простые метрики:
# MAE: 1.7085
# MSE: 4.9029
# RMSE: 2.2143
# MAPE: 10.31%
# R²: 0.6322
# Score: 1.7084977294717516
# Params: {'eta': 0.03, 'max_depth': 6, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0}
#
# 🔹 Iteration 32/144
# Простые метрики:
# MAE: 1.7085
# MSE: 4.9029
# RMSE: 2.2143
# MAPE: 10.31%
# R²: 0.6322
# Score: 1.7084977294717516
# Params: {'eta': 0.03, 'max_depth': 6, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0.1}
#
# 🔹 Iteration 33/144
# Простые метрики:
# MAE: 1.7158
# MSE: 5.0297
# RMSE: 2.2427
# MAPE: 10.32%
# R²: 0.6226
# Score: 1.7158367174012323
# Params: {'eta': 0.03, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0}
#
# 🔹 Iteration 34/144
# Простые метрики:
# MAE: 1.7232
# MSE: 5.0564
# RMSE: 2.2486
# MAPE: 10.40%
# R²: 0.6206
# Score: 1.723171833583287
# Params: {'eta': 0.03, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.1}
#
# 🔹 Iteration 35/144
# Простые метрики:
# MAE: 1.6576
# MSE: 4.7524
# RMSE: 2.1800
# MAPE: 9.85%
# R²: 0.6434
# Score: 1.6576279163360594
# Params: {'eta': 0.03, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.8, 'gamma': 0}
#
# 🔹 Iteration 36/144
# Простые метрики:
# MAE: 1.6576
# MSE: 4.7524
# RMSE: 2.1800
# MAPE: 9.85%
# R²: 0.6434
# Score: 1.6576278695038387
# Params: {'eta': 0.03, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.8, 'gamma': 0.1}
#
# 🔹 Iteration 37/144
# Простые метрики:
# MAE: 1.7051
# MSE: 4.9323
# RMSE: 2.2209
# MAPE: 10.19%
# R²: 0.6300
# Score: 1.7050515013081688
# Params: {'eta': 0.03, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.7, 'gamma': 0}
#
# 🔹 Iteration 38/144
# Простые метрики:
# MAE: 1.7072
# MSE: 4.9453
# RMSE: 2.2238
# MAPE: 10.20%
# R²: 0.6290
# Score: 1.707221485887255
# Params: {'eta': 0.03, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.7, 'gamma': 0.1}
#
# 🔹 Iteration 39/144
# Простые метрики:
# MAE: 1.7288
# MSE: 5.0332
# RMSE: 2.2435
# MAPE: 10.27%
# R²: 0.6224
# Score: 1.7288082557065148
# Params: {'eta': 0.03, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0}
#
# 🔹 Iteration 40/144
# Простые метрики:
# MAE: 1.7288
# MSE: 5.0332
# RMSE: 2.2435
# MAPE: 10.27%
# R²: 0.6224
# Score: 1.7288094477994103
# Params: {'eta': 0.03, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0.1}
#
# 🔹 Iteration 41/144
# Простые метрики:
# MAE: 1.7087
# MSE: 4.9689
# RMSE: 2.2291
# MAPE: 10.35%
# R²: 0.6272
# Score: 1.7087498222078596
# Params: {'eta': 0.03, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0}
#
# 🔹 Iteration 42/144
# Простые метрики:
# MAE: 1.7087
# MSE: 4.9689
# RMSE: 2.2291
# MAPE: 10.35%
# R²: 0.6272
# Score: 1.7087493325982774
# Params: {'eta': 0.03, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.1}
#
# 🔹 Iteration 43/144
# Простые метрики:
# MAE: 1.6996
# MSE: 4.9553
# RMSE: 2.2261
# MAPE: 10.15%
# R²: 0.6282
# Score: 1.6995604114873069
# Params: {'eta': 0.03, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.8, 'gamma': 0}
#
# 🔹 Iteration 44/144
# Простые метрики:
# MAE: 1.7076
# MSE: 4.9597
# RMSE: 2.2270
# MAPE: 10.17%
# R²: 0.6279
# Score: 1.7076377051217215
# Params: {'eta': 0.03, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.8, 'gamma': 0.1}
#
# 🔹 Iteration 45/144
# Простые метрики:
# MAE: 1.6953
# MSE: 4.9802
# RMSE: 2.2316
# MAPE: 10.26%
# R²: 0.6264
# Score: 1.6952758397374836
# Params: {'eta': 0.03, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.7, 'gamma': 0}
#
# 🔹 Iteration 46/144
# Простые метрики:
# MAE: 1.6953
# MSE: 4.9802
# RMSE: 2.2316
# MAPE: 10.26%
# R²: 0.6264
# Score: 1.6952758269650599
# Params: {'eta': 0.03, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.7, 'gamma': 0.1}
#
# 🔹 Iteration 47/144
# Простые метрики:
# MAE: 1.7298
# MSE: 5.0671
# RMSE: 2.2510
# MAPE: 10.44%
# R²: 0.6198
# Score: 1.7297803631850652
# Params: {'eta': 0.03, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0}
#
# 🔹 Iteration 48/144
# Простые метрики:
# MAE: 1.7369
# MSE: 5.0476
# RMSE: 2.2467
# MAPE: 10.28%
# R²: 0.6213
# Score: 1.7369214824267796
# Params: {'eta': 0.03, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0.1}
#
# 🔹 Iteration 49/144
# Простые метрики:
# MAE: 1.7701
# MSE: 5.3443
# RMSE: 2.3118
# MAPE: 10.86%
# R²: 0.5990
# Score: 1.7701183310576847
# Params: {'eta': 0.05, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0}
#
# 🔹 Iteration 50/144
# Простые метрики:
# MAE: 1.7701
# MSE: 5.3443
# RMSE: 2.3118
# MAPE: 10.86%
# R²: 0.5990
# Score: 1.7701183310576847
# Params: {'eta': 0.05, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.1}
#
# 🔹 Iteration 51/144
# Простые метрики:
# MAE: 1.7804
# MSE: 5.3354
# RMSE: 2.3098
# MAPE: 10.86%
# R²: 0.5997
# Score: 1.780448442697525
# Params: {'eta': 0.05, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.8, 'gamma': 0}
#
# 🔹 Iteration 52/144
# Простые метрики:
# MAE: 1.7804
# MSE: 5.3354
# RMSE: 2.3098
# MAPE: 10.86%
# R²: 0.5997
# Score: 1.780448442697525
# Params: {'eta': 0.05, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.8, 'gamma': 0.1}
#
# 🔹 Iteration 53/144
# Простые метрики:
# MAE: 1.7686
# MSE: 5.3126
# RMSE: 2.3049
# MAPE: 10.83%
# R²: 0.6014
# Score: 1.768560859986714
# Params: {'eta': 0.05, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.7, 'gamma': 0}
#
# 🔹 Iteration 54/144
# Простые метрики:
# MAE: 1.7686
# MSE: 5.3126
# RMSE: 2.3049
# MAPE: 10.83%
# R²: 0.6014
# Score: 1.768560859986714
# Params: {'eta': 0.05, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.7, 'gamma': 0.1}
#
# 🔹 Iteration 55/144
# Простые метрики:
# MAE: 1.7858
# MSE: 5.2796
# RMSE: 2.2977
# MAPE: 10.89%
# R²: 0.6039
# Score: 1.7857906171253748
# Params: {'eta': 0.05, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0}
#
# 🔹 Iteration 56/144
# Простые метрики:
# MAE: 1.7858
# MSE: 5.2796
# RMSE: 2.2977
# MAPE: 10.89%
# R²: 0.6039
# Score: 1.7857906171253748
# Params: {'eta': 0.05, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0.1}
#
# 🔹 Iteration 57/144
# Простые метрики:
# MAE: 1.7701
# MSE: 5.3443
# RMSE: 2.3118
# MAPE: 10.86%
# R²: 0.5990
# Score: 1.7701182586806161
# Params: {'eta': 0.05, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0}
#
# 🔹 Iteration 58/144
# Простые метрики:
# MAE: 1.7701
# MSE: 5.3443
# RMSE: 2.3118
# MAPE: 10.86%
# R²: 0.5990
# Score: 1.7701182586806161
# Params: {'eta': 0.05, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.1}
#
# 🔹 Iteration 59/144
# Простые метрики:
# MAE: 1.7804
# MSE: 5.3354
# RMSE: 2.3098
# MAPE: 10.86%
# R²: 0.5997
# Score: 1.780448442697525
# Params: {'eta': 0.05, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.8, 'gamma': 0}
#
# 🔹 Iteration 60/144
# Простые метрики:
# MAE: 1.7804
# MSE: 5.3354
# RMSE: 2.3098
# MAPE: 10.86%
# R²: 0.5997
# Score: 1.780448442697525
# Params: {'eta': 0.05, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.8, 'gamma': 0.1}
#
# 🔹 Iteration 61/144
# Простые метрики:
# MAE: 1.7686
# MSE: 5.3126
# RMSE: 2.3049
# MAPE: 10.83%
# R²: 0.6014
# Score: 1.768560859986714
# Params: {'eta': 0.05, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.7, 'gamma': 0}
#
# 🔹 Iteration 62/144
# Простые метрики:
# MAE: 1.7686
# MSE: 5.3126
# RMSE: 2.3049
# MAPE: 10.83%
# R²: 0.6014
# Score: 1.768560859986714
# Params: {'eta': 0.05, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.7, 'gamma': 0.1}
#
# 🔹 Iteration 63/144
# Простые метрики:
# MAE: 1.7858
# MSE: 5.2796
# RMSE: 2.2977
# MAPE: 10.89%
# R²: 0.6039
# Score: 1.7857906171253748
# Params: {'eta': 0.05, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0}
#
# 🔹 Iteration 64/144
# Простые метрики:
# MAE: 1.7858
# MSE: 5.2796
# RMSE: 2.2977
# MAPE: 10.89%
# R²: 0.6039
# Score: 1.7857906171253748
# Params: {'eta': 0.05, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0.1}
#
# 🔹 Iteration 65/144
# Простые метрики:
# MAE: 1.7507
# MSE: 5.0798
# RMSE: 2.2538
# MAPE: 10.67%
# R²: 0.6189
# Score: 1.75072249685015
# Params: {'eta': 0.05, 'max_depth': 6, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0}
#
# 🔹 Iteration 66/144
# Простые метрики:
# MAE: 1.7507
# MSE: 5.0798
# RMSE: 2.2538
# MAPE: 10.67%
# R²: 0.6189
# Score: 1.75072249685015
# Params: {'eta': 0.05, 'max_depth': 6, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.1}
#
# 🔹 Iteration 67/144
# Простые метрики:
# MAE: 1.7158
# MSE: 4.9673
# RMSE: 2.2287
# MAPE: 10.43%
# R²: 0.6273
# Score: 1.7158150136470796
# Params: {'eta': 0.05, 'max_depth': 6, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.8, 'gamma': 0}
#
# 🔹 Iteration 68/144
# Простые метрики:
# MAE: 1.7158
# MSE: 4.9673
# RMSE: 2.2287
# MAPE: 10.43%
# R²: 0.6273
# Score: 1.7158150136470796
# Params: {'eta': 0.05, 'max_depth': 6, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.8, 'gamma': 0.1}
#
# 🔹 Iteration 69/144
# Простые метрики:
# MAE: 1.7407
# MSE: 5.0506
# RMSE: 2.2474
# MAPE: 10.59%
# R²: 0.6211
# Score: 1.7407070330211096
# Params: {'eta': 0.05, 'max_depth': 6, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.7, 'gamma': 0}
#
# 🔹 Iteration 70/144
# Простые метрики:
# MAE: 1.7407
# MSE: 5.0506
# RMSE: 2.2474
# MAPE: 10.59%
# R²: 0.6211
# Score: 1.7407070330211096
# Params: {'eta': 0.05, 'max_depth': 6, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.7, 'gamma': 0.1}
#
# 🔹 Iteration 71/144
# Простые метрики:
# MAE: 1.7166
# MSE: 4.8953
# RMSE: 2.2125
# MAPE: 10.43%
# R²: 0.6327
# Score: 1.716590676137379
# Params: {'eta': 0.05, 'max_depth': 6, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0}
#
# 🔹 Iteration 72/144
# Простые метрики:
# MAE: 1.7166
# MSE: 4.8953
# RMSE: 2.2125
# MAPE: 10.43%
# R²: 0.6327
# Score: 1.716590676137379
# Params: {'eta': 0.05, 'max_depth': 6, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0.1}
#
# 🔹 Iteration 73/144
# Простые метрики:
# MAE: 1.7438
# MSE: 5.0693
# RMSE: 2.2515
# MAPE: 10.59%
# R²: 0.6197
# Score: 1.7437668561935429
# Params: {'eta': 0.05, 'max_depth': 6, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0}
#
# 🔹 Iteration 74/144
# Простые метрики:
# MAE: 1.7438
# MSE: 5.0693
# RMSE: 2.2515
# MAPE: 10.59%
# R²: 0.6197
# Score: 1.7437668561935429
# Params: {'eta': 0.05, 'max_depth': 6, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.1}
#
# 🔹 Iteration 75/144
# Простые метрики:
# MAE: 1.7087
# MSE: 4.9058
# RMSE: 2.2149
# MAPE: 10.37%
# R²: 0.6319
# Score: 1.7087419552462444
# Params: {'eta': 0.05, 'max_depth': 6, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.8, 'gamma': 0}
#
# 🔹 Iteration 76/144
# Простые метрики:
# MAE: 1.7087
# MSE: 4.9058
# RMSE: 2.2149
# MAPE: 10.37%
# R²: 0.6319
# Score: 1.7087419552462444
# Params: {'eta': 0.05, 'max_depth': 6, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.8, 'gamma': 0.1}
#
# 🔹 Iteration 77/144
# Простые метрики:
# MAE: 1.7347
# MSE: 4.9698
# RMSE: 2.2293
# MAPE: 10.49%
# R²: 0.6271
# Score: 1.7346546283790043
# Params: {'eta': 0.05, 'max_depth': 6, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.7, 'gamma': 0}
#
# 🔹 Iteration 78/144
# Простые метрики:
# MAE: 1.7347
# MSE: 4.9698
# RMSE: 2.2293
# MAPE: 10.49%
# R²: 0.6271
# Score: 1.7346546283790043
# Params: {'eta': 0.05, 'max_depth': 6, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.7, 'gamma': 0.1}
#
# 🔹 Iteration 79/144
# Простые метрики:
# MAE: 1.7027
# MSE: 4.8580
# RMSE: 2.2041
# MAPE: 10.36%
# R²: 0.6355
# Score: 1.7026766649314335
# Params: {'eta': 0.05, 'max_depth': 6, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0}
#
# 🔹 Iteration 80/144
# Простые метрики:
# MAE: 1.7027
# MSE: 4.8580
# RMSE: 2.2041
# MAPE: 10.36%
# R²: 0.6355
# Score: 1.7026766649314335
# Params: {'eta': 0.05, 'max_depth': 6, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0.1}
#
# 🔹 Iteration 81/144
# Простые метрики:
# MAE: 1.7409
# MSE: 5.0540
# RMSE: 2.2481
# MAPE: 10.37%
# R²: 0.6208
# Score: 1.7409319690295628
# Params: {'eta': 0.05, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0}
#
# 🔹 Iteration 82/144
# Простые метрики:
# MAE: 1.7409
# MSE: 5.0540
# RMSE: 2.2481
# MAPE: 10.37%
# R²: 0.6208
# Score: 1.740931990316936
# Params: {'eta': 0.05, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.1}
#
# 🔹 Iteration 83/144
# Простые метрики:
# MAE: 1.7384
# MSE: 5.1324
# RMSE: 2.2655
# MAPE: 10.34%
# R²: 0.6149
# Score: 1.738389353241239
# Params: {'eta': 0.05, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.8, 'gamma': 0}
#
# 🔹 Iteration 84/144
# Простые метрики:
# MAE: 1.7384
# MSE: 5.1324
# RMSE: 2.2655
# MAPE: 10.34%
# R²: 0.6149
# Score: 1.7383887784821646
# Params: {'eta': 0.05, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.8, 'gamma': 0.1}
#
# 🔹 Iteration 85/144
# Простые метрики:
# MAE: 1.7465
# MSE: 5.0021
# RMSE: 2.2365
# MAPE: 10.36%
# R²: 0.6247
# Score: 1.7465222503457751
# Params: {'eta': 0.05, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.7, 'gamma': 0}
#
# 🔹 Iteration 86/144
# Простые метрики:
# MAE: 1.7465
# MSE: 5.0021
# RMSE: 2.2365
# MAPE: 10.36%
# R²: 0.6247
# Score: 1.7465210625103542
# Params: {'eta': 0.05, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.7, 'gamma': 0.1}
#
# 🔹 Iteration 87/144
# Простые метрики:
# MAE: 1.7696
# MSE: 5.2193
# RMSE: 2.2846
# MAPE: 10.55%
# R²: 0.6084
# Score: 1.769559534106936
# Params: {'eta': 0.05, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0}
#
# 🔹 Iteration 88/144
# Простые метрики:
# MAE: 1.7696
# MSE: 5.2193
# RMSE: 2.2846
# MAPE: 10.55%
# R²: 0.6084
# Score: 1.7695586528096883
# Params: {'eta': 0.05, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0.1}
#
# 🔹 Iteration 89/144
# Простые метрики:
# MAE: 1.7408
# MSE: 5.0930
# RMSE: 2.2568
# MAPE: 10.36%
# R²: 0.6179
# Score: 1.7407627395221166
# Params: {'eta': 0.05, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0}
#
# 🔹 Iteration 90/144
# Простые метрики:
# MAE: 1.7408
# MSE: 5.0930
# RMSE: 2.2568
# MAPE: 10.36%
# R²: 0.6179
# Score: 1.7407627395221166
# Params: {'eta': 0.05, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.1}
#
# 🔹 Iteration 91/144
# Простые метрики:
# MAE: 1.7076
# MSE: 4.9803
# RMSE: 2.2317
# MAPE: 10.14%
# R²: 0.6264
# Score: 1.7075751083237785
# Params: {'eta': 0.05, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.8, 'gamma': 0}
#
# 🔹 Iteration 92/144
# Простые метрики:
# MAE: 1.7076
# MSE: 4.9803
# RMSE: 2.2317
# MAPE: 10.14%
# R²: 0.6264
# Score: 1.7075752403054918
# Params: {'eta': 0.05, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.8, 'gamma': 0.1}
#
# 🔹 Iteration 93/144
# Простые метрики:
# MAE: 1.7484
# MSE: 5.1737
# RMSE: 2.2746
# MAPE: 10.56%
# R²: 0.6118
# Score: 1.7483817407063076
# Params: {'eta': 0.05, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.7, 'gamma': 0}
#
# 🔹 Iteration 94/144
# Простые метрики:
# MAE: 1.7484
# MSE: 5.1737
# RMSE: 2.2746
# MAPE: 10.56%
# R²: 0.6118
# Score: 1.7483817407063076
# Params: {'eta': 0.05, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.7, 'gamma': 0.1}
#
# 🔹 Iteration 95/144
# Простые метрики:
# MAE: 1.7116
# MSE: 4.9046
# RMSE: 2.2146
# MAPE: 10.23%
# R²: 0.6320
# Score: 1.711620257581983
# Params: {'eta': 0.05, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0}
#
# 🔹 Iteration 96/144
# Простые метрики:
# MAE: 1.7200
# MSE: 4.9988
# RMSE: 2.2358
# MAPE: 10.28%
# R²: 0.6250
# Score: 1.720000459466662
# Params: {'eta': 0.05, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0.1}
#
# 🔹 Iteration 97/144
# Простые метрики:
# MAE: 1.7605
# MSE: 5.2300
# RMSE: 2.2869
# MAPE: 10.75%
# R²: 0.6076
# Score: 1.760533606154578
# Params: {'eta': 0.1, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0}
#
# 🔹 Iteration 98/144
# Простые метрики:
# MAE: 1.7605
# MSE: 5.2300
# RMSE: 2.2869
# MAPE: 10.75%
# R²: 0.6076
# Score: 1.760533606154578
# Params: {'eta': 0.1, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.1}
#
# 🔹 Iteration 99/144
# Простые метрики:
# MAE: 1.8145
# MSE: 5.4118
# RMSE: 2.3263
# MAPE: 11.06%
# R²: 0.5940
# Score: 1.8145437913281575
# Params: {'eta': 0.1, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.8, 'gamma': 0}
#
# 🔹 Iteration 100/144
# Простые метрики:
# MAE: 1.8145
# MSE: 5.4118
# RMSE: 2.3263
# MAPE: 11.06%
# R²: 0.5940
# Score: 1.8145437913281575
# Params: {'eta': 0.1, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.8, 'gamma': 0.1}
#
# 🔹 Iteration 101/144
# Простые метрики:
# MAE: 1.7812
# MSE: 5.2494
# RMSE: 2.2912
# MAPE: 10.84%
# R²: 0.6062
# Score: 1.7812423459121158
# Params: {'eta': 0.1, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.7, 'gamma': 0}
#
# 🔹 Iteration 102/144
# Простые метрики:
# MAE: 1.7812
# MSE: 5.2494
# RMSE: 2.2912
# MAPE: 10.84%
# R²: 0.6062
# Score: 1.7812423459121158
# Params: {'eta': 0.1, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.7, 'gamma': 0.1}
#
# 🔹 Iteration 103/144
# Простые метрики:
# MAE: 1.7800
# MSE: 5.2814
# RMSE: 2.2981
# MAPE: 10.88%
# R²: 0.6038
# Score: 1.780007038797651
# Params: {'eta': 0.1, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0}
#
# 🔹 Iteration 104/144
# Простые метрики:
# MAE: 1.7800
# MSE: 5.2814
# RMSE: 2.2981
# MAPE: 10.88%
# R²: 0.6038
# Score: 1.780007038797651
# Params: {'eta': 0.1, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0.1}
#
# 🔹 Iteration 105/144
# Простые метрики:
# MAE: 1.7605
# MSE: 5.2300
# RMSE: 2.2869
# MAPE: 10.75%
# R²: 0.6076
# Score: 1.760533606154578
# Params: {'eta': 0.1, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0}
#
# 🔹 Iteration 106/144
# Простые метрики:
# MAE: 1.7605
# MSE: 5.2300
# RMSE: 2.2869
# MAPE: 10.75%
# R²: 0.6076
# Score: 1.760533606154578
# Params: {'eta': 0.1, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.1}
#
# 🔹 Iteration 107/144
# Простые метрики:
# MAE: 1.8145
# MSE: 5.4118
# RMSE: 2.3263
# MAPE: 11.06%
# R²: 0.5940
# Score: 1.8145437913281575
# Params: {'eta': 0.1, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.8, 'gamma': 0}
#
# 🔹 Iteration 108/144
# Простые метрики:
# MAE: 1.8145
# MSE: 5.4118
# RMSE: 2.3263
# MAPE: 11.06%
# R²: 0.5940
# Score: 1.8145437913281575
# Params: {'eta': 0.1, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.8, 'gamma': 0.1}
#
# 🔹 Iteration 109/144
# Простые метрики:
# MAE: 1.7812
# MSE: 5.2494
# RMSE: 2.2912
# MAPE: 10.84%
# R²: 0.6062
# Score: 1.7812423459121158
# Params: {'eta': 0.1, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.7, 'gamma': 0}
#
# 🔹 Iteration 110/144
# Простые метрики:
# MAE: 1.7812
# MSE: 5.2494
# RMSE: 2.2912
# MAPE: 10.84%
# R²: 0.6062
# Score: 1.7812423459121158
# Params: {'eta': 0.1, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.7, 'gamma': 0.1}
#
# 🔹 Iteration 111/144
# Простые метрики:
# MAE: 1.7800
# MSE: 5.2814
# RMSE: 2.2981
# MAPE: 10.88%
# R²: 0.6038
# Score: 1.780007038797651
# Params: {'eta': 0.1, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0}
#
# 🔹 Iteration 112/144
# Простые метрики:
# MAE: 1.7800
# MSE: 5.2814
# RMSE: 2.2981
# MAPE: 10.88%
# R²: 0.6038
# Score: 1.780007038797651
# Params: {'eta': 0.1, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0.1}
#
# 🔹 Iteration 113/144
# Простые метрики:
# MAE: 1.7360
# MSE: 5.0834
# RMSE: 2.2546
# MAPE: 10.58%
# R²: 0.6186
# Score: 1.735969695874623
# Params: {'eta': 0.1, 'max_depth': 6, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0}
#
# 🔹 Iteration 114/144
# Простые метрики:
# MAE: 1.7360
# MSE: 5.0834
# RMSE: 2.2546
# MAPE: 10.58%
# R²: 0.6186
# Score: 1.735969695874623
# Params: {'eta': 0.1, 'max_depth': 6, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.1}
#
# 🔹 Iteration 115/144
# Простые метрики:
# MAE: 1.7324
# MSE: 5.0302
# RMSE: 2.2428
# MAPE: 10.46%
# R²: 0.6226
# Score: 1.7324358676161087
# Params: {'eta': 0.1, 'max_depth': 6, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.8, 'gamma': 0}
#
# 🔹 Iteration 116/144
# Простые метрики:
# MAE: 1.7324
# MSE: 5.0302
# RMSE: 2.2428
# MAPE: 10.46%
# R²: 0.6226
# Score: 1.7324358676161087
# Params: {'eta': 0.1, 'max_depth': 6, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.8, 'gamma': 0.1}
#
# 🔹 Iteration 117/144
# Простые метрики:
# MAE: 1.7018
# MSE: 4.8962
# RMSE: 2.2127
# MAPE: 10.37%
# R²: 0.6327
# Score: 1.7017984458378383
# Params: {'eta': 0.1, 'max_depth': 6, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.7, 'gamma': 0}
#
# 🔹 Iteration 118/144
# Простые метрики:
# MAE: 1.7018
# MSE: 4.8962
# RMSE: 2.2127
# MAPE: 10.37%
# R²: 0.6327
# Score: 1.7017984458378383
# Params: {'eta': 0.1, 'max_depth': 6, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.7, 'gamma': 0.1}
#
# 🔹 Iteration 119/144
# Простые метрики:
# MAE: 1.7001
# MSE: 4.8403
# RMSE: 2.2001
# MAPE: 10.39%
# R²: 0.6369
# Score: 1.7001303698335377
# Params: {'eta': 0.1, 'max_depth': 6, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0}
#
# 🔹 Iteration 120/144
# Простые метрики:
# MAE: 1.7001
# MSE: 4.8403
# RMSE: 2.2001
# MAPE: 10.39%
# R²: 0.6369
# Score: 1.7001320472785406
# Params: {'eta': 0.1, 'max_depth': 6, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0.1}
#
# 🔹 Iteration 121/144
# Простые метрики:
# MAE: 1.7414
# MSE: 5.0844
# RMSE: 2.2549
# MAPE: 10.60%
# R²: 0.6185
# Score: 1.7413664604936325
# Params: {'eta': 0.1, 'max_depth': 6, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0}
#
# 🔹 Iteration 122/144
# Простые метрики:
# MAE: 1.7414
# MSE: 5.0844
# RMSE: 2.2549
# MAPE: 10.60%
# R²: 0.6185
# Score: 1.7413664604936325
# Params: {'eta': 0.1, 'max_depth': 6, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.1}
#
# 🔹 Iteration 123/144
# Простые метрики:
# MAE: 1.7277
# MSE: 5.0029
# RMSE: 2.2367
# MAPE: 10.39%
# R²: 0.6247
# Score: 1.7276843615940638
# Params: {'eta': 0.1, 'max_depth': 6, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.8, 'gamma': 0}
#
# 🔹 Iteration 124/144
# Простые метрики:
# MAE: 1.7277
# MSE: 5.0029
# RMSE: 2.2367
# MAPE: 10.39%
# R²: 0.6247
# Score: 1.7276843615940638
# Params: {'eta': 0.1, 'max_depth': 6, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.8, 'gamma': 0.1}
#
# 🔹 Iteration 125/144
# Простые метрики:
# MAE: 1.7062
# MSE: 4.9084
# RMSE: 2.2155
# MAPE: 10.35%
# R²: 0.6317
# Score: 1.7061685102326527
# Params: {'eta': 0.1, 'max_depth': 6, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.7, 'gamma': 0}
#
# 🔹 Iteration 126/144
# Простые метрики:
# MAE: 1.7062
# MSE: 4.9084
# RMSE: 2.2155
# MAPE: 10.35%
# R²: 0.6317
# Score: 1.7061685102326527
# Params: {'eta': 0.1, 'max_depth': 6, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.7, 'gamma': 0.1}
#
# 🔹 Iteration 127/144
# Простые метрики:
# MAE: 1.7214
# MSE: 4.9799
# RMSE: 2.2316
# MAPE: 10.58%
# R²: 0.6264
# Score: 1.721359147344317
# Params: {'eta': 0.1, 'max_depth': 6, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0}
#
# 🔹 Iteration 128/144
# Простые метрики:
# MAE: 1.7214
# MSE: 4.9799
# RMSE: 2.2316
# MAPE: 10.58%
# R²: 0.6264
# Score: 1.721359147344317
# Params: {'eta': 0.1, 'max_depth': 6, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0.1}
#
# 🔹 Iteration 129/144
# Простые метрики:
# MAE: 1.7293
# MSE: 5.1277
# RMSE: 2.2644
# MAPE: 10.25%
# R²: 0.6153
# Score: 1.7293154341833932
# Params: {'eta': 0.1, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0}
#
# 🔹 Iteration 130/144
# Простые метрики:
# MAE: 1.7293
# MSE: 5.1277
# RMSE: 2.2644
# MAPE: 10.25%
# R²: 0.6153
# Score: 1.7293156002249037
# Params: {'eta': 0.1, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.1}
#
# 🔹 Iteration 131/144
# Простые метрики:
# MAE: 1.7547
# MSE: 5.1650
# RMSE: 2.2727
# MAPE: 10.34%
# R²: 0.6125
# Score: 1.754689440556935
# Params: {'eta': 0.1, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.8, 'gamma': 0}
#
# 🔹 Iteration 132/144
# Простые метрики:
# MAE: 1.7547
# MSE: 5.1650
# RMSE: 2.2727
# MAPE: 10.34%
# R²: 0.6125
# Score: 1.754689440556935
# Params: {'eta': 0.1, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.8, 'gamma': 0.1}
#
# 🔹 Iteration 133/144
# Простые метрики:
# MAE: 1.7027
# MSE: 4.9792
# RMSE: 2.2314
# MAPE: 10.14%
# R²: 0.6264
# Score: 1.7026959674698965
# Params: {'eta': 0.1, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.7, 'gamma': 0}
#
# 🔹 Iteration 134/144
# Простые метрики:
# MAE: 1.7027
# MSE: 4.9792
# RMSE: 2.2314
# MAPE: 10.14%
# R²: 0.6264
# Score: 1.7026962782655441
# Params: {'eta': 0.1, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.7, 'gamma': 0.1}
#
# 🔹 Iteration 135/144
# Простые метрики:
# MAE: 1.7938
# MSE: 5.3442
# RMSE: 2.3118
# MAPE: 10.54%
# R²: 0.5991
# Score: 1.7938190826347895
# Params: {'eta': 0.1, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0}
#
# 🔹 Iteration 136/144
# Простые метрики:
# MAE: 1.7938
# MSE: 5.3442
# RMSE: 2.3117
# MAPE: 10.54%
# R²: 0.5991
# Score: 1.7938204961163657
# Params: {'eta': 0.1, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0.1}
#
# 🔹 Iteration 137/144
# Простые метрики:
# MAE: 1.7902
# MSE: 5.3980
# RMSE: 2.3234
# MAPE: 10.52%
# R²: 0.5950
# Score: 1.7901829855782645
# Params: {'eta': 0.1, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0}
#
# 🔹 Iteration 138/144
# Простые метрики:
# MAE: 1.7902
# MSE: 5.3980
# RMSE: 2.3234
# MAPE: 10.52%
# R²: 0.5950
# Score: 1.7901829855782645
# Params: {'eta': 0.1, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.7, 'gamma': 0.1}
#
# 🔹 Iteration 139/144
# Простые метрики:
# MAE: 1.7149
# MSE: 5.1286
# RMSE: 2.2646
# MAPE: 10.25%
# R²: 0.6152
# Score: 1.714874670335225
# Params: {'eta': 0.1, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.8, 'gamma': 0}
#
# 🔹 Iteration 140/144
# Простые метрики:
# MAE: 1.7149
# MSE: 5.1286
# RMSE: 2.2646
# MAPE: 10.25%
# R²: 0.6152
# Score: 1.7148755856922695
# Params: {'eta': 0.1, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.7, 'colsample_bytree': 0.8, 'gamma': 0.1}
#
# 🔹 Iteration 141/144
# Простые метрики:
# MAE: 1.7352
# MSE: 5.0899
# RMSE: 2.2561
# MAPE: 10.46%
# R²: 0.6181
# Score: 1.7351851531437466
# Params: {'eta': 0.1, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.7, 'gamma': 0}
#
# 🔹 Iteration 142/144
# Простые метрики:
# MAE: 1.7552
# MSE: 5.1029
# RMSE: 2.2590
# MAPE: 10.38%
# R²: 0.6172
# Score: 1.7552151347909655
# Params: {'eta': 0.1, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.7, 'gamma': 0.1}
#
# 🔹 Iteration 143/144
# Простые метрики:
# MAE: 1.7579
# MSE: 5.0945
# RMSE: 2.2571
# MAPE: 10.47%
# R²: 0.6178
# Score: 1.7578770697116854
# Params: {'eta': 0.1, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0}
#
# 🔹 Iteration 144/144
# Простые метрики:
# MAE: 1.7436
# MSE: 5.0855
# RMSE: 2.2551
# MAPE: 10.34%
# R²: 0.6185
# Score: 1.7435585337025779
# Params: {'eta': 0.1, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0.1}
#
# BEST RESULT
# Score: 1.6576278695038387
# Params: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'seed': 42, 'eta': 0.03, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.8, 'gamma': 0.1}

# %%
# BEST RESULT
# Score: 1.6576278695038387
# Params: {'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'seed': 42, 'eta': 0.03, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.8, 'gamma': 0.1}

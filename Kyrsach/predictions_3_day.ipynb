# %% [markdown]
# ## Импорт библиотек

# %%
import warnings
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import itertools

from datetime import datetime

from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

import xgboost as xgb
import lightgbm as lgb
from sklearn.ensemble import HistGradientBoostingRegressor
from catboost import CatBoostRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# %%
warnings.filterwarnings('ignore')

# %%
seed = 42
np.random.seed(seed)
random.seed(seed)

# %% [markdown]
# ## Загрузка данных

# %%
df = pd.read_csv('df_for_learning.csv', index_col=0)
df.head()
# Out:
#    Индекс ВМО        date  Средняя температура воздуха  Количество осадков  \
# 0       34059  1982-01-31                         -9.2                 0.0
# 1       34059  1982-02-01                        -11.8                 0.0
# 2       34059  1982-02-02                        -15.2                 0.0
# 3       34059  1982-02-03                        -16.3                 0.0
# 4       34059  1982-02-04                        -17.4                 0.0
#
#    Горизонтальная дальность видимости  Общее количество облачности  \
# 0                              69.125                        5.125
# 1                              68.125                        3.375
# 2                              67.625                        1.000
# 3                              53.500                        0.625
# 4                              55.000                        5.000
#
#    Количество облачности нижнего яруса  Форма облаков верхнего яруса  \
# 0                                  0.0                         0.750
# 1                                  0.0                         1.750
# 2                                  0.0                         0.375
# 3                                  0.0                         0.250
# 4                                  0.0                         2.500
#
#    Форма облаков среднего яруса  Форма облаков вертикального развития  ...  \
# 0                         0.000                                   0.0  ...
# 1                         0.125                                   0.0  ...
# 2                         0.000                                   0.0  ...
# 3                         0.000                                   0.0  ...
# 4                         0.625                                   0.0  ...
#
#    Атмосферное давление на уровне станции_lag_395  year  day  day_of_year_sin  \
# 0                                        983.0500  1982   31         0.508671
# 1                                        980.3750  1982    1         0.523416
# 2                                        984.6000  1982    2         0.538005
# 3                                        981.3750  1982    3         0.552435
# 4                                        979.3875  1982    4         0.566702
#
#    day_of_year_cos  season  month_sin  month_cos  \
# 0         0.860961       1   0.500000   0.866025
# 1         0.852078       1   0.866025   0.500000
# 2         0.842942       1   0.866025   0.500000
# 3         0.833556       1   0.866025   0.500000
# 4         0.823923       1   0.866025   0.500000
#
#    Средняя температура воздуха_mean_group  temp_delta_vs_all_stations
# 0                               -8.820930                    0.110631
# 1                               -8.623256                    0.519601
# 2                               -9.165116                    0.276744
# 3                               -9.504651                    0.185382
# 4                               -8.655814                    0.614618
#
# [5 rows x 57 columns]

# %%
df['date'] = pd.to_datetime(df['date'])
df = df.sort_values(['Индекс ВМО', 'date']).reset_index(drop=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109053 entries, 0 to 109052
# Data columns (total 57 columns):
#  #   Column                                          Non-Null Count   Dtype
# ---  ------                                          --------------   -----
#  0   Индекс ВМО                                      109053 non-null  int64
#  1   date                                            109053 non-null  datetime64[ns]
#  2   Средняя температура воздуха                     109053 non-null  float64
#  3   Количество осадков                              109053 non-null  float64
#  4   Горизонтальная дальность видимости              109053 non-null  float64
#  5   Общее количество облачности                     109053 non-null  float64
#  6   Количество облачности нижнего яруса             109053 non-null  float64
#  7   Форма облаков верхнего яруса                    109053 non-null  float64
#  8   Форма облаков среднего яруса                    109053 non-null  float64
#  9   Форма облаков вертикального развития            109053 non-null  float64
#  10  Слоистые и слоисто_кучевые облака               109053 non-null  float64
#  11  Слоисто_дождразорванно_дождевые облака          109053 non-null  float64
#  12  Высота нижней границы облачности                109053 non-null  float64
#  13  Погода между сроками                            109053 non-null  float64
#  14  Погода в срок наблюдения                        109053 non-null  float64
#  15  Направление ветра                               109053 non-null  float64
#  16  Средняя скорость ветра                          109053 non-null  float64
#  17  Максимальная скорость ветра                     109053 non-null  float64
#  18  Сумма осадков                                   109053 non-null  float64
#  19  Температура поверхности почвы                   109053 non-null  float64
#  20  Парциальное давление водяного пара              109053 non-null  float64
#  21  Относительная влажность воздуха                 109053 non-null  float64
#  22  Дефицит насыщения водяного пара                 109053 non-null  float64
#  23  Атмосферное давление на уровне станции          109053 non-null  float64
#  24  Атмосферное давление на уровне моря             109053 non-null  float64
#  25  Характеристика барической тенденции             109053 non-null  float64
#  26  Величина барической тенденции                   109053 non-null  float64
#  27  Средняя температура воздуха_lag_335             109053 non-null  float64
#  28  Средняя температура воздуха_lag_365             109053 non-null  float64
#  29  Средняя температура воздуха_lag_395             109053 non-null  float64
#  30  Температура поверхности почвы_lag_335           109053 non-null  float64
#  31  Температура поверхности почвы_lag_365           109053 non-null  float64
#  32  Температура поверхности почвы_lag_395           109053 non-null  float64
#  33  Парциальное давление водяного пара_lag_335      109053 non-null  float64
#  34  Парциальное давление водяного пара_lag_365      109053 non-null  float64
#  35  Парциальное давление водяного пара_lag_395      109053 non-null  float64
#  36  Относительная влажность воздуха_lag_335         109053 non-null  float64
#  37  Относительная влажность воздуха_lag_365         109053 non-null  float64
#  38  Относительная влажность воздуха_lag_395         109053 non-null  float64
#  39  Дефицит насыщения водяного пара_lag_335         109053 non-null  float64
#  40  Дефицит насыщения водяного пара_lag_365         109053 non-null  float64
#  41  Дефицит насыщения водяного пара_lag_395         109053 non-null  float64
#  42  Атмосферное давление на уровне моря_lag_335     109053 non-null  float64
#  43  Атмосферное давление на уровне моря_lag_365     109053 non-null  float64
#  44  Атмосферное давление на уровне моря_lag_395     109053 non-null  float64
#  45  Атмосферное давление на уровне станции_lag_335  109053 non-null  float64
#  46  Атмосферное давление на уровне станции_lag_365  109053 non-null  float64
#  47  Атмосферное давление на уровне станции_lag_395  109053 non-null  float64
#  48  year                                            109053 non-null  int64
#  49  day                                             109053 non-null  int64
#  50  day_of_year_sin                                 109053 non-null  float64
#  51  day_of_year_cos                                 109053 non-null  float64
#  52  season                                          109053 non-null  int64
#  53  month_sin                                       109053 non-null  float64
#  54  month_cos                                       109053 non-null  float64
#  55  Средняя температура воздуха_mean_group          109053 non-null  float64
#  56  temp_delta_vs_all_stations                      109053 non-null  float64
# dtypes: datetime64[ns](1), float64(52), int64(4)
# memory usage: 47.4 MB

# %% [markdown]
# ## Работа с лагами

# %% [markdown]
# ### Выбор признаков

# %%
df.shape
# Out:
# (109053, 57)

# %%
original_cols = [
    col for col in df.columns
    if not any([
        '_lag_' in col,
        '_sin' in col,
        '_cos' in col,
        '_mean' in col,
        'delta' in col,
        col in ['year', 'day', 'season', 'Индекс ВМО', 'date']
    ])
]
# original_cols

# %% [markdown]
# ### Добавление лагов

# %%
def add_lag_features(df, lag_cols, lag=1, group_col='Индекс ВМО', date_col='date'):
    """
    Добавляет лаги для указанных колонок
    df : DataFrame
    lag_cols : list - колонки, для которых делаем лаги
    lag : int - размер лага (в днях)
    """
    df = df.sort_values([group_col, date_col]).copy()

    for col in lag_cols:
        df[f'{col}_lag_{lag}'] = df.groupby(group_col)[col].shift(lag)

    return df

# %%
df_with_lags = add_lag_features(df, original_cols, lag=3)

# %%
df_with_lags.columns
# Out:
# Index(['Индекс ВМО', 'date', 'Средняя температура воздуха',
#        'Количество осадков', 'Горизонтальная дальность видимости',
#        'Общее количество облачности', 'Количество облачности нижнего яруса',
#        'Форма облаков верхнего яруса', 'Форма облаков среднего яруса',
#        'Форма облаков вертикального развития',
#        'Слоистые и слоисто_кучевые облака',
#        'Слоисто_дождразорванно_дождевые облака',
#        'Высота нижней границы облачности', 'Погода между сроками',
#        'Погода в срок наблюдения', 'Направление ветра',
#        'Средняя скорость ветра', 'Максимальная скорость ветра',
#        'Сумма осадков', 'Температура поверхности почвы',
#        'Парциальное давление водяного пара', 'Относительная влажность воздуха',
#        'Дефицит насыщения водяного пара',
#        'Атмосферное давление на уровне станции',
#        'Атмосферное давление на уровне моря',
#        'Характеристика барической тенденции', 'Величина барической тенденции',
#        'Средняя температура воздуха_lag_335',
#        'Средняя температура воздуха_lag_365',
#        'Средняя температура воздуха_lag_395',
#        'Температура поверхности почвы_lag_335',
#        'Температура поверхности почвы_lag_365',
#        'Температура поверхности почвы_lag_395',
#        'Парциальное давление водяного пара_lag_335',
#        'Парциальное давление водяного пара_lag_365',
#        'Парциальное давление водяного пара_lag_395',
#        'Относительная влажность воздуха_lag_335',
#        'Относительная влажность воздуха_lag_365',
#        'Относительная влажность воздуха_lag_395',
#        'Дефицит насыщения водяного пара_lag_335',
#        'Дефицит насыщения водяного пара_lag_365',
#        'Дефицит насыщения водяного пара_lag_395',
#        'Атмосферное давление на уровне моря_lag_335',
#        'Атмосферное давление на уровне моря_lag_365',
#        'Атмосферное давление на уровне моря_lag_395',
#        'Атмосферное давление на уровне станции_lag_335',
#        'Атмосферное давление на уровне станции_lag_365',
#        'Атмосферное давление на уровне станции_lag_395', 'year', 'day',
#        'day_of_year_sin', 'day_of_year_cos', 'season', 'month_sin',
#        'month_cos', 'Средняя температура воздуха_mean_group',
#        'temp_delta_vs_all_stations', 'Средняя температура воздуха_lag_3',
#        'Количество осадков_lag_3', 'Горизонтальная дальность видимости_lag_3',
#        'Общее количество облачности_lag_3',
#        'Количество облачности нижнего яруса_lag_3',
#        'Форма облаков верхнего яруса_lag_3',
#        'Форма облаков среднего яруса_lag_3',
#        'Форма облаков вертикального развития_lag_3',
#        'Слоистые и слоисто_кучевые облака_lag_3',
#        'Слоисто_дождразорванно_дождевые облака_lag_3',
#        'Высота нижней границы облачности_lag_3', 'Погода между сроками_lag_3',
#        'Погода в срок наблюдения_lag_3', 'Направление ветра_lag_3',
#        'Средняя скорость ветра_lag_3', 'Максимальная скорость ветра_lag_3',
#        'Сумма осадков_lag_3', 'Температура поверхности почвы_lag_3',
#        'Парциальное давление водяного пара_lag_3',
#        'Относительная влажность воздуха_lag_3',
#        'Дефицит насыщения водяного пара_lag_3',
#        'Атмосферное давление на уровне станции_lag_3',
#        'Атмосферное давление на уровне моря_lag_3',
#        'Характеристика барической тенденции_lag_3',
#        'Величина барической тенденции_lag_3'],
#       dtype='object')

# %% [markdown]
# ### Работа с пропусками

# %%
df_with_lags.isna().sum().sum()
# Out:
# np.int64(525)

# %%
df_with_lags.date.min(), df_with_lags.date.max()
# Out:
# (Timestamp('1982-01-31 00:00:00'), Timestamp('2024-09-25 00:00:00'))

# %%
# Для каждой группы находим первую дату без NaN
def first_valid_date_per_group(df, group_col='Индекс ВМО', date_col='date'):
    # Словарь: индекс ВМО - дата первой строки без NaN
    first_dates = {}

    for idx, group in df.groupby(group_col):
        # Проверяем только колонки с NaN
        valid_rows = group[~group.isna().any(axis=1)]
        if not valid_rows.empty:
            first_dates[idx] = valid_rows[date_col].iloc[0]
        else:
            first_dates[idx] = None  # если все строки пустые

    return first_dates


first_dates_dict = first_valid_date_per_group(df_with_lags)
first_dates_dict
# Out:
# {34059: Timestamp('1982-02-03 00:00:00'),
#  34152: Timestamp('1982-02-03 00:00:00'),
#  34163: Timestamp('1982-02-03 00:00:00'),
#  34172: Timestamp('1982-02-03 00:00:00'),
#  34186: Timestamp('1982-02-03 00:00:00'),
#  34289: Timestamp('1982-02-03 00:00:00'),
#  34391: Timestamp('1982-02-03 00:00:00')}

# %%
# Обрезаем каждую группу по дате
cleaned_groups = []
for idx, group in df_with_lags.groupby('Индекс ВМО'):
    start_date = first_dates_dict[idx]
    cleaned_group = group[group['date'] >= start_date]
    cleaned_groups.append(cleaned_group)

clean_lagged_df = pd.concat(cleaned_groups).reset_index(drop=True)

# %%
clean_lagged_df.date.min(), clean_lagged_df.date.max()
# Out:
# (Timestamp('1982-02-03 00:00:00'), Timestamp('2024-09-25 00:00:00'))

# %%
clean_lagged_df.isna().sum().sum()
# Out:
# np.int64(0)

# %%
df.shape, clean_lagged_df.shape
# Out:
# ((109053, 57), (109032, 82))

# %% [markdown]
# ## Удаление лишних признаков (Чтобы не было утечек)

# %% [markdown]
# Делать предсказания по предыдущим дням, а не по текущему восстанавливать

# %%
columns_for_drop = [col for col in original_cols if col != 'Средняя температура воздуха']

# %%
df_for_training = clean_lagged_df.drop(columns=columns_for_drop)

# %%
df_for_training.head()
# Out:
#    Индекс ВМО       date  Средняя температура воздуха  \
# 0       34059 1982-02-03                        -16.3
# 1       34059 1982-02-04                        -17.4
# 2       34059 1982-02-05                         -7.9
# 3       34059 1982-02-06                         -9.8
# 4       34059 1982-02-07                        -18.2
#
#    Средняя температура воздуха_lag_335  Средняя температура воздуха_lag_365  \
# 0                                 -3.2                                 -8.0
# 1                                 -2.3                                  0.9
# 2                                 -5.7                                 -0.7
# 3                                -11.1                                  2.4
# 4                                 -1.9                                  1.9
#
#    Средняя температура воздуха_lag_395  Температура поверхности почвы_lag_335  \
# 0                                 -2.5                                -2.7500
# 1                                 -0.1                                -4.0000
# 2                                  0.4                                -9.6250
# 3                                 -1.8                                -6.8875
# 4                                 -8.6                                -2.2750
#
#    Температура поверхности почвы_lag_365  \
# 0                                -7.1250
# 1                                -1.1375
# 2                                -1.3875
# 3                                 1.0000
# 4                                 0.0000
#
#    Температура поверхности почвы_lag_395  \
# 0                                -2.7500
# 1                                -0.4250
# 2                                -0.3750
# 3                                -2.0125
# 4                                -8.5000
#
#    Парциальное давление водяного пара_lag_335  ...  \
# 0                                      4.9500  ...
# 1                                      4.3375  ...
# 2                                      3.0125  ...
# 3                                      3.7750  ...
# 4                                      4.1750  ...
#
#    Максимальная скорость ветра_lag_3  Сумма осадков_lag_3  \
# 0                             10.000                  0.0
# 1                              7.125                  0.0
# 2                              3.500                  0.0
# 3                              4.750                  0.0
# 4                              2.750                  0.0
#
#    Температура поверхности почвы_lag_3  \
# 0                              -10.750
# 1                              -12.500
# 2                              -16.750
# 3                              -17.875
# 4                              -16.125
#
#    Парциальное давление водяного пара_lag_3  \
# 0                                    2.1125
# 1                                    1.8875
# 2                                    1.3250
# 3                                    1.3750
# 4                                    1.5375
#
#    Относительная влажность воздуха_lag_3  \
# 0                                 75.375
# 1                                 77.375
# 2                                 73.125
# 3                                 79.125
# 4                                 78.875
#
#    Дефицит насыщения водяного пара_lag_3  \
# 0                                 0.7000
# 1                                 0.5625
# 2                                 0.5250
# 3                                 0.3625
# 4                                 0.3750
#
#    Атмосферное давление на уровне станции_lag_3  \
# 0                                      997.0250
# 1                                     1001.1625
# 2                                     1006.4125
# 3                                     1005.8750
# 4                                     1004.3125
#
#    Атмосферное давление на уровне моря_lag_3  \
# 0                                  1018.3125
# 1                                  1022.6250
# 2                                  1028.3000
# 3                                  1027.8500
# 4                                  1026.1750
#
#    Характеристика барической тенденции_lag_3  \
# 0                                      5.125
# 1                                      2.000
# 2                                      3.500
# 3                                      4.000
# 4                                      6.375
#
#    Величина барической тенденции_lag_3
# 0                               0.7125
# 1                               0.9750
# 2                               0.4125
# 3                               0.4875
# 4                               0.6500
#
# [5 rows x 58 columns]

# %%
df_for_training.shape
# Out:
# (109032, 58)

# %%
df_for_training.isna().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Разделение данных на тренировочную/валидационную

# %%
df_for_training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109032 entries, 0 to 109031
# Data columns (total 58 columns):
#  #   Column                                          Non-Null Count   Dtype
# ---  ------                                          --------------   -----
#  0   Индекс ВМО                                      109032 non-null  int64
#  1   date                                            109032 non-null  datetime64[ns]
#  2   Средняя температура воздуха                     109032 non-null  float64
#  3   Средняя температура воздуха_lag_335             109032 non-null  float64
#  4   Средняя температура воздуха_lag_365             109032 non-null  float64
#  5   Средняя температура воздуха_lag_395             109032 non-null  float64
#  6   Температура поверхности почвы_lag_335           109032 non-null  float64
#  7   Температура поверхности почвы_lag_365           109032 non-null  float64
#  8   Температура поверхности почвы_lag_395           109032 non-null  float64
#  9   Парциальное давление водяного пара_lag_335      109032 non-null  float64
#  10  Парциальное давление водяного пара_lag_365      109032 non-null  float64
#  11  Парциальное давление водяного пара_lag_395      109032 non-null  float64
#  12  Относительная влажность воздуха_lag_335         109032 non-null  float64
#  13  Относительная влажность воздуха_lag_365         109032 non-null  float64
#  14  Относительная влажность воздуха_lag_395         109032 non-null  float64
#  15  Дефицит насыщения водяного пара_lag_335         109032 non-null  float64
#  16  Дефицит насыщения водяного пара_lag_365         109032 non-null  float64
#  17  Дефицит насыщения водяного пара_lag_395         109032 non-null  float64
#  18  Атмосферное давление на уровне моря_lag_335     109032 non-null  float64
#  19  Атмосферное давление на уровне моря_lag_365     109032 non-null  float64
#  20  Атмосферное давление на уровне моря_lag_395     109032 non-null  float64
#  21  Атмосферное давление на уровне станции_lag_335  109032 non-null  float64
#  22  Атмосферное давление на уровне станции_lag_365  109032 non-null  float64
#  23  Атмосферное давление на уровне станции_lag_395  109032 non-null  float64
#  24  year                                            109032 non-null  int64
#  25  day                                             109032 non-null  int64
#  26  day_of_year_sin                                 109032 non-null  float64
#  27  day_of_year_cos                                 109032 non-null  float64
#  28  season                                          109032 non-null  int64
#  29  month_sin                                       109032 non-null  float64
#  30  month_cos                                       109032 non-null  float64
#  31  Средняя температура воздуха_mean_group          109032 non-null  float64
#  32  temp_delta_vs_all_stations                      109032 non-null  float64
#  33  Средняя температура воздуха_lag_3               109032 non-null  float64
#  34  Количество осадков_lag_3                        109032 non-null  float64
#  35  Горизонтальная дальность видимости_lag_3        109032 non-null  float64
#  36  Общее количество облачности_lag_3               109032 non-null  float64
#  37  Количество облачности нижнего яруса_lag_3       109032 non-null  float64
#  38  Форма облаков верхнего яруса_lag_3              109032 non-null  float64
#  39  Форма облаков среднего яруса_lag_3              109032 non-null  float64
#  40  Форма облаков вертикального развития_lag_3      109032 non-null  float64
#  41  Слоистые и слоисто_кучевые облака_lag_3         109032 non-null  float64
#  42  Слоисто_дождразорванно_дождевые облака_lag_3    109032 non-null  float64
#  43  Высота нижней границы облачности_lag_3          109032 non-null  float64
#  44  Погода между сроками_lag_3                      109032 non-null  float64
#  45  Погода в срок наблюдения_lag_3                  109032 non-null  float64
#  46  Направление ветра_lag_3                         109032 non-null  float64
#  47  Средняя скорость ветра_lag_3                    109032 non-null  float64
#  48  Максимальная скорость ветра_lag_3               109032 non-null  float64
#  49  Сумма осадков_lag_3                             109032 non-null  float64
#  50  Температура поверхности почвы_lag_3             109032 non-null  float64
#  51  Парциальное давление водяного пара_lag_3        109032 non-null  float64
#  52  Относительная влажность воздуха_lag_3           109032 non-null  float64
#  53  Дефицит насыщения водяного пара_lag_3           109032 non-null  float64
#  54  Атмосферное давление на уровне станции_lag_3    109032 non-null  float64
#  55  Атмосферное давление на уровне моря_lag_3       109032 non-null  float64
#  56  Характеристика барической тенденции_lag_3       109032 non-null  float64
#  57  Величина барической тенденции_lag_3             109032 non-null  float64
# dtypes: datetime64[ns](1), float64(53), int64(4)
# memory usage: 48.2 MB

# %%
df_for_training.date.min(), df_for_training.date.max()
# Out:
# (Timestamp('1982-02-03 00:00:00'), Timestamp('2024-09-25 00:00:00'))

# %%
val_start = df_for_training['date'].max() - pd.DateOffset(months=1)
val_start
# Out:
# Timestamp('2024-08-25 00:00:00')

# %%
# Разделяем
train_df = df_for_training[df_for_training['date'] < val_start].copy()
val_df = df_for_training[df_for_training['date'] >= val_start].copy()

print("Train shape:", train_df.shape)
print("Validation shape:", val_df.shape)
# Out:
# Train shape: (108808, 58)
# Validation shape: (224, 58)

# %%
train_df = train_df.drop(columns=['date'])
val_df_drop_date = val_df.drop(columns=['date'])

# %%
train_df.columns
# Out:
# Index(['Индекс ВМО', 'Средняя температура воздуха',
#        'Средняя температура воздуха_lag_335',
#        'Средняя температура воздуха_lag_365',
#        'Средняя температура воздуха_lag_395',
#        'Температура поверхности почвы_lag_335',
#        'Температура поверхности почвы_lag_365',
#        'Температура поверхности почвы_lag_395',
#        'Парциальное давление водяного пара_lag_335',
#        'Парциальное давление водяного пара_lag_365',
#        'Парциальное давление водяного пара_lag_395',
#        'Относительная влажность воздуха_lag_335',
#        'Относительная влажность воздуха_lag_365',
#        'Относительная влажность воздуха_lag_395',
#        'Дефицит насыщения водяного пара_lag_335',
#        'Дефицит насыщения водяного пара_lag_365',
#        'Дефицит насыщения водяного пара_lag_395',
#        'Атмосферное давление на уровне моря_lag_335',
#        'Атмосферное давление на уровне моря_lag_365',
#        'Атмосферное давление на уровне моря_lag_395',
#        'Атмосферное давление на уровне станции_lag_335',
#        'Атмосферное давление на уровне станции_lag_365',
#        'Атмосферное давление на уровне станции_lag_395', 'year', 'day',
#        'day_of_year_sin', 'day_of_year_cos', 'season', 'month_sin',
#        'month_cos', 'Средняя температура воздуха_mean_group',
#        'temp_delta_vs_all_stations', 'Средняя температура воздуха_lag_3',
#        'Количество осадков_lag_3', 'Горизонтальная дальность видимости_lag_3',
#        'Общее количество облачности_lag_3',
#        'Количество облачности нижнего яруса_lag_3',
#        'Форма облаков верхнего яруса_lag_3',
#        'Форма облаков среднего яруса_lag_3',
#        'Форма облаков вертикального развития_lag_3',
#        'Слоистые и слоисто_кучевые облака_lag_3',
#        'Слоисто_дождразорванно_дождевые облака_lag_3',
#        'Высота нижней границы облачности_lag_3', 'Погода между сроками_lag_3',
#        'Погода в срок наблюдения_lag_3', 'Направление ветра_lag_3',
#        'Средняя скорость ветра_lag_3', 'Максимальная скорость ветра_lag_3',
#        'Сумма осадков_lag_3', 'Температура поверхности почвы_lag_3',
#        'Парциальное давление водяного пара_lag_3',
#        'Относительная влажность воздуха_lag_3',
#        'Дефицит насыщения водяного пара_lag_3',
#        'Атмосферное давление на уровне станции_lag_3',
#        'Атмосферное давление на уровне моря_lag_3',
#        'Характеристика барической тенденции_lag_3',
#        'Величина барической тенденции_lag_3'],
#       dtype='object')

# %%
y_train = train_df['Средняя температура воздуха']
y_val = val_df_drop_date['Средняя температура воздуха']

# Признаки (оставляем Индекс ВМО)
X_train = train_df.drop(columns=['Средняя температура воздуха'])
X_val = val_df_drop_date.drop(columns=['Средняя температура воздуха'])

print("Train shape:", X_train.shape, y_train.shape)
print("Validation shape:", X_val.shape, y_val.shape)
# Out:
# Train shape: (108808, 56) (108808,)
# Validation shape: (224, 56) (224,)

# %%
print(X_train.isna().sum().sum())
print(y_train.isna().sum().sum())
print('Валидационное:')
print(X_val.isna().sum().sum())
print(y_val.isna().sum().sum())
# Out:
# 0
# 0
# Валидационное:
# 0
# 0

# %%
X_train.columns
# Out:
# Index(['Индекс ВМО', 'Средняя температура воздуха_lag_335',
#        'Средняя температура воздуха_lag_365',
#        'Средняя температура воздуха_lag_395',
#        'Температура поверхности почвы_lag_335',
#        'Температура поверхности почвы_lag_365',
#        'Температура поверхности почвы_lag_395',
#        'Парциальное давление водяного пара_lag_335',
#        'Парциальное давление водяного пара_lag_365',
#        'Парциальное давление водяного пара_lag_395',
#        'Относительная влажность воздуха_lag_335',
#        'Относительная влажность воздуха_lag_365',
#        'Относительная влажность воздуха_lag_395',
#        'Дефицит насыщения водяного пара_lag_335',
#        'Дефицит насыщения водяного пара_lag_365',
#        'Дефицит насыщения водяного пара_lag_395',
#        'Атмосферное давление на уровне моря_lag_335',
#        'Атмосферное давление на уровне моря_lag_365',
#        'Атмосферное давление на уровне моря_lag_395',
#        'Атмосферное давление на уровне станции_lag_335',
#        'Атмосферное давление на уровне станции_lag_365',
#        'Атмосферное давление на уровне станции_lag_395', 'year', 'day',
#        'day_of_year_sin', 'day_of_year_cos', 'season', 'month_sin',
#        'month_cos', 'Средняя температура воздуха_mean_group',
#        'temp_delta_vs_all_stations', 'Средняя температура воздуха_lag_3',
#        'Количество осадков_lag_3', 'Горизонтальная дальность видимости_lag_3',
#        'Общее количество облачности_lag_3',
#        'Количество облачности нижнего яруса_lag_3',
#        'Форма облаков верхнего яруса_lag_3',
#        'Форма облаков среднего яруса_lag_3',
#        'Форма облаков вертикального развития_lag_3',
#        'Слоистые и слоисто_кучевые облака_lag_3',
#        'Слоисто_дождразорванно_дождевые облака_lag_3',
#        'Высота нижней границы облачности_lag_3', 'Погода между сроками_lag_3',
#        'Погода в срок наблюдения_lag_3', 'Направление ветра_lag_3',
#        'Средняя скорость ветра_lag_3', 'Максимальная скорость ветра_lag_3',
#        'Сумма осадков_lag_3', 'Температура поверхности почвы_lag_3',
#        'Парциальное давление водяного пара_lag_3',
#        'Относительная влажность воздуха_lag_3',
#        'Дефицит насыщения водяного пара_lag_3',
#        'Атмосферное давление на уровне станции_lag_3',
#        'Атмосферное давление на уровне моря_lag_3',
#        'Характеристика барической тенденции_lag_3',
#        'Величина барической тенденции_lag_3'],
#       dtype='object')

# %% [markdown]
# ## Функции оценки точности

# %% [markdown]
# ### Стандартные методы

# %%
def simple_metric(y_val, y_pred):
    mae = mean_absolute_error(y_val, y_pred)
    mse = mean_squared_error(y_val, y_pred)
    rmse = np.sqrt(mse)
    mape = np.mean(np.abs((y_val - y_pred) / y_val)) * 100
    r2 = r2_score(y_val, y_pred)

    print("Простые метрики:")
    print(f"MAE: {mae:.4f}")
    print(f"MSE: {mse:.4f}")
    print(f"RMSE: {rmse:.4f}")
    print(f"MAPE: {mape:.2f}%")
    print(f"R²: {r2:.4f}")
    return {
        'MAE': mae,
        'MSE': mse,
        'RMSE': rmse,
        'MAPE': mape,
        'R2': r2
    }

# %% [markdown]
# ### Ошибки по дням

# %%
def daily_metrics(df_val, y_pred, date_col='date',
                  y_true_col='Средняя температура воздуха', y_pred_col='prediction'):
    df_val['prediction'] = y_pred
    results = []

    for date, group in df_val.groupby(date_col):
        y_true = group[y_true_col].values
        y_pred = group[y_pred_col].values

        mae = mean_absolute_error(y_true, y_pred)
        rmse = np.sqrt(mean_squared_error(y_true, y_pred))
        r2 = r2_score(y_true, y_pred)

        results.append({
            'date': date,
            'MAE': mae,
            'RMSE': rmse,
            'R2': r2
        })

    return pd.DataFrame(results).sort_values('date')

# %% [markdown]
# ### Столбчатые диаграммы ошибок по индексам

# %%
def metrics_per_index(df_val, y_pred, index_col='Индекс ВМО',
                      y_true_col='Средняя температура воздуха', y_pred_col='prediction'):
    """
    df_val: DataFrame с колонками y_true и индекс
    y_pred: массив предсказаний
    """
    df_val = df_val.copy()
    df_val[y_pred_col] = y_pred

    metrics_list = []

    for idx, group in df_val.groupby(index_col):
        y_true = group[y_true_col].values
        y_p = group[y_pred_col].values

        mae = mean_absolute_error(y_true, y_p)
        rmse = np.sqrt(mean_squared_error(y_true, y_p))
        r2 = r2_score(y_true, y_p)

        metrics_list.append({
            index_col: idx,
            'MAE': mae,
            'RMSE': rmse,
            'R2': r2
        })

    metrics_df = pd.DataFrame(metrics_list).sort_values(index_col)

    # Строим графики
    fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharex=True)

    axes[0].bar(metrics_df[index_col].astype(str), metrics_df['MAE'], color='skyblue')
    axes[0].set_title('MAE по индексам')
    axes[0].set_ylabel('MAE (°C)')

    axes[1].bar(metrics_df[index_col].astype(str), metrics_df['RMSE'], color='salmon')
    axes[1].set_title('RMSE по индексам')
    axes[1].set_ylabel('RMSE (°C)')

    axes[2].bar(metrics_df[index_col].astype(str), metrics_df['R2'], color='lightgreen')
    axes[2].set_title('R² по индексам')
    axes[2].set_ylabel('R²')

    for ax in axes:
        ax.set_xlabel('Индекс ВМО')
        ax.tick_params(axis='x', rotation=45)

    plt.tight_layout()
    plt.show()

    return metrics_df

# %% [markdown]
# ### Линейный график MAE

# %%
def cumulative_mae(df_val, y_pred, date_col='date',
                   y_true_col='Средняя температура воздуха', y_pred_col='prediction'):
    """
    df_val: DataFrame с колонками y_true и date
    y_pred: массив предсказаний
    """
    df_val = df_val.copy()
    df_val[y_pred_col] = y_pred

    # Сортируем по дате
    df_val = df_val.sort_values(date_col)

    # Копим MAE по дням
    cum_errors = []
    all_true = []
    all_pred = []

    for date, group in df_val.groupby(date_col):
        all_true.extend(group[y_true_col].values)
        all_pred.extend(group[y_pred_col].values)

        mae = mean_absolute_error(all_true, all_pred)
        cum_errors.append({'date': date, 'Cumulative_MAE': mae})

    cum_df = pd.DataFrame(cum_errors)

    # График
    plt.figure(figsize=(12, 5))
    plt.plot(cum_df['date'], cum_df['Cumulative_MAE'], marker='o', linestyle='-')
    plt.xlabel('Дата')
    plt.ylabel('MAE (°C)')
    plt.title('MAE по дням')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.show()

    return cum_df

# %% [markdown]
# ### Накопление ошибки Mae

# %%
def cumulative_error(df_val, y_pred, date_col='date',
                     y_true_col='Средняя температура воздуха', y_pred_col='prediction'):
    df_val = df_val.copy()
    df_val[y_pred_col] = y_pred

    df_val = df_val.sort_values(date_col)

    cum_errors = []
    total_error = 0

    for date, group in df_val.groupby(date_col):
        daily_error = (group[y_true_col] - group[y_pred_col]).abs().sum()
        total_error += daily_error

        cum_errors.append({'date': date, 'Cumulative_Error': total_error})

    cum_df = pd.DataFrame(cum_errors)

    # График
    plt.figure(figsize=(12, 5))
    plt.plot(cum_df['date'], cum_df['Cumulative_Error'], marker='o')
    plt.xlabel('Дата')
    plt.ylabel('Накопленная ошибка')
    plt.title('Накопление абсолютной ошибки по дням')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.show()

    return cum_df

# %% [markdown]
# ### Сравнения истинной средней и предсказанной средней

# %%
def plot_true_vs_pred(df_val, y_pred, date_col='date', y_true_col='Средняя температура воздуха'):
    df_plot = df_val.copy()
    df_plot['prediction'] = y_pred

    # Усредняем по индексам
    daily_true = df_plot.groupby(date_col)[y_true_col].mean()
    daily_pred = df_plot.groupby(date_col)['prediction'].mean()

    plt.figure(figsize=(12, 6))
    plt.plot(daily_true.index, daily_true.values, label='Истинная температура', marker='o', linestyle='-', color='blue')
    plt.plot(daily_pred.index, daily_pred.values, label='Предсказанная температура', marker='x', linestyle='--',
             color='orange')
    plt.xlabel('Дата')
    plt.ylabel('Температура (°C)')
    plt.title('Сравнение истинной и предсказанной температуры')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Сравнение истинной и предсказанной по индексам

# %%
def plot_true_vs_pred_by_index(df_val, y_pred, date_col='date', index_col='Индекс ВМО',
                               y_true_col='Средняя температура воздуха'):
    df_plot = df_val.copy()
    df_plot['prediction'] = y_pred

    indices = df_plot[index_col].unique()
    n_indices = len(indices)

    # Определяем размер подграфиков (по 2 в ряду)
    n_cols = 2
    n_rows = (n_indices + 1) // n_cols

    fig, axes = plt.subplots(n_rows, n_cols, figsize=(14, n_rows * 3), sharex=True, sharey=True)
    axes = axes.flatten()

    for i, idx in enumerate(indices):
        ax = axes[i]
        df_idx = df_plot[df_plot[index_col] == idx]
        ax.plot(df_idx[date_col], df_idx[y_true_col], label='Истинная', marker='o', linestyle='-', color='blue')
        ax.plot(df_idx[date_col], df_idx['prediction'], label='Предсказанная', marker='x', linestyle='--',
                color='orange')
        ax.set_title(f'Индекс ВМО: {idx}')
        ax.grid(True, linestyle='--', alpha=0.5)
        if i % n_cols == 0:
            ax.set_ylabel('Температура (°C)')
        ax.legend(fontsize=8)

    # Скрываем лишние пустые графики
    for j in range(i + 1, len(axes)):
        axes[j].axis('off')

    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Предсказательные модели

# %% [markdown]
# ### XGBRegressor

# %%
# Создаем DMatrix для XGBoost
dtrain = xgb.DMatrix(X_train, label=y_train)
dval = xgb.DMatrix(X_val, label=y_val)

# Параметры модели
params = {
    'objective': 'reg:squarederror',  # регрессия
    'eval_metric': 'rmse',
    'eta': 0.1,  # learning rate
    'max_depth': 6,  # глубина деревьев
    'subsample': 0.8,  # случайная подвыборка для предотвращения переобучения
    'colsample_bytree': 0.8,
    'seed': 42
}

# Обучение с ранней остановкой
evals = [(dtrain, 'train'), (dval, 'validation')]
xgb_model = xgb.train(
    params,
    dtrain,
    num_boost_round=500,
    evals=evals,
    early_stopping_rounds=20,
    verbose_eval=50
)

# Предсказание на валидации
y_pred = xgb_model.predict(dval)
xgb_result = simple_metric(y_val, y_pred)
xgb_result
# Out:
# [0]	train-rmse:11.52517	validation-rmse:11.25046
# [50]	train-rmse:3.76811	validation-rmse:2.57196
# [65]	train-rmse:3.69132	validation-rmse:2.57095
# Простые метрики:
# MAE: 2.0819
# MSE: 6.6098
# RMSE: 2.5710
# MAPE: 12.46%
# R²: 0.5041
# {'MAE': 2.0818540334701536,
#  'MSE': 6.609804720953739,
#  'RMSE': np.float64(2.5709540487830074),
#  'MAPE': np.float64(12.458366310336475),
#  'R2': 0.5041016451394047}

# %% [markdown]
# ### LightGBM

# %%
train_data = lgb.Dataset(X_train, label=y_train)
val_data = lgb.Dataset(X_val, label=y_val)

# Параметры (максимально близко к XGBoost)
params = {
    'objective': 'regression',  # аналог reg:squarederror
    'metric': 'rmse',
    'learning_rate': 0.1,  # eta
    'max_depth': 6,
    'feature_fraction': 0.8,  # colsample_bytree
    'bagging_fraction': 0.8,  # subsample
    'bagging_freq': 1,
    'seed': 42,
    'verbosity': -1
}

# Обучение с early stopping
model = lgb.train(
    params,
    train_data,
    num_boost_round=500,
    valid_sets=[train_data, val_data],
    valid_names=['train', 'validation'],
    callbacks=[
        lgb.early_stopping(stopping_rounds=20),
        lgb.log_evaluation(period=50)
    ]
)

# Предсказание
y_pred = model.predict(X_val, num_iteration=model.best_iteration)

# Метрика
lgb_result = simple_metric(y_val, y_pred)
lgb_result
# Out:
# Training until validation scores don't improve for 20 rounds
# [50]	train's rmse: 3.90192	validation's rmse: 2.48698
# Early stopping, best iteration is:
# [42]	train's rmse: 3.94978	validation's rmse: 2.48314
# Простые метрики:
# MAE: 1.9743
# MSE: 6.1660
# RMSE: 2.4831
# MAPE: 11.98%
# R²: 0.5374
# {'MAE': 1.974349170211896,
#  'MSE': 6.165977132692343,
#  'RMSE': np.float64(2.4831385649400124),
#  'MAPE': np.float64(11.980799007885786),
#  'R2': 0.5373996592490884}

# %% [markdown]
# ### HistGradientBoostingRegressor

# %%
model = HistGradientBoostingRegressor(
    loss='squared_error',
    learning_rate=0.1,
    max_depth=6,
    max_iter=500,
    max_bins=255,
    early_stopping=True,
    n_iter_no_change=20,
    validation_fraction=0.2,  # ← ВАЖНО
    random_state=42,
    verbose=1
)

model.fit(X_train, y_train)

y_pred = model.predict(X_val)

hist_result = simple_metric(y_val, y_pred)
hist_result
# Out:
# Binning 0.039 GB of training data: 0.187 s
# Binning 0.010 GB of validation data: 0.018 s
# Fitting gradient boosted rounds:
# Fit 500 trees in 10.843 s, (15488 total leaves)
# Time spent computing histograms: 4.636s
# Time spent finding best splits:  2.059s
# Time spent applying splits:      2.120s
# Time spent predicting:           0.172s
# Простые метрики:
# MAE: 2.1520
# MSE: 7.1914
# RMSE: 2.6817
# MAPE: 13.32%
# R²: 0.4605
# {'MAE': 2.1519812703258983,
#  'MSE': 7.191397087627087,
#  'RMSE': np.float64(2.68167803578787),
#  'MAPE': np.float64(13.31773566798292),
#  'R2': 0.4604678753067645}

# %% [markdown]
# ### CatBoostRegressor

# %%
# Модель (параметры максимально близки к XGBoost)
model = CatBoostRegressor(
    loss_function='RMSE',
    learning_rate=0.1,
    depth=6,
    iterations=500,
    subsample=0.8,
    rsm=0.8,
    random_seed=42,
    verbose=50
)

# Обучение с early stopping
model.fit(
    X_train, y_train,
    eval_set=(X_val, y_val),
    early_stopping_rounds=20,
    use_best_model=True
)

# Предсказание
y_pred = model.predict(X_val)

# Метрика
cat_result = simple_metric(y_val, y_pred)
cat_result
# Out:
# 0:	learn: 11.5821584	test: 11.4307352	best: 11.4307352 (0)	total: 18.9ms	remaining: 9.42s
# 50:	learn: 4.1185765	test: 2.5847762	best: 2.5828597 (49)	total: 962ms	remaining: 8.47s
# 100:	learn: 3.9978471	test: 2.5617036	best: 2.5485364 (96)	total: 1.81s	remaining: 7.17s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 2.532229035
# bestIteration = 128
#
# Shrink model to first 129 iterations.
# Простые метрики:
# MAE: 2.0380
# MSE: 6.4122
# RMSE: 2.5322
# MAPE: 12.28%
# R²: 0.5189
# {'MAE': 2.0380010393383796,
#  'MSE': 6.412183933484753,
#  'RMSE': np.float64(2.5322290444359004),
#  'MAPE': np.float64(12.2831139269853),
#  'R2': 0.5189280776180308}

# %% [markdown]
# ## Результаты

# %%
results = []

if 'xgb_result' in globals():
    results.append({'model': 'XGBoost', **xgb_result})

if 'lgb_result' in globals():
    results.append({'model': 'LightGBM', **lgb_result})

if 'hist_result' in globals():
    results.append({'model': 'HistGB', **hist_result})

if 'cat_result' in globals():
    results.append({'model': 'CatBoost', **cat_result})


df_results = pd.DataFrame(results)
df_results = df_results.sort_values(by='MAE').reset_index(drop=True)

df_results
# Out:
#       model       MAE       MSE      RMSE       MAPE        R2
# 0  LightGBM  1.974349  6.165977  2.483139  11.980799  0.537400
# 1  CatBoost  2.038001  6.412184  2.532229  12.283114  0.518928
# 2   XGBoost  2.081854  6.609805  2.570954  12.458366  0.504102
# 3    HistGB  2.151981  7.191397  2.681678  13.317736  0.460468

# %% [markdown]
# ## Подбор параметров

# %%
param_grid = {
    'learning_rate': [0.03, 0.05, 0.1],
    'max_depth': [4, 6, 8],
    'min_data_in_leaf': [20, 50],
    'feature_fraction': [0.7, 0.8],
    'bagging_fraction': [0.7, 0.8],
    'min_gain_to_split': [0, 0.1]
}

keys, values = zip(*param_grid.items())
param_combinations = [dict(zip(keys, v)) for v in itertools.product(*values)]

best_score = float('inf')
best_params = None
best_model = None

for i, params_update in enumerate(param_combinations):
    print(f"\n🔹 Iteration {i+1}/{len(param_combinations)}")

    params = {
        'objective': 'regression',
        'metric': 'rmse',
        'seed': 42,
        'verbosity': -1,
        **params_update
    }

    model = lgb.train(
        params,
        train_data,
        num_boost_round=500,
        valid_sets=[val_data],
        valid_names=['validation'],
        callbacks=[
            lgb.early_stopping(stopping_rounds=20),
            lgb.log_evaluation(0)
        ]
    )

    y_pred = model.predict(X_val, num_iteration=model.best_iteration)
    score = simple_metric(y_val, y_pred)['MAE']

    print(f"Score: {score}")
    print(f"Params: {params_update}")

    if score < best_score:
        best_score = score
        best_params = params
        best_model = model

print("\nBEST RESULT")
print("Score:", best_score)
print("Params:", best_params)
# Out:
# 🔹 Iteration 1/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [179]	validation's rmse: 2.52545
# Простые метрики:
# MAE: 2.0280
# MSE: 6.3779
# RMSE: 2.5255
# MAPE: 12.32%
# R²: 0.5215
# Score: 2.0280471310027406
# Params: {'learning_rate': 0.03, 'max_depth': 4, 'min_data_in_leaf': 20, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'min_gain_to_split': 0}
#
# 🔹 Iteration 2/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [179]	validation's rmse: 2.52545
# Простые метрики:
# MAE: 2.0280
# MSE: 6.3779
# RMSE: 2.5255
# MAPE: 12.32%
# R²: 0.5215
# Score: 2.0280471310027406
# Params: {'learning_rate': 0.03, 'max_depth': 4, 'min_data_in_leaf': 20, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 3/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [179]	validation's rmse: 2.52545
# Простые метрики:
# MAE: 2.0280
# MSE: 6.3779
# RMSE: 2.5255
# MAPE: 12.32%
# R²: 0.5215
# Score: 2.0280471310027406
# Params: {'learning_rate': 0.03, 'max_depth': 4, 'min_data_in_leaf': 20, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'min_gain_to_split': 0}
#
# 🔹 Iteration 4/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [179]	validation's rmse: 2.52545
# Простые метрики:
# MAE: 2.0280
# MSE: 6.3779
# RMSE: 2.5255
# MAPE: 12.32%
# R²: 0.5215
# Score: 2.0280471310027406
# Params: {'learning_rate': 0.03, 'max_depth': 4, 'min_data_in_leaf': 20, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 5/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [156]	validation's rmse: 2.55793
# Простые метрики:
# MAE: 2.0665
# MSE: 6.5430
# RMSE: 2.5579
# MAPE: 12.49%
# R²: 0.5091
# Score: 2.0664748319457535
# Params: {'learning_rate': 0.03, 'max_depth': 4, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.7, 'min_gain_to_split': 0}
#
# 🔹 Iteration 6/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [156]	validation's rmse: 2.55793
# Простые метрики:
# MAE: 2.0665
# MSE: 6.5430
# RMSE: 2.5579
# MAPE: 12.49%
# R²: 0.5091
# Score: 2.0664748319457535
# Params: {'learning_rate': 0.03, 'max_depth': 4, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.7, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 7/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [156]	validation's rmse: 2.55793
# Простые метрики:
# MAE: 2.0665
# MSE: 6.5430
# RMSE: 2.5579
# MAPE: 12.49%
# R²: 0.5091
# Score: 2.0664748319457535
# Params: {'learning_rate': 0.03, 'max_depth': 4, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'min_gain_to_split': 0}
#
# 🔹 Iteration 8/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [156]	validation's rmse: 2.55793
# Простые метрики:
# MAE: 2.0665
# MSE: 6.5430
# RMSE: 2.5579
# MAPE: 12.49%
# R²: 0.5091
# Score: 2.0664748319457535
# Params: {'learning_rate': 0.03, 'max_depth': 4, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 9/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [176]	validation's rmse: 2.54088
# Простые метрики:
# MAE: 2.0403
# MSE: 6.4561
# RMSE: 2.5409
# MAPE: 12.41%
# R²: 0.5156
# Score: 2.040283729265758
# Params: {'learning_rate': 0.03, 'max_depth': 4, 'min_data_in_leaf': 50, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'min_gain_to_split': 0}
#
# 🔹 Iteration 10/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [176]	validation's rmse: 2.54088
# Простые метрики:
# MAE: 2.0403
# MSE: 6.4561
# RMSE: 2.5409
# MAPE: 12.41%
# R²: 0.5156
# Score: 2.040283729265758
# Params: {'learning_rate': 0.03, 'max_depth': 4, 'min_data_in_leaf': 50, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 11/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [176]	validation's rmse: 2.54088
# Простые метрики:
# MAE: 2.0403
# MSE: 6.4561
# RMSE: 2.5409
# MAPE: 12.41%
# R²: 0.5156
# Score: 2.040283729265758
# Params: {'learning_rate': 0.03, 'max_depth': 4, 'min_data_in_leaf': 50, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'min_gain_to_split': 0}
#
# 🔹 Iteration 12/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [176]	validation's rmse: 2.54088
# Простые метрики:
# MAE: 2.0403
# MSE: 6.4561
# RMSE: 2.5409
# MAPE: 12.41%
# R²: 0.5156
# Score: 2.040283729265758
# Params: {'learning_rate': 0.03, 'max_depth': 4, 'min_data_in_leaf': 50, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 13/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [179]	validation's rmse: 2.53763
# Простые метрики:
# MAE: 2.0381
# MSE: 6.4396
# RMSE: 2.5376
# MAPE: 12.38%
# R²: 0.5169
# Score: 2.0380936859987364
# Params: {'learning_rate': 0.03, 'max_depth': 4, 'min_data_in_leaf': 50, 'feature_fraction': 0.8, 'bagging_fraction': 0.7, 'min_gain_to_split': 0}
#
# 🔹 Iteration 14/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [179]	validation's rmse: 2.53763
# Простые метрики:
# MAE: 2.0381
# MSE: 6.4396
# RMSE: 2.5376
# MAPE: 12.38%
# R²: 0.5169
# Score: 2.0380936859987364
# Params: {'learning_rate': 0.03, 'max_depth': 4, 'min_data_in_leaf': 50, 'feature_fraction': 0.8, 'bagging_fraction': 0.7, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 15/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [179]	validation's rmse: 2.53763
# Простые метрики:
# MAE: 2.0381
# MSE: 6.4396
# RMSE: 2.5376
# MAPE: 12.38%
# R²: 0.5169
# Score: 2.0380936859987364
# Params: {'learning_rate': 0.03, 'max_depth': 4, 'min_data_in_leaf': 50, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'min_gain_to_split': 0}
#
# 🔹 Iteration 16/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [179]	validation's rmse: 2.53763
# Простые метрики:
# MAE: 2.0381
# MSE: 6.4396
# RMSE: 2.5376
# MAPE: 12.38%
# R²: 0.5169
# Score: 2.0380936859987364
# Params: {'learning_rate': 0.03, 'max_depth': 4, 'min_data_in_leaf': 50, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 17/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [177]	validation's rmse: 2.51122
# Простые метрики:
# MAE: 2.0039
# MSE: 6.3062
# RMSE: 2.5112
# MAPE: 12.19%
# R²: 0.5269
# Score: 2.003863200116703
# Params: {'learning_rate': 0.03, 'max_depth': 6, 'min_data_in_leaf': 20, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'min_gain_to_split': 0}
#
# 🔹 Iteration 18/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [177]	validation's rmse: 2.51122
# Простые метрики:
# MAE: 2.0039
# MSE: 6.3062
# RMSE: 2.5112
# MAPE: 12.19%
# R²: 0.5269
# Score: 2.003863200116703
# Params: {'learning_rate': 0.03, 'max_depth': 6, 'min_data_in_leaf': 20, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 19/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [177]	validation's rmse: 2.51122
# Простые метрики:
# MAE: 2.0039
# MSE: 6.3062
# RMSE: 2.5112
# MAPE: 12.19%
# R²: 0.5269
# Score: 2.003863200116703
# Params: {'learning_rate': 0.03, 'max_depth': 6, 'min_data_in_leaf': 20, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'min_gain_to_split': 0}
#
# 🔹 Iteration 20/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [177]	validation's rmse: 2.51122
# Простые метрики:
# MAE: 2.0039
# MSE: 6.3062
# RMSE: 2.5112
# MAPE: 12.19%
# R²: 0.5269
# Score: 2.003863200116703
# Params: {'learning_rate': 0.03, 'max_depth': 6, 'min_data_in_leaf': 20, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 21/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [161]	validation's rmse: 2.48686
# Простые метрики:
# MAE: 1.9917
# MSE: 6.1844
# RMSE: 2.4869
# MAPE: 12.05%
# R²: 0.5360
# Score: 1.9917212834331772
# Params: {'learning_rate': 0.03, 'max_depth': 6, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.7, 'min_gain_to_split': 0}
#
# 🔹 Iteration 22/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [161]	validation's rmse: 2.48686
# Простые метрики:
# MAE: 1.9917
# MSE: 6.1844
# RMSE: 2.4869
# MAPE: 12.05%
# R²: 0.5360
# Score: 1.9917212834331772
# Params: {'learning_rate': 0.03, 'max_depth': 6, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.7, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 23/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [161]	validation's rmse: 2.48686
# Простые метрики:
# MAE: 1.9917
# MSE: 6.1844
# RMSE: 2.4869
# MAPE: 12.05%
# R²: 0.5360
# Score: 1.9917212834331772
# Params: {'learning_rate': 0.03, 'max_depth': 6, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'min_gain_to_split': 0}
#
# 🔹 Iteration 24/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [161]	validation's rmse: 2.48686
# Простые метрики:
# MAE: 1.9917
# MSE: 6.1844
# RMSE: 2.4869
# MAPE: 12.05%
# R²: 0.5360
# Score: 1.9917212834331772
# Params: {'learning_rate': 0.03, 'max_depth': 6, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 25/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [241]	validation's rmse: 2.47974
# Простые метрики:
# MAE: 1.9727
# MSE: 6.1491
# RMSE: 2.4797
# MAPE: 12.02%
# R²: 0.5387
# Score: 1.9727415456342148
# Params: {'learning_rate': 0.03, 'max_depth': 6, 'min_data_in_leaf': 50, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'min_gain_to_split': 0}
#
# 🔹 Iteration 26/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [182]	validation's rmse: 2.49069
# Простые метрики:
# MAE: 1.9855
# MSE: 6.2036
# RMSE: 2.4907
# MAPE: 12.07%
# R²: 0.5346
# Score: 1.9855037313926462
# Params: {'learning_rate': 0.03, 'max_depth': 6, 'min_data_in_leaf': 50, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 27/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [241]	validation's rmse: 2.47974
# Простые метрики:
# MAE: 1.9727
# MSE: 6.1491
# RMSE: 2.4797
# MAPE: 12.02%
# R²: 0.5387
# Score: 1.9727415456342148
# Params: {'learning_rate': 0.03, 'max_depth': 6, 'min_data_in_leaf': 50, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'min_gain_to_split': 0}
#
# 🔹 Iteration 28/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [182]	validation's rmse: 2.49069
# Простые метрики:
# MAE: 1.9855
# MSE: 6.2036
# RMSE: 2.4907
# MAPE: 12.07%
# R²: 0.5346
# Score: 1.9855037313926462
# Params: {'learning_rate': 0.03, 'max_depth': 6, 'min_data_in_leaf': 50, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 29/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [177]	validation's rmse: 2.49775
# Простые метрики:
# MAE: 1.9905
# MSE: 6.2388
# RMSE: 2.4977
# MAPE: 12.12%
# R²: 0.5319
# Score: 1.9905446591575309
# Params: {'learning_rate': 0.03, 'max_depth': 6, 'min_data_in_leaf': 50, 'feature_fraction': 0.8, 'bagging_fraction': 0.7, 'min_gain_to_split': 0}
#
# 🔹 Iteration 30/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [177]	validation's rmse: 2.49775
# Простые метрики:
# MAE: 1.9905
# MSE: 6.2388
# RMSE: 2.4977
# MAPE: 12.12%
# R²: 0.5319
# Score: 1.9905446591575309
# Params: {'learning_rate': 0.03, 'max_depth': 6, 'min_data_in_leaf': 50, 'feature_fraction': 0.8, 'bagging_fraction': 0.7, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 31/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [177]	validation's rmse: 2.49775
# Простые метрики:
# MAE: 1.9905
# MSE: 6.2388
# RMSE: 2.4977
# MAPE: 12.12%
# R²: 0.5319
# Score: 1.9905446591575309
# Params: {'learning_rate': 0.03, 'max_depth': 6, 'min_data_in_leaf': 50, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'min_gain_to_split': 0}
#
# 🔹 Iteration 32/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [177]	validation's rmse: 2.49775
# Простые метрики:
# MAE: 1.9905
# MSE: 6.2388
# RMSE: 2.4977
# MAPE: 12.12%
# R²: 0.5319
# Score: 1.9905446591575309
# Params: {'learning_rate': 0.03, 'max_depth': 6, 'min_data_in_leaf': 50, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 33/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [138]	validation's rmse: 2.50624
# Простые метрики:
# MAE: 2.0072
# MSE: 6.2812
# RMSE: 2.5062
# MAPE: 12.12%
# R²: 0.5288
# Score: 2.00720478581281
# Params: {'learning_rate': 0.03, 'max_depth': 8, 'min_data_in_leaf': 20, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'min_gain_to_split': 0}
#
# 🔹 Iteration 34/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [138]	validation's rmse: 2.50624
# Простые метрики:
# MAE: 2.0072
# MSE: 6.2812
# RMSE: 2.5062
# MAPE: 12.12%
# R²: 0.5288
# Score: 2.00720478581281
# Params: {'learning_rate': 0.03, 'max_depth': 8, 'min_data_in_leaf': 20, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 35/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [138]	validation's rmse: 2.50624
# Простые метрики:
# MAE: 2.0072
# MSE: 6.2812
# RMSE: 2.5062
# MAPE: 12.12%
# R²: 0.5288
# Score: 2.00720478581281
# Params: {'learning_rate': 0.03, 'max_depth': 8, 'min_data_in_leaf': 20, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'min_gain_to_split': 0}
#
# 🔹 Iteration 36/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [138]	validation's rmse: 2.50624
# Простые метрики:
# MAE: 2.0072
# MSE: 6.2812
# RMSE: 2.5062
# MAPE: 12.12%
# R²: 0.5288
# Score: 2.00720478581281
# Params: {'learning_rate': 0.03, 'max_depth': 8, 'min_data_in_leaf': 20, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 37/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [136]	validation's rmse: 2.52597
# Простые метрики:
# MAE: 2.0255
# MSE: 6.3805
# RMSE: 2.5260
# MAPE: 12.18%
# R²: 0.5213
# Score: 2.025505435393644
# Params: {'learning_rate': 0.03, 'max_depth': 8, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.7, 'min_gain_to_split': 0}
#
# 🔹 Iteration 38/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [136]	validation's rmse: 2.52597
# Простые метрики:
# MAE: 2.0255
# MSE: 6.3805
# RMSE: 2.5260
# MAPE: 12.18%
# R²: 0.5213
# Score: 2.025505435393644
# Params: {'learning_rate': 0.03, 'max_depth': 8, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.7, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 39/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [136]	validation's rmse: 2.52597
# Простые метрики:
# MAE: 2.0255
# MSE: 6.3805
# RMSE: 2.5260
# MAPE: 12.18%
# R²: 0.5213
# Score: 2.025505435393644
# Params: {'learning_rate': 0.03, 'max_depth': 8, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'min_gain_to_split': 0}
#
# 🔹 Iteration 40/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [136]	validation's rmse: 2.52597
# Простые метрики:
# MAE: 2.0255
# MSE: 6.3805
# RMSE: 2.5260
# MAPE: 12.18%
# R²: 0.5213
# Score: 2.025505435393644
# Params: {'learning_rate': 0.03, 'max_depth': 8, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 41/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [149]	validation's rmse: 2.48757
# Простые метрики:
# MAE: 1.9806
# MSE: 6.1880
# RMSE: 2.4876
# MAPE: 12.04%
# R²: 0.5357
# Score: 1.9806487619220625
# Params: {'learning_rate': 0.03, 'max_depth': 8, 'min_data_in_leaf': 50, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'min_gain_to_split': 0}
#
# 🔹 Iteration 42/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [149]	validation's rmse: 2.48757
# Простые метрики:
# MAE: 1.9806
# MSE: 6.1880
# RMSE: 2.4876
# MAPE: 12.04%
# R²: 0.5357
# Score: 1.9806487619220625
# Params: {'learning_rate': 0.03, 'max_depth': 8, 'min_data_in_leaf': 50, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 43/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [149]	validation's rmse: 2.48757
# Простые метрики:
# MAE: 1.9806
# MSE: 6.1880
# RMSE: 2.4876
# MAPE: 12.04%
# R²: 0.5357
# Score: 1.9806487619220625
# Params: {'learning_rate': 0.03, 'max_depth': 8, 'min_data_in_leaf': 50, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'min_gain_to_split': 0}
#
# 🔹 Iteration 44/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [149]	validation's rmse: 2.48757
# Простые метрики:
# MAE: 1.9806
# MSE: 6.1880
# RMSE: 2.4876
# MAPE: 12.04%
# R²: 0.5357
# Score: 1.9806487619220625
# Params: {'learning_rate': 0.03, 'max_depth': 8, 'min_data_in_leaf': 50, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 45/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [169]	validation's rmse: 2.51856
# Простые метрики:
# MAE: 2.0011
# MSE: 6.3431
# RMSE: 2.5186
# MAPE: 12.21%
# R²: 0.5241
# Score: 2.0011358679263727
# Params: {'learning_rate': 0.03, 'max_depth': 8, 'min_data_in_leaf': 50, 'feature_fraction': 0.8, 'bagging_fraction': 0.7, 'min_gain_to_split': 0}
#
# 🔹 Iteration 46/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [169]	validation's rmse: 2.51856
# Простые метрики:
# MAE: 2.0011
# MSE: 6.3431
# RMSE: 2.5186
# MAPE: 12.21%
# R²: 0.5241
# Score: 2.0011358679263727
# Params: {'learning_rate': 0.03, 'max_depth': 8, 'min_data_in_leaf': 50, 'feature_fraction': 0.8, 'bagging_fraction': 0.7, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 47/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [169]	validation's rmse: 2.51856
# Простые метрики:
# MAE: 2.0011
# MSE: 6.3431
# RMSE: 2.5186
# MAPE: 12.21%
# R²: 0.5241
# Score: 2.0011358679263727
# Params: {'learning_rate': 0.03, 'max_depth': 8, 'min_data_in_leaf': 50, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'min_gain_to_split': 0}
#
# 🔹 Iteration 48/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [169]	validation's rmse: 2.51856
# Простые метрики:
# MAE: 2.0011
# MSE: 6.3431
# RMSE: 2.5186
# MAPE: 12.21%
# R²: 0.5241
# Score: 2.0011358679263727
# Params: {'learning_rate': 0.03, 'max_depth': 8, 'min_data_in_leaf': 50, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 49/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [98]	validation's rmse: 2.53938
# Простые метрики:
# MAE: 2.0343
# MSE: 6.4485
# RMSE: 2.5394
# MAPE: 12.41%
# R²: 0.5162
# Score: 2.034296126971646
# Params: {'learning_rate': 0.05, 'max_depth': 4, 'min_data_in_leaf': 20, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'min_gain_to_split': 0}
#
# 🔹 Iteration 50/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [98]	validation's rmse: 2.53938
# Простые метрики:
# MAE: 2.0343
# MSE: 6.4485
# RMSE: 2.5394
# MAPE: 12.41%
# R²: 0.5162
# Score: 2.034296126971646
# Params: {'learning_rate': 0.05, 'max_depth': 4, 'min_data_in_leaf': 20, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 51/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [98]	validation's rmse: 2.53938
# Простые метрики:
# MAE: 2.0343
# MSE: 6.4485
# RMSE: 2.5394
# MAPE: 12.41%
# R²: 0.5162
# Score: 2.034296126971646
# Params: {'learning_rate': 0.05, 'max_depth': 4, 'min_data_in_leaf': 20, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'min_gain_to_split': 0}
#
# 🔹 Iteration 52/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [98]	validation's rmse: 2.53938
# Простые метрики:
# MAE: 2.0343
# MSE: 6.4485
# RMSE: 2.5394
# MAPE: 12.41%
# R²: 0.5162
# Score: 2.034296126971646
# Params: {'learning_rate': 0.05, 'max_depth': 4, 'min_data_in_leaf': 20, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 53/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [149]	validation's rmse: 2.52413
# Простые метрики:
# MAE: 2.0130
# MSE: 6.3712
# RMSE: 2.5241
# MAPE: 12.30%
# R²: 0.5220
# Score: 2.013013565032557
# Params: {'learning_rate': 0.05, 'max_depth': 4, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.7, 'min_gain_to_split': 0}
#
# 🔹 Iteration 54/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [149]	validation's rmse: 2.52413
# Простые метрики:
# MAE: 2.0130
# MSE: 6.3712
# RMSE: 2.5241
# MAPE: 12.30%
# R²: 0.5220
# Score: 2.013013565032557
# Params: {'learning_rate': 0.05, 'max_depth': 4, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.7, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 55/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [149]	validation's rmse: 2.52413
# Простые метрики:
# MAE: 2.0130
# MSE: 6.3712
# RMSE: 2.5241
# MAPE: 12.30%
# R²: 0.5220
# Score: 2.013013565032557
# Params: {'learning_rate': 0.05, 'max_depth': 4, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'min_gain_to_split': 0}
#
# 🔹 Iteration 56/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [149]	validation's rmse: 2.52413
# Простые метрики:
# MAE: 2.0130
# MSE: 6.3712
# RMSE: 2.5241
# MAPE: 12.30%
# R²: 0.5220
# Score: 2.013013565032557
# Params: {'learning_rate': 0.05, 'max_depth': 4, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 57/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [106]	validation's rmse: 2.53533
# Простые метрики:
# MAE: 2.0261
# MSE: 6.4279
# RMSE: 2.5353
# MAPE: 12.40%
# R²: 0.5177
# Score: 2.026127450094236
# Params: {'learning_rate': 0.05, 'max_depth': 4, 'min_data_in_leaf': 50, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'min_gain_to_split': 0}
#
# 🔹 Iteration 58/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [106]	validation's rmse: 2.53533
# Простые метрики:
# MAE: 2.0261
# MSE: 6.4279
# RMSE: 2.5353
# MAPE: 12.40%
# R²: 0.5177
# Score: 2.026127450094236
# Params: {'learning_rate': 0.05, 'max_depth': 4, 'min_data_in_leaf': 50, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 59/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [106]	validation's rmse: 2.53533
# Простые метрики:
# MAE: 2.0261
# MSE: 6.4279
# RMSE: 2.5353
# MAPE: 12.40%
# R²: 0.5177
# Score: 2.026127450094236
# Params: {'learning_rate': 0.05, 'max_depth': 4, 'min_data_in_leaf': 50, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'min_gain_to_split': 0}
#
# 🔹 Iteration 60/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [106]	validation's rmse: 2.53533
# Простые метрики:
# MAE: 2.0261
# MSE: 6.4279
# RMSE: 2.5353
# MAPE: 12.40%
# R²: 0.5177
# Score: 2.026127450094236
# Params: {'learning_rate': 0.05, 'max_depth': 4, 'min_data_in_leaf': 50, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 61/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [112]	validation's rmse: 2.54458
# Простые метрики:
# MAE: 2.0378
# MSE: 6.4749
# RMSE: 2.5446
# MAPE: 12.40%
# R²: 0.5142
# Score: 2.0378170111016165
# Params: {'learning_rate': 0.05, 'max_depth': 4, 'min_data_in_leaf': 50, 'feature_fraction': 0.8, 'bagging_fraction': 0.7, 'min_gain_to_split': 0}
#
# 🔹 Iteration 62/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [112]	validation's rmse: 2.54458
# Простые метрики:
# MAE: 2.0378
# MSE: 6.4749
# RMSE: 2.5446
# MAPE: 12.40%
# R²: 0.5142
# Score: 2.0378170111016165
# Params: {'learning_rate': 0.05, 'max_depth': 4, 'min_data_in_leaf': 50, 'feature_fraction': 0.8, 'bagging_fraction': 0.7, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 63/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [112]	validation's rmse: 2.54458
# Простые метрики:
# MAE: 2.0378
# MSE: 6.4749
# RMSE: 2.5446
# MAPE: 12.40%
# R²: 0.5142
# Score: 2.0378170111016165
# Params: {'learning_rate': 0.05, 'max_depth': 4, 'min_data_in_leaf': 50, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'min_gain_to_split': 0}
#
# 🔹 Iteration 64/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [112]	validation's rmse: 2.54458
# Простые метрики:
# MAE: 2.0378
# MSE: 6.4749
# RMSE: 2.5446
# MAPE: 12.40%
# R²: 0.5142
# Score: 2.0378170111016165
# Params: {'learning_rate': 0.05, 'max_depth': 4, 'min_data_in_leaf': 50, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 65/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [149]	validation's rmse: 2.45551
# Простые метрики:
# MAE: 1.9724
# MSE: 6.0295
# RMSE: 2.4555
# MAPE: 11.92%
# R²: 0.5476
# Score: 1.9723836831026194
# Params: {'learning_rate': 0.05, 'max_depth': 6, 'min_data_in_leaf': 20, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'min_gain_to_split': 0}
#
# 🔹 Iteration 66/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [149]	validation's rmse: 2.45551
# Простые метрики:
# MAE: 1.9724
# MSE: 6.0295
# RMSE: 2.4555
# MAPE: 11.92%
# R²: 0.5476
# Score: 1.9723836831026194
# Params: {'learning_rate': 0.05, 'max_depth': 6, 'min_data_in_leaf': 20, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 67/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [149]	validation's rmse: 2.45551
# Простые метрики:
# MAE: 1.9724
# MSE: 6.0295
# RMSE: 2.4555
# MAPE: 11.92%
# R²: 0.5476
# Score: 1.9723836831026194
# Params: {'learning_rate': 0.05, 'max_depth': 6, 'min_data_in_leaf': 20, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'min_gain_to_split': 0}
#
# 🔹 Iteration 68/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [149]	validation's rmse: 2.45551
# Простые метрики:
# MAE: 1.9724
# MSE: 6.0295
# RMSE: 2.4555
# MAPE: 11.92%
# R²: 0.5476
# Score: 1.9723836831026194
# Params: {'learning_rate': 0.05, 'max_depth': 6, 'min_data_in_leaf': 20, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 69/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [87]	validation's rmse: 2.50135
# Простые метрики:
# MAE: 1.9937
# MSE: 6.2568
# RMSE: 2.5013
# MAPE: 12.09%
# R²: 0.5306
# Score: 1.993668210493268
# Params: {'learning_rate': 0.05, 'max_depth': 6, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.7, 'min_gain_to_split': 0}
#
# 🔹 Iteration 70/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [87]	validation's rmse: 2.50135
# Простые метрики:
# MAE: 1.9937
# MSE: 6.2568
# RMSE: 2.5013
# MAPE: 12.09%
# R²: 0.5306
# Score: 1.993668210493268
# Params: {'learning_rate': 0.05, 'max_depth': 6, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.7, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 71/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [87]	validation's rmse: 2.50135
# Простые метрики:
# MAE: 1.9937
# MSE: 6.2568
# RMSE: 2.5013
# MAPE: 12.09%
# R²: 0.5306
# Score: 1.993668210493268
# Params: {'learning_rate': 0.05, 'max_depth': 6, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'min_gain_to_split': 0}
#
# 🔹 Iteration 72/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [87]	validation's rmse: 2.50135
# Простые метрики:
# MAE: 1.9937
# MSE: 6.2568
# RMSE: 2.5013
# MAPE: 12.09%
# R²: 0.5306
# Score: 1.993668210493268
# Params: {'learning_rate': 0.05, 'max_depth': 6, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 73/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [86]	validation's rmse: 2.50637
# Простые метрики:
# MAE: 2.0050
# MSE: 6.2819
# RMSE: 2.5064
# MAPE: 12.16%
# R²: 0.5287
# Score: 2.0050330234660896
# Params: {'learning_rate': 0.05, 'max_depth': 6, 'min_data_in_leaf': 50, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'min_gain_to_split': 0}
#
# 🔹 Iteration 74/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [86]	validation's rmse: 2.50637
# Простые метрики:
# MAE: 2.0050
# MSE: 6.2819
# RMSE: 2.5064
# MAPE: 12.16%
# R²: 0.5287
# Score: 2.0050330234660896
# Params: {'learning_rate': 0.05, 'max_depth': 6, 'min_data_in_leaf': 50, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 75/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [86]	validation's rmse: 2.50637
# Простые метрики:
# MAE: 2.0050
# MSE: 6.2819
# RMSE: 2.5064
# MAPE: 12.16%
# R²: 0.5287
# Score: 2.0050330234660896
# Params: {'learning_rate': 0.05, 'max_depth': 6, 'min_data_in_leaf': 50, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'min_gain_to_split': 0}
#
# 🔹 Iteration 76/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [86]	validation's rmse: 2.50637
# Простые метрики:
# MAE: 2.0050
# MSE: 6.2819
# RMSE: 2.5064
# MAPE: 12.16%
# R²: 0.5287
# Score: 2.0050330234660896
# Params: {'learning_rate': 0.05, 'max_depth': 6, 'min_data_in_leaf': 50, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 77/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [97]	validation's rmse: 2.50953
# Простые метрики:
# MAE: 1.9943
# MSE: 6.2977
# RMSE: 2.5095
# MAPE: 12.13%
# R²: 0.5275
# Score: 1.9942975112183718
# Params: {'learning_rate': 0.05, 'max_depth': 6, 'min_data_in_leaf': 50, 'feature_fraction': 0.8, 'bagging_fraction': 0.7, 'min_gain_to_split': 0}
#
# 🔹 Iteration 78/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [97]	validation's rmse: 2.50953
# Простые метрики:
# MAE: 1.9943
# MSE: 6.2977
# RMSE: 2.5095
# MAPE: 12.13%
# R²: 0.5275
# Score: 1.9942975112183718
# Params: {'learning_rate': 0.05, 'max_depth': 6, 'min_data_in_leaf': 50, 'feature_fraction': 0.8, 'bagging_fraction': 0.7, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 79/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [97]	validation's rmse: 2.50953
# Простые метрики:
# MAE: 1.9943
# MSE: 6.2977
# RMSE: 2.5095
# MAPE: 12.13%
# R²: 0.5275
# Score: 1.9942975112183718
# Params: {'learning_rate': 0.05, 'max_depth': 6, 'min_data_in_leaf': 50, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'min_gain_to_split': 0}
#
# 🔹 Iteration 80/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [97]	validation's rmse: 2.50953
# Простые метрики:
# MAE: 1.9943
# MSE: 6.2977
# RMSE: 2.5095
# MAPE: 12.13%
# R²: 0.5275
# Score: 1.9942975112183718
# Params: {'learning_rate': 0.05, 'max_depth': 6, 'min_data_in_leaf': 50, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 81/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [99]	validation's rmse: 2.48324
# Простые метрики:
# MAE: 1.9655
# MSE: 6.1665
# RMSE: 2.4832
# MAPE: 11.99%
# R²: 0.5374
# Score: 1.9654878854164721
# Params: {'learning_rate': 0.05, 'max_depth': 8, 'min_data_in_leaf': 20, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'min_gain_to_split': 0}
#
# 🔹 Iteration 82/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [99]	validation's rmse: 2.48324
# Простые метрики:
# MAE: 1.9655
# MSE: 6.1665
# RMSE: 2.4832
# MAPE: 11.99%
# R²: 0.5374
# Score: 1.9654878854164721
# Params: {'learning_rate': 0.05, 'max_depth': 8, 'min_data_in_leaf': 20, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 83/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [99]	validation's rmse: 2.48324
# Простые метрики:
# MAE: 1.9655
# MSE: 6.1665
# RMSE: 2.4832
# MAPE: 11.99%
# R²: 0.5374
# Score: 1.9654878854164721
# Params: {'learning_rate': 0.05, 'max_depth': 8, 'min_data_in_leaf': 20, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'min_gain_to_split': 0}
#
# 🔹 Iteration 84/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [99]	validation's rmse: 2.48324
# Простые метрики:
# MAE: 1.9655
# MSE: 6.1665
# RMSE: 2.4832
# MAPE: 11.99%
# R²: 0.5374
# Score: 1.9654878854164721
# Params: {'learning_rate': 0.05, 'max_depth': 8, 'min_data_in_leaf': 20, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 85/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [100]	validation's rmse: 2.51446
# Простые метрики:
# MAE: 2.0043
# MSE: 6.3225
# RMSE: 2.5145
# MAPE: 12.19%
# R²: 0.5257
# Score: 2.0043485755921937
# Params: {'learning_rate': 0.05, 'max_depth': 8, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.7, 'min_gain_to_split': 0}
#
# 🔹 Iteration 86/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [100]	validation's rmse: 2.51446
# Простые метрики:
# MAE: 2.0043
# MSE: 6.3225
# RMSE: 2.5145
# MAPE: 12.19%
# R²: 0.5257
# Score: 2.0043485755921937
# Params: {'learning_rate': 0.05, 'max_depth': 8, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.7, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 87/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [100]	validation's rmse: 2.51446
# Простые метрики:
# MAE: 2.0043
# MSE: 6.3225
# RMSE: 2.5145
# MAPE: 12.19%
# R²: 0.5257
# Score: 2.0043485755921937
# Params: {'learning_rate': 0.05, 'max_depth': 8, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'min_gain_to_split': 0}
#
# 🔹 Iteration 88/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [100]	validation's rmse: 2.51446
# Простые метрики:
# MAE: 2.0043
# MSE: 6.3225
# RMSE: 2.5145
# MAPE: 12.19%
# R²: 0.5257
# Score: 2.0043485755921937
# Params: {'learning_rate': 0.05, 'max_depth': 8, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 89/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [101]	validation's rmse: 2.49603
# Простые метрики:
# MAE: 1.9808
# MSE: 6.2302
# RMSE: 2.4960
# MAPE: 12.08%
# R²: 0.5326
# Score: 1.9807945966670732
# Params: {'learning_rate': 0.05, 'max_depth': 8, 'min_data_in_leaf': 50, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'min_gain_to_split': 0}
#
# 🔹 Iteration 90/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [101]	validation's rmse: 2.49603
# Простые метрики:
# MAE: 1.9808
# MSE: 6.2302
# RMSE: 2.4960
# MAPE: 12.08%
# R²: 0.5326
# Score: 1.9807945966670732
# Params: {'learning_rate': 0.05, 'max_depth': 8, 'min_data_in_leaf': 50, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 91/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [101]	validation's rmse: 2.49603
# Простые метрики:
# MAE: 1.9808
# MSE: 6.2302
# RMSE: 2.4960
# MAPE: 12.08%
# R²: 0.5326
# Score: 1.9807945966670732
# Params: {'learning_rate': 0.05, 'max_depth': 8, 'min_data_in_leaf': 50, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'min_gain_to_split': 0}
#
# 🔹 Iteration 92/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [101]	validation's rmse: 2.49603
# Простые метрики:
# MAE: 1.9808
# MSE: 6.2302
# RMSE: 2.4960
# MAPE: 12.08%
# R²: 0.5326
# Score: 1.9807945966670732
# Params: {'learning_rate': 0.05, 'max_depth': 8, 'min_data_in_leaf': 50, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 93/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [82]	validation's rmse: 2.56256
# Простые метрики:
# MAE: 2.0595
# MSE: 6.5667
# RMSE: 2.5626
# MAPE: 12.44%
# R²: 0.5073
# Score: 2.0594746602298133
# Params: {'learning_rate': 0.05, 'max_depth': 8, 'min_data_in_leaf': 50, 'feature_fraction': 0.8, 'bagging_fraction': 0.7, 'min_gain_to_split': 0}
#
# 🔹 Iteration 94/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [82]	validation's rmse: 2.5626
# Простые метрики:
# MAE: 2.0595
# MSE: 6.5669
# RMSE: 2.5626
# MAPE: 12.44%
# R²: 0.5073
# Score: 2.0595197964975456
# Params: {'learning_rate': 0.05, 'max_depth': 8, 'min_data_in_leaf': 50, 'feature_fraction': 0.8, 'bagging_fraction': 0.7, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 95/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [82]	validation's rmse: 2.56256
# Простые метрики:
# MAE: 2.0595
# MSE: 6.5667
# RMSE: 2.5626
# MAPE: 12.44%
# R²: 0.5073
# Score: 2.0594746602298133
# Params: {'learning_rate': 0.05, 'max_depth': 8, 'min_data_in_leaf': 50, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'min_gain_to_split': 0}
#
# 🔹 Iteration 96/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [82]	validation's rmse: 2.5626
# Простые метрики:
# MAE: 2.0595
# MSE: 6.5669
# RMSE: 2.5626
# MAPE: 12.44%
# R²: 0.5073
# Score: 2.0595197964975456
# Params: {'learning_rate': 0.05, 'max_depth': 8, 'min_data_in_leaf': 50, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 97/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [46]	validation's rmse: 2.51857
# Простые метрики:
# MAE: 2.0040
# MSE: 6.3432
# RMSE: 2.5186
# MAPE: 12.30%
# R²: 0.5241
# Score: 2.0040037800639836
# Params: {'learning_rate': 0.1, 'max_depth': 4, 'min_data_in_leaf': 20, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'min_gain_to_split': 0}
#
# 🔹 Iteration 98/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [46]	validation's rmse: 2.51857
# Простые метрики:
# MAE: 2.0040
# MSE: 6.3432
# RMSE: 2.5186
# MAPE: 12.30%
# R²: 0.5241
# Score: 2.0040037800639836
# Params: {'learning_rate': 0.1, 'max_depth': 4, 'min_data_in_leaf': 20, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 99/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [46]	validation's rmse: 2.51857
# Простые метрики:
# MAE: 2.0040
# MSE: 6.3432
# RMSE: 2.5186
# MAPE: 12.30%
# R²: 0.5241
# Score: 2.0040037800639836
# Params: {'learning_rate': 0.1, 'max_depth': 4, 'min_data_in_leaf': 20, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'min_gain_to_split': 0}
#
# 🔹 Iteration 100/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [46]	validation's rmse: 2.51857
# Простые метрики:
# MAE: 2.0040
# MSE: 6.3432
# RMSE: 2.5186
# MAPE: 12.30%
# R²: 0.5241
# Score: 2.0040037800639836
# Params: {'learning_rate': 0.1, 'max_depth': 4, 'min_data_in_leaf': 20, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 101/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [45]	validation's rmse: 2.53802
# Простые метрики:
# MAE: 2.0173
# MSE: 6.4415
# RMSE: 2.5380
# MAPE: 12.37%
# R²: 0.5167
# Score: 2.017270185312312
# Params: {'learning_rate': 0.1, 'max_depth': 4, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.7, 'min_gain_to_split': 0}
#
# 🔹 Iteration 102/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [45]	validation's rmse: 2.53802
# Простые метрики:
# MAE: 2.0173
# MSE: 6.4415
# RMSE: 2.5380
# MAPE: 12.37%
# R²: 0.5167
# Score: 2.017270185312312
# Params: {'learning_rate': 0.1, 'max_depth': 4, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.7, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 103/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [45]	validation's rmse: 2.53802
# Простые метрики:
# MAE: 2.0173
# MSE: 6.4415
# RMSE: 2.5380
# MAPE: 12.37%
# R²: 0.5167
# Score: 2.017270185312312
# Params: {'learning_rate': 0.1, 'max_depth': 4, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'min_gain_to_split': 0}
#
# 🔹 Iteration 104/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [45]	validation's rmse: 2.53802
# Простые метрики:
# MAE: 2.0173
# MSE: 6.4415
# RMSE: 2.5380
# MAPE: 12.37%
# R²: 0.5167
# Score: 2.017270185312312
# Params: {'learning_rate': 0.1, 'max_depth': 4, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 105/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [46]	validation's rmse: 2.51114
# Простые метрики:
# MAE: 2.0038
# MSE: 6.3058
# RMSE: 2.5111
# MAPE: 12.29%
# R²: 0.5269
# Score: 2.003762588332882
# Params: {'learning_rate': 0.1, 'max_depth': 4, 'min_data_in_leaf': 50, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'min_gain_to_split': 0}
#
# 🔹 Iteration 106/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [46]	validation's rmse: 2.51114
# Простые метрики:
# MAE: 2.0038
# MSE: 6.3058
# RMSE: 2.5111
# MAPE: 12.29%
# R²: 0.5269
# Score: 2.003762588332882
# Params: {'learning_rate': 0.1, 'max_depth': 4, 'min_data_in_leaf': 50, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 107/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [46]	validation's rmse: 2.51114
# Простые метрики:
# MAE: 2.0038
# MSE: 6.3058
# RMSE: 2.5111
# MAPE: 12.29%
# R²: 0.5269
# Score: 2.003762588332882
# Params: {'learning_rate': 0.1, 'max_depth': 4, 'min_data_in_leaf': 50, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'min_gain_to_split': 0}
#
# 🔹 Iteration 108/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [46]	validation's rmse: 2.51114
# Простые метрики:
# MAE: 2.0038
# MSE: 6.3058
# RMSE: 2.5111
# MAPE: 12.29%
# R²: 0.5269
# Score: 2.003762588332882
# Params: {'learning_rate': 0.1, 'max_depth': 4, 'min_data_in_leaf': 50, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 109/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [44]	validation's rmse: 2.54277
# Простые метрики:
# MAE: 2.0231
# MSE: 6.4657
# RMSE: 2.5428
# MAPE: 12.39%
# R²: 0.5149
# Score: 2.023105117506184
# Params: {'learning_rate': 0.1, 'max_depth': 4, 'min_data_in_leaf': 50, 'feature_fraction': 0.8, 'bagging_fraction': 0.7, 'min_gain_to_split': 0}
#
# 🔹 Iteration 110/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [44]	validation's rmse: 2.54277
# Простые метрики:
# MAE: 2.0231
# MSE: 6.4657
# RMSE: 2.5428
# MAPE: 12.39%
# R²: 0.5149
# Score: 2.023105117506184
# Params: {'learning_rate': 0.1, 'max_depth': 4, 'min_data_in_leaf': 50, 'feature_fraction': 0.8, 'bagging_fraction': 0.7, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 111/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [44]	validation's rmse: 2.54277
# Простые метрики:
# MAE: 2.0231
# MSE: 6.4657
# RMSE: 2.5428
# MAPE: 12.39%
# R²: 0.5149
# Score: 2.023105117506184
# Params: {'learning_rate': 0.1, 'max_depth': 4, 'min_data_in_leaf': 50, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'min_gain_to_split': 0}
#
# 🔹 Iteration 112/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [44]	validation's rmse: 2.54277
# Простые метрики:
# MAE: 2.0231
# MSE: 6.4657
# RMSE: 2.5428
# MAPE: 12.39%
# R²: 0.5149
# Score: 2.023105117506184
# Params: {'learning_rate': 0.1, 'max_depth': 4, 'min_data_in_leaf': 50, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 113/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [43]	validation's rmse: 2.46845
# Простые метрики:
# MAE: 1.9880
# MSE: 6.0933
# RMSE: 2.4685
# MAPE: 12.12%
# R²: 0.5429
# Score: 1.9880487193685588
# Params: {'learning_rate': 0.1, 'max_depth': 6, 'min_data_in_leaf': 20, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'min_gain_to_split': 0}
#
# 🔹 Iteration 114/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [43]	validation's rmse: 2.46845
# Простые метрики:
# MAE: 1.9880
# MSE: 6.0933
# RMSE: 2.4685
# MAPE: 12.12%
# R²: 0.5429
# Score: 1.9880487193685588
# Params: {'learning_rate': 0.1, 'max_depth': 6, 'min_data_in_leaf': 20, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 115/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [43]	validation's rmse: 2.46845
# Простые метрики:
# MAE: 1.9880
# MSE: 6.0933
# RMSE: 2.4685
# MAPE: 12.12%
# R²: 0.5429
# Score: 1.9880487193685588
# Params: {'learning_rate': 0.1, 'max_depth': 6, 'min_data_in_leaf': 20, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'min_gain_to_split': 0}
#
# 🔹 Iteration 116/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [43]	validation's rmse: 2.46845
# Простые метрики:
# MAE: 1.9880
# MSE: 6.0933
# RMSE: 2.4685
# MAPE: 12.12%
# R²: 0.5429
# Score: 1.9880487193685588
# Params: {'learning_rate': 0.1, 'max_depth': 6, 'min_data_in_leaf': 20, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 117/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [46]	validation's rmse: 2.51229
# Простые метрики:
# MAE: 2.0002
# MSE: 6.3116
# RMSE: 2.5123
# MAPE: 12.16%
# R²: 0.5265
# Score: 2.000182245630562
# Params: {'learning_rate': 0.1, 'max_depth': 6, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.7, 'min_gain_to_split': 0}
#
# 🔹 Iteration 118/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [46]	validation's rmse: 2.51229
# Простые метрики:
# MAE: 2.0002
# MSE: 6.3116
# RMSE: 2.5123
# MAPE: 12.16%
# R²: 0.5265
# Score: 2.000182245630562
# Params: {'learning_rate': 0.1, 'max_depth': 6, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.7, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 119/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [46]	validation's rmse: 2.51229
# Простые метрики:
# MAE: 2.0002
# MSE: 6.3116
# RMSE: 2.5123
# MAPE: 12.16%
# R²: 0.5265
# Score: 2.000182245630562
# Params: {'learning_rate': 0.1, 'max_depth': 6, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'min_gain_to_split': 0}
#
# 🔹 Iteration 120/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [46]	validation's rmse: 2.51229
# Простые метрики:
# MAE: 2.0002
# MSE: 6.3116
# RMSE: 2.5123
# MAPE: 12.16%
# R²: 0.5265
# Score: 2.000182245630562
# Params: {'learning_rate': 0.1, 'max_depth': 6, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 121/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [38]	validation's rmse: 2.47572
# Простые метрики:
# MAE: 2.0054
# MSE: 6.1292
# RMSE: 2.4757
# MAPE: 12.15%
# R²: 0.5402
# Score: 2.005430096052528
# Params: {'learning_rate': 0.1, 'max_depth': 6, 'min_data_in_leaf': 50, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'min_gain_to_split': 0}
#
# 🔹 Iteration 122/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [38]	validation's rmse: 2.47572
# Простые метрики:
# MAE: 2.0054
# MSE: 6.1292
# RMSE: 2.4757
# MAPE: 12.15%
# R²: 0.5402
# Score: 2.005430096052528
# Params: {'learning_rate': 0.1, 'max_depth': 6, 'min_data_in_leaf': 50, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 123/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [38]	validation's rmse: 2.47572
# Простые метрики:
# MAE: 2.0054
# MSE: 6.1292
# RMSE: 2.4757
# MAPE: 12.15%
# R²: 0.5402
# Score: 2.005430096052528
# Params: {'learning_rate': 0.1, 'max_depth': 6, 'min_data_in_leaf': 50, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'min_gain_to_split': 0}
#
# 🔹 Iteration 124/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [38]	validation's rmse: 2.47572
# Простые метрики:
# MAE: 2.0054
# MSE: 6.1292
# RMSE: 2.4757
# MAPE: 12.15%
# R²: 0.5402
# Score: 2.005430096052528
# Params: {'learning_rate': 0.1, 'max_depth': 6, 'min_data_in_leaf': 50, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 125/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [51]	validation's rmse: 2.49891
# Простые метрики:
# MAE: 1.9881
# MSE: 6.2445
# RMSE: 2.4989
# MAPE: 12.09%
# R²: 0.5315
# Score: 1.988132147283691
# Params: {'learning_rate': 0.1, 'max_depth': 6, 'min_data_in_leaf': 50, 'feature_fraction': 0.8, 'bagging_fraction': 0.7, 'min_gain_to_split': 0}
#
# 🔹 Iteration 126/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [51]	validation's rmse: 2.49891
# Простые метрики:
# MAE: 1.9881
# MSE: 6.2445
# RMSE: 2.4989
# MAPE: 12.09%
# R²: 0.5315
# Score: 1.988132147283691
# Params: {'learning_rate': 0.1, 'max_depth': 6, 'min_data_in_leaf': 50, 'feature_fraction': 0.8, 'bagging_fraction': 0.7, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 127/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [51]	validation's rmse: 2.49891
# Простые метрики:
# MAE: 1.9881
# MSE: 6.2445
# RMSE: 2.4989
# MAPE: 12.09%
# R²: 0.5315
# Score: 1.988132147283691
# Params: {'learning_rate': 0.1, 'max_depth': 6, 'min_data_in_leaf': 50, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'min_gain_to_split': 0}
#
# 🔹 Iteration 128/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [51]	validation's rmse: 2.49891
# Простые метрики:
# MAE: 1.9881
# MSE: 6.2445
# RMSE: 2.4989
# MAPE: 12.09%
# R²: 0.5315
# Score: 1.988132147283691
# Params: {'learning_rate': 0.1, 'max_depth': 6, 'min_data_in_leaf': 50, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 129/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [42]	validation's rmse: 2.49618
# Простые метрики:
# MAE: 2.0184
# MSE: 6.2309
# RMSE: 2.4962
# MAPE: 12.28%
# R²: 0.5325
# Score: 2.018439009490182
# Params: {'learning_rate': 0.1, 'max_depth': 8, 'min_data_in_leaf': 20, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'min_gain_to_split': 0}
#
# 🔹 Iteration 130/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [42]	validation's rmse: 2.49618
# Простые метрики:
# MAE: 2.0184
# MSE: 6.2309
# RMSE: 2.4962
# MAPE: 12.28%
# R²: 0.5325
# Score: 2.018439009490182
# Params: {'learning_rate': 0.1, 'max_depth': 8, 'min_data_in_leaf': 20, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 131/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [42]	validation's rmse: 2.49618
# Простые метрики:
# MAE: 2.0184
# MSE: 6.2309
# RMSE: 2.4962
# MAPE: 12.28%
# R²: 0.5325
# Score: 2.018439009490182
# Params: {'learning_rate': 0.1, 'max_depth': 8, 'min_data_in_leaf': 20, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'min_gain_to_split': 0}
#
# 🔹 Iteration 132/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [42]	validation's rmse: 2.49618
# Простые метрики:
# MAE: 2.0184
# MSE: 6.2309
# RMSE: 2.4962
# MAPE: 12.28%
# R²: 0.5325
# Score: 2.018439009490182
# Params: {'learning_rate': 0.1, 'max_depth': 8, 'min_data_in_leaf': 20, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 133/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [51]	validation's rmse: 2.47961
# Простые метрики:
# MAE: 1.9621
# MSE: 6.1485
# RMSE: 2.4796
# MAPE: 11.97%
# R²: 0.5387
# Score: 1.9621041395966385
# Params: {'learning_rate': 0.1, 'max_depth': 8, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.7, 'min_gain_to_split': 0}
#
# 🔹 Iteration 134/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [51]	validation's rmse: 2.47961
# Простые метрики:
# MAE: 1.9621
# MSE: 6.1485
# RMSE: 2.4796
# MAPE: 11.97%
# R²: 0.5387
# Score: 1.9621041395966385
# Params: {'learning_rate': 0.1, 'max_depth': 8, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.7, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 135/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [51]	validation's rmse: 2.47961
# Простые метрики:
# MAE: 1.9621
# MSE: 6.1485
# RMSE: 2.4796
# MAPE: 11.97%
# R²: 0.5387
# Score: 1.9621041395966385
# Params: {'learning_rate': 0.1, 'max_depth': 8, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'min_gain_to_split': 0}
#
# 🔹 Iteration 136/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [51]	validation's rmse: 2.47961
# Простые метрики:
# MAE: 1.9621
# MSE: 6.1485
# RMSE: 2.4796
# MAPE: 11.97%
# R²: 0.5387
# Score: 1.9621041395966385
# Params: {'learning_rate': 0.1, 'max_depth': 8, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 137/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [50]	validation's rmse: 2.50273
# Простые метрики:
# MAE: 1.9990
# MSE: 6.2637
# RMSE: 2.5027
# MAPE: 12.30%
# R²: 0.5301
# Score: 1.998978056845342
# Params: {'learning_rate': 0.1, 'max_depth': 8, 'min_data_in_leaf': 50, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'min_gain_to_split': 0}
#
# 🔹 Iteration 138/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [50]	validation's rmse: 2.50273
# Простые метрики:
# MAE: 1.9990
# MSE: 6.2637
# RMSE: 2.5027
# MAPE: 12.30%
# R²: 0.5301
# Score: 1.998978056845342
# Params: {'learning_rate': 0.1, 'max_depth': 8, 'min_data_in_leaf': 50, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 139/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [50]	validation's rmse: 2.50273
# Простые метрики:
# MAE: 1.9990
# MSE: 6.2637
# RMSE: 2.5027
# MAPE: 12.30%
# R²: 0.5301
# Score: 1.998978056845342
# Params: {'learning_rate': 0.1, 'max_depth': 8, 'min_data_in_leaf': 50, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'min_gain_to_split': 0}
#
# 🔹 Iteration 140/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [50]	validation's rmse: 2.50273
# Простые метрики:
# MAE: 1.9990
# MSE: 6.2637
# RMSE: 2.5027
# MAPE: 12.30%
# R²: 0.5301
# Score: 1.998978056845342
# Params: {'learning_rate': 0.1, 'max_depth': 8, 'min_data_in_leaf': 50, 'feature_fraction': 0.7, 'bagging_fraction': 0.8, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 141/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [49]	validation's rmse: 2.48812
# Простые метрики:
# MAE: 1.9640
# MSE: 6.1908
# RMSE: 2.4881
# MAPE: 11.98%
# R²: 0.5355
# Score: 1.964027811153269
# Params: {'learning_rate': 0.1, 'max_depth': 8, 'min_data_in_leaf': 50, 'feature_fraction': 0.8, 'bagging_fraction': 0.7, 'min_gain_to_split': 0}
#
# 🔹 Iteration 142/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [49]	validation's rmse: 2.48812
# Простые метрики:
# MAE: 1.9640
# MSE: 6.1908
# RMSE: 2.4881
# MAPE: 11.98%
# R²: 0.5355
# Score: 1.964027811153269
# Params: {'learning_rate': 0.1, 'max_depth': 8, 'min_data_in_leaf': 50, 'feature_fraction': 0.8, 'bagging_fraction': 0.7, 'min_gain_to_split': 0.1}
#
# 🔹 Iteration 143/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [49]	validation's rmse: 2.48812
# Простые метрики:
# MAE: 1.9640
# MSE: 6.1908
# RMSE: 2.4881
# MAPE: 11.98%
# R²: 0.5355
# Score: 1.964027811153269
# Params: {'learning_rate': 0.1, 'max_depth': 8, 'min_data_in_leaf': 50, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'min_gain_to_split': 0}
#
# 🔹 Iteration 144/144
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [49]	validation's rmse: 2.48812
# Простые метрики:
# MAE: 1.9640
# MSE: 6.1908
# RMSE: 2.4881
# MAPE: 11.98%
# R²: 0.5355
# Score: 1.964027811153269
# Params: {'learning_rate': 0.1, 'max_depth': 8, 'min_data_in_leaf': 50, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'min_gain_to_split': 0.1}
#
# BEST RESULT
# Score: 1.9621041395966385
# Params: {'objective': 'regression', 'metric': 'rmse', 'seed': 42, 'verbosity': -1, 'learning_rate': 0.1, 'max_depth': 8, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.7, 'min_gain_to_split': 0}

# %%
# BEST RESULT
# Score: 1.9621041395966385
# Params: {'objective': 'regression', 'metric': 'rmse', 'seed': 42, 'verbosity': -1, 'learning_rate': 0.1, 'max_depth': 8, 'min_data_in_leaf': 20, 'feature_fraction': 0.8, 'bagging_fraction': 0.7, 'min_gain_to_split': 0}
